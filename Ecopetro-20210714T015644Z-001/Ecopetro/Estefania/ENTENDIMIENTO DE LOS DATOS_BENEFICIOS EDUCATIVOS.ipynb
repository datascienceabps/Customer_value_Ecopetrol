# %% [markdown]
# **CONEXIÓN A LA FUENTE DE DATOS Y ANÁLISIS EXPLORATORIO (PERSONAL-BENEFICIOS EDUCATIVOS)**

# %% [markdown]
# #**librerias**

# %%
#Librerias
import re
import numpy as np
import pandas as pd
import pandas_profiling
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
nltk.download('stopwords')
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import unicodedata
from es_lemmatizer import lemmatize
import spacy
import re
import pyodbc
import prince
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\estduclui\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #**rutas**

# %%
#RUTAS
#P :Operaciones financieras
#P : Personal

Campaña_OF = Path('C:/Users/estduclui/Documents/ECOPETROL- TA/Entendimiento del negocio/Modelo Analítico PCF - Cuentas por pagar.xlsx')
Campaña_P = Path('C:/Users/estduclui/Documents/ECOPETROL- TA/Entendimiento del negocio/Modelo Analítico PCP - Beneficio Educativo.xlsx')

# %% [markdown]
# #**Funciones**

# %%
# CONEXION A SERVIDOR ###################################################################################
def Conexion():
    server = '172.27.48.148'
    #database = 'bdcmp_NuevaEpsCrm' 
    username = 'CienciaDatos' 
    password = 'C13nc1aD47*5'  
    cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';UID='+username+';PWD='+ password)
    cursor = cnxn.cursor()
    return cnxn


# DEFINICION DE PICOS Y FECHAS ##################################################################################
##Se definen fechas para realizar los respectivos filtros 
##cuando se extraiga la información correspondiente desde el servidor

def fechas(df_Tipo_P):

#####Personal
    df_P = df_Tipo_P
    
    df_P['fecha_ini_1'] = ['20210201','20210201','20210201','20210401','20210401','20210401','20210401',
                           '20210201','20210201','20210201','20210201','20210201','20210201', '20210201','20210201',
                           '20201101', '20201101', '20200901', '20200901', '20200901']
    df_P['fecha_fin_1'] = ['20210301','20210301','20210301','20210501','20210501','20210501','20210501',
                           '20210301','20210301','20210301','20210301','20210301','20210301', '20210301','20210301',
                           '20201201', '20201201', '20201001', '20201001', '20201001']
    df_P['fecha_ini_2'] = ['20200801','20200801','0','20201101','20201101','20201101','20201101',
                           '20201101','20201101','20201101','20201101','20201101','20201101', '20201101','20200801',
                           '0', '0', '0', '0', '0']
    df_P['fecha_fin_2'] = ['20200901','20200901','0','20201201','20201201','20201201','20201201',
                           '20201201','20201201','20201201','20201201','20201201','20201201', '20201201','20200901',
                           '0', '0', '0', '0', '0']
    df_P  =  df_P.replace('0','20200101')
    return df_P  

## EXTRACCIÓN ########################################################################################################

def Extraccion(df_fechas, df_General, picos):
    #df_fechas : Nombre de la tabla con las tipologias seleccionadas y las fechas definidas correspondientes (con la función de fechas)
    #df_general : Nombre de tabla para cada campaña sin las fechas definidas 
    #picos : Número máximo de picos que se analizan [en OF son 2, en P son 3]
    
    query_base = "SELECT * FROM [172.27.90.50].[Ecopetrol_Reporting].[dbo].[Tbl_Ecopetrol_ResultadoBackOffice]"
    
    i = 0 
    cnxn = Conexion()
    query = "WHERE ([fgs_Nivel3] = '"+ df_fechas['Nivel 3'][i] + "') AND ([fgs_FechaInicio] BETWEEN '" + df_fechas['fecha_ini_1'][i]+ "' AND '" + df_fechas['fecha_fin_1'][i] +"')"  
    query_completa = query_base + query
    df_inicial = pd.read_sql(query_completa, cnxn)

    for j in range(1,picos+1):
        df_General["Datos_Pico_"+str(j)] = 0
        for i in range(0,len(df_fechas['Campaña'])):
            cnxn = Conexion()
            query = "WHERE ([fgs_Nivel3] = '"+ df_fechas['Nivel 3'][i] + "') AND ([fgs_FechaInicio] BETWEEN '" + df_fechas["fecha_ini_"+str(j)][i]+ "' AND '" + df_fechas["fecha_fin_"+str(j)][i] +"')"  
            query_completa = query_base + query
            df = pd.read_sql(query_completa, cnxn)
            df_total = pd.concat([df_inicial,df]).drop_duplicates()
            df_inicial = df_total
            df_General["Datos_Pico_"+str(j)][i] = df.shape[0] 
    print('Total de registros:', df_inicial.shape[0])
    print('Total de columnas:', df_inicial.shape[1])
            
    return df_total,df_General                 

# VALORES FALTANTES ###############################################################################################################################################################################################

def Valores_Faltantes(df, porcentaje):
    Faltantes = df.isnull().sum()
    df_Faltantes = pd.DataFrame({'Nombre_Columnas':Faltantes.index, 'Total_Vacios':Faltantes.values})#[df_Faltantes['Total_Vacios'] != 0]
    df_Faltantes = df_Faltantes[df_Faltantes['Total_Vacios'] != 0]

    df_Faltantes['Porcentaje_vacio'] = ((df_Faltantes['Total_Vacios']/df.shape[0])*100).round(2)
    df_Faltantes['Columna_vacia'] = 'NO'
    df_Faltantes.loc[df_Faltantes['Total_Vacios'] == df.shape[0], 'Columna_vacia'] = 'SI'
    
    print('Total columnas con valores faltantes :', df_Faltantes.shape[0])
    print('Total columnas vacias :', df_Faltantes[df_Faltantes['Columna_vacia'] == 'SI'].Columna_vacia.count())
    print('Total columnas no vacias con mas del ' + str(porcentaje) + '% de valores faltantes :', df_Faltantes[(df_Faltantes['Porcentaje_vacio'] >= porcentaje) & (df_Faltantes['Columna_vacia'] == 'NO') ].Columna_vacia.count())
    #print('Total columnas no vacias con menos del ' + str(porcentaje) + '% de valores faltantes :', df_Faltantes[(df_Faltantes['Porcentaje_vacio'] >= porcentaje) & (df_Faltantes['Columna_vacia'] == 'NO') ].Columna_vacia.count())
    
    return df_Faltantes

# ELIMINAR COLUMNAS##############################################################################################

#para eliminar columnas seleccionadas
def Eliminar_columnas(df, lista_columnas):
    df_drop = df.drop(columns = lista_columnas)
    print ('Cantidad de columnas iniciales : ', df.shape[1])
    print ('Cantidad despues de eliminar : ', df_drop.shape[1] )
    return df_drop

#Para eliminar columnas duplicadas
def columnas_nodup(df):
    print ('Total de columnas antes de eliminar dup: ', df.shape[1])
    df_sindup = df.T.drop_duplicates().T
    print ('Total de columnas duplicadas : ', df.shape[1] - df_sindup.shape[1])
    print ('Total de columnas no duplicadas:', df_sindup.shape[1])
    return df_sindup

# %% [markdown]
# **CAMPAÑA OPERACIONES FINACIERAS - CUENTAS POR PAGAR**

# %% [markdown]
# # **EXTRACCIÓN**

# %% [markdown]
# ## **Definición de Tipologías y meses que se extraeran**

# %% [markdown]
# Se extrae tabla producto del entendimiento del negocio donde se encuentran definidas las tipologias y meses donde se presentaron los picos a estudiar

# %%
df_Tipo_P =  pd.read_excel(Campaña_P, sheet_name = '2. Esquema Tipologías de Servic', usecols = "B:I", skiprows= lambda x: x in [0, 1]).astype(str).replace('NaT','0')

# %% [markdown]
# -- Campaña Operaciones financieras

# %%
df_Tipo_P
# Out:
#      Campaña                Nivel 1                                   Nivel 2  \
# 0   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 1   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 2   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 3   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 4   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 5   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 6   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 7   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 8   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 9   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 10  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 11  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 12  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 13  Personal  Gestión de beneficios  Beneficio Educativo - Colegios Ecopetrol
# 14  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 15  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 16  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 17  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 18  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 19  Personal  Gestión de beneficios             Beneficio Educativo - Regular
#
#                                               Nivel 3  \
# 0   Legal / Reconocimiento Pensionados (Incluye Su...
# 1   Legal / Reconocimiento Trabajadores (Incluye B...
# 2                    Solicitud de educación inclusiva
# 3            Anticipo Pensionados Educación Inclusiva
# 4           Anticipo Trabajadores Educación Inclusiva
# 5           Anticipo Pensionados (Incluye Sustitutos)
# 6                 Anticipo Trabajadores (Incluye BXC)
# 7   Consulta Bachiller Ecopetrol (Incapacidad médi...
# 8   Consulta de información relacionadas con reemb...
# 9      Consulta especialista beneficios atención PQRS
# 10  Consulta sobre liquidación/pago préstamo para ...
# 11  Consulta Titulares Beneficio Eductivo - Desvin...
# 12  Consultas Titulares Beneficio Educativo (No In...
# 13  Solicitud / Consulta / revisión pagos colegios...
# 14  Soporte Plataforma para Instituciones Educativ...
# 15  Reintegro de dinero Pensionados Educación (Inc...
# 16  Reintegro de dinero trabajadores Educación (In...
# 17  Inscripción casos especiales comité de educaci...
# 18  Inscripción casos especiales comité educación ...
# 19  Inscripción solicitud becas Comité de Educació...
#
#                Picos de demanda        Gráficos análisis exploratorio
# 0    Febrero -2021   Agosto-2020                      1. Legalización
# 1    Febrero -2021   Agosto-2020                      1. Legalización
# 2                   Febrero-2021  2. Solicitud de educación inclusiva
# 3     Abril-2021  Noviembre-2020                          3. Anticipo
# 4     Abril-2021  Noviembre-2020                          3. Anticipo
# 5     Abril-2021  Noviembre-2020                          3. Anticipo
# 6     Abril-2021  Noviembre-2020                          3. Anticipo
# 7   Febrero-2021  Noviembre-2020                          4. Consulta
# 8   Febrero-2021  Noviembre-2020                          4. Consulta
# 9   Febrero-2021  Noviembre-2020                          4. Consulta
# 10  Febrero-2021  Noviembre-2020                          4. Consulta
# 11  Febrero-2021  Noviembre-2020                          4. Consulta
# 12  Febrero-2021  Noviembre-2020                          4. Consulta
# 13  Febrero-2021  Noviembre-2020                          4. Consulta
# 14     Febrero-2021  Agosto-2020                5. Soporte Plataforma
# 15                Noviembre-2020                         6. Reintegro
# 16                Noviembre-2020                         6. Reintegro
# 17               Septiembre-2020                       7. Inscripción
# 18               Septiembre-2020                       7. Inscripción
# 19               Septiembre-2020                       7. Inscripción

# %% [markdown]
# Se definen fechas de los picos en cada tipologia con el fin de realizar el posterior filtro

# %%
df_fechas_P = fechas(df_Tipo_P)

df_fechas_P
# Out:
#      Campaña                Nivel 1                                   Nivel 2  \
# 0   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 1   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 2   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 3   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 4   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 5   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 6   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 7   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 8   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 9   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 10  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 11  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 12  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 13  Personal  Gestión de beneficios  Beneficio Educativo - Colegios Ecopetrol
# 14  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 15  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 16  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 17  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 18  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 19  Personal  Gestión de beneficios             Beneficio Educativo - Regular
#
#                                               Nivel 3  \
# 0   Legal / Reconocimiento Pensionados (Incluye Su...
# 1   Legal / Reconocimiento Trabajadores (Incluye B...
# 2                    Solicitud de educación inclusiva
# 3            Anticipo Pensionados Educación Inclusiva
# 4           Anticipo Trabajadores Educación Inclusiva
# 5           Anticipo Pensionados (Incluye Sustitutos)
# 6                 Anticipo Trabajadores (Incluye BXC)
# 7   Consulta Bachiller Ecopetrol (Incapacidad médi...
# 8   Consulta de información relacionadas con reemb...
# 9      Consulta especialista beneficios atención PQRS
# 10  Consulta sobre liquidación/pago préstamo para ...
# 11  Consulta Titulares Beneficio Eductivo - Desvin...
# 12  Consultas Titulares Beneficio Educativo (No In...
# 13  Solicitud / Consulta / revisión pagos colegios...
# 14  Soporte Plataforma para Instituciones Educativ...
# 15  Reintegro de dinero Pensionados Educación (Inc...
# 16  Reintegro de dinero trabajadores Educación (In...
# 17  Inscripción casos especiales comité de educaci...
# 18  Inscripción casos especiales comité educación ...
# 19  Inscripción solicitud becas Comité de Educació...
#
#                Picos de demanda        Gráficos análisis exploratorio  \
# 0    Febrero -2021   Agosto-2020                      1. Legalización
# 1    Febrero -2021   Agosto-2020                      1. Legalización
# 2                   Febrero-2021  2. Solicitud de educación inclusiva
# 3     Abril-2021  Noviembre-2020                          3. Anticipo
# 4     Abril-2021  Noviembre-2020                          3. Anticipo
# 5     Abril-2021  Noviembre-2020                          3. Anticipo
# 6     Abril-2021  Noviembre-2020                          3. Anticipo
# 7   Febrero-2021  Noviembre-2020                          4. Consulta
# 8   Febrero-2021  Noviembre-2020                          4. Consulta
# 9   Febrero-2021  Noviembre-2020                          4. Consulta
# 10  Febrero-2021  Noviembre-2020                          4. Consulta
# 11  Febrero-2021  Noviembre-2020                          4. Consulta
# 12  Febrero-2021  Noviembre-2020                          4. Consulta
# 13  Febrero-2021  Noviembre-2020                          4. Consulta
# 14     Febrero-2021  Agosto-2020                5. Soporte Plataforma
# 15                Noviembre-2020                         6. Reintegro
# 16                Noviembre-2020                         6. Reintegro
# 17               Septiembre-2020                       7. Inscripción
# 18               Septiembre-2020                       7. Inscripción
# 19               Septiembre-2020                       7. Inscripción
#
#    fecha_ini_1 fecha_fin_1 fecha_ini_2 fecha_fin_2
# 0     20210201    20210301    20200801    20200901
# 1     20210201    20210301    20200801    20200901
# 2     20210201    20210301    20200101    20200101
# 3     20210401    20210501    20201101    20201201
# 4     20210401    20210501    20201101    20201201
# 5     20210401    20210501    20201101    20201201
# 6     20210401    20210501    20201101    20201201
# 7     20210201    20210301    20201101    20201201
# 8     20210201    20210301    20201101    20201201
# 9     20210201    20210301    20201101    20201201
# 10    20210201    20210301    20201101    20201201
# 11    20210201    20210301    20201101    20201201
# 12    20210201    20210301    20201101    20201201
# 13    20210201    20210301    20201101    20201201
# 14    20210201    20210301    20200801    20200901
# 15    20201101    20201201    20200101    20200101
# 16    20201101    20201201    20200101    20200101
# 17    20200901    20201001    20200101    20200101
# 18    20200901    20201001    20200101    20200101
# 19    20200901    20201001    20200101    20200101

# %% [markdown]
# ## **Conexión y extracción de la información base**

# %%
# %%time
# Extraccion de la base con los filtros correspondientes
df_Registros_P = Extraccion(df_fechas_P, df_Tipo_P, 2)[0]
# Tipologias seleccionadas e información general
df_General_P = Extraccion(df_fechas_P, df_Tipo_P, 2)[1]
# Out:
# <ipython-input-3-92c054b267ce>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_General["Datos_Pico_"+str(j)][i] = df.shape[0]
# Total de registros: 13748
# Total de columnas: 222
# Total de registros: 13748
# Total de columnas: 222
# Wall time: 12min 1s

# %% [markdown]
# Tabla con información general de lo que se extrajo por tipologia y pico

# %%
df_General_P['total'] = df_General_P['Datos_Pico_1'] + df_General_P['Datos_Pico_2']

# %%
df_General_P
# Out:
#      Campaña                Nivel 1                                   Nivel 2  \
# 0   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 1   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 2   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 3   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 4   Personal  Gestión de beneficios           Beneficio Educativo - Inclusiva
# 5   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 6   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 7   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 8   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 9   Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 10  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 11  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 12  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 13  Personal  Gestión de beneficios  Beneficio Educativo - Colegios Ecopetrol
# 14  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 15  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 16  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 17  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 18  Personal  Gestión de beneficios             Beneficio Educativo - Regular
# 19  Personal  Gestión de beneficios             Beneficio Educativo - Regular
#
#                                               Nivel 3  \
# 0   Legal / Reconocimiento Pensionados (Incluye Su...
# 1   Legal / Reconocimiento Trabajadores (Incluye B...
# 2                    Solicitud de educación inclusiva
# 3            Anticipo Pensionados Educación Inclusiva
# 4           Anticipo Trabajadores Educación Inclusiva
# 5           Anticipo Pensionados (Incluye Sustitutos)
# 6                 Anticipo Trabajadores (Incluye BXC)
# 7   Consulta Bachiller Ecopetrol (Incapacidad médi...
# 8   Consulta de información relacionadas con reemb...
# 9      Consulta especialista beneficios atención PQRS
# 10  Consulta sobre liquidación/pago préstamo para ...
# 11  Consulta Titulares Beneficio Eductivo - Desvin...
# 12  Consultas Titulares Beneficio Educativo (No In...
# 13  Solicitud / Consulta / revisión pagos colegios...
# 14  Soporte Plataforma para Instituciones Educativ...
# 15  Reintegro de dinero Pensionados Educación (Inc...
# 16  Reintegro de dinero trabajadores Educación (In...
# 17  Inscripción casos especiales comité de educaci...
# 18  Inscripción casos especiales comité educación ...
# 19  Inscripción solicitud becas Comité de Educació...
#
#                Picos de demanda        Gráficos análisis exploratorio  \
# 0    Febrero -2021   Agosto-2020                      1. Legalización
# 1    Febrero -2021   Agosto-2020                      1. Legalización
# 2                   Febrero-2021  2. Solicitud de educación inclusiva
# 3     Abril-2021  Noviembre-2020                          3. Anticipo
# 4     Abril-2021  Noviembre-2020                          3. Anticipo
# 5     Abril-2021  Noviembre-2020                          3. Anticipo
# 6     Abril-2021  Noviembre-2020                          3. Anticipo
# 7   Febrero-2021  Noviembre-2020                          4. Consulta
# 8   Febrero-2021  Noviembre-2020                          4. Consulta
# 9   Febrero-2021  Noviembre-2020                          4. Consulta
# 10  Febrero-2021  Noviembre-2020                          4. Consulta
# 11  Febrero-2021  Noviembre-2020                          4. Consulta
# 12  Febrero-2021  Noviembre-2020                          4. Consulta
# 13  Febrero-2021  Noviembre-2020                          4. Consulta
# 14     Febrero-2021  Agosto-2020                5. Soporte Plataforma
# 15                Noviembre-2020                         6. Reintegro
# 16                Noviembre-2020                         6. Reintegro
# 17               Septiembre-2020                       7. Inscripción
# 18               Septiembre-2020                       7. Inscripción
# 19               Septiembre-2020                       7. Inscripción
#
#    fecha_ini_1 fecha_fin_1 fecha_ini_2 fecha_fin_2  Datos_Pico_1  \
# 0     20210201    20210301    20200801    20200901          1271
# 1     20210201    20210301    20200801    20200901          2272
# 2     20210201    20210301           0           0           414
# 3     20210401    20210501    20201101    20201201            13
# 4     20210401    20210501    20201101    20201201             3
# 5     20210401    20210501    20201101    20201201           585
# 6     20210401    20210501    20201101    20201201           313
# 7     20210201    20210301    20201101    20201201             1
# 8     20210201    20210301    20201101    20201201             7
# 9     20210201    20210301    20201101    20201201             1
# 10    20210201    20210301    20201101    20201201             8
# 11    20210201    20210301    20201101    20201201            29
# 12    20210201    20210301    20201101    20201201           647
# 13    20210201    20210301    20201101    20201201            25
# 14    20210201    20210301    20200801    20200901           657
# 15    20201101    20201201           0           0            58
# 16    20201101    20201201           0           0           303
# 17    20200901    20201001           0           0            99
# 18    20200901    20201001           0           0            14
# 19    20200901    20201001           0           0           353
#
#     Datos_Pico_2  total
# 0           1144   2415
# 1           1923   4195
# 2              0    414
# 3              7     20
# 4             12     15
# 5           1001   1586
# 6           1494   1807
# 7              2      3
# 8              5     12
# 9              0      1
# 10             2     10
# 11            23     52
# 12           578   1225
# 13            20     45
# 14           464   1121
# 15             0     58
# 16             0    303
# 17             0     99
# 18             0     14
# 19             0    353

# %%
df_Registros_P.to_csv('Base_general_extraida_P.csv', index = False)

# %% [markdown]
# # **REVISIÓN Y LIMPIEZA**

# %% [markdown]
# ## **Perfilamiento inicial**

# %%
profile = df_Registros_P.profile_report(title = 'Pandas Profiling Report', correlations={"cramers": {"calculate": False}})
profile.to_file(output_file = 'Perfilamiento_BaseInicial_BeneficiosEducativos.html')
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=235.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render HTML'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Export report to file'), FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %% [markdown]
# ## **Valores faltantes**

# %% [markdown]
# ### **Columnas con valores faltantes**

# %%
df_Registros_P = pd.read_csv('Base_general_extraida_P.csv')
# Out:
# C:\Users\estduclui\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (51,156,160,161,162,163,165,167,197) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_Faltantes_P = Valores_Faltantes(df_Registros_P, 50)
# Out:
# Total columnas con valores faltantes : 157
# Total columnas vacias : 56
# Total columnas no vacias con mas del 50% de valores faltantes : 58

# %%
df_Faltantes_P[(df_Faltantes_P['Porcentaje_vacio'] >=50 ) & (df_Faltantes_P['Columna_vacia'] == 'NO')]
# Out:
#                         Nombre_Columnas  Total_Vacios  Porcentaje_vacio  \
# 34               fgs_BarrioDireccion_01         13699             99.64
# 35            fgs_LocalidadDireccion_01         13695             99.61
# 40                      fgs_Telefono_02         13482             98.07
# 41                      fgs_Telefono_03         13613             99.02
# 42                      fgs_Telefono_04         13699             99.64
# 44                         fgs_Email_02         13682             99.52
# 45                         fgs_Email_03         13731             99.88
# 63                   fmf_FechaSolicitud          7508             54.61
# 68                          fdp_IdFlujo         10592             77.04
# 84          T_Real_SolicitadoRegistrado          7508             54.61
# 89     fdp_IdHistoricoPqrEscalamientoN2         10752             78.21
# 90            fdp_IdGrupoEscalamientoN2         10752             78.21
# 91        fdp_NombreGrupoEscalamientoN2         10752             78.21
# 92     fdp_IdDetalleFlujoEscalamientoN2         10752             78.21
# 93          fdp_IdUsuarioEscalamientoN2         10776             78.38
# 94            fdp_UsuarioEscalamientoN2         10776             78.38
# 95      fdp_NombreUsuarioEscalamientoN2         10776             78.38
# 96        fgs_ObservacionEscalamientoN2         10752             78.21
# 97              fdp_FechaEscalamientoN2         10752             78.21
# 98   fdp_FechaVencimientoEscalamientoN2         10752             78.21
# 99         CodigoGrupoRolEscalamientoN2         10776             78.38
# 100              GrupoRolEscalamientoN2         10776             78.38
# 102             fdp_NivelEscalamientoN2         10752             78.21
# 103                 T_Objetivo_EnNivel2         10752             78.21
# 123        fdp_IdHistoricoPqrDevolucion         13527             98.39
# 124               fdp_IdGrupoDevolucion         13527             98.39
# 125           fdp_NombreGrupoDevolucion         13527             98.39
# 126        fdp_IdDetalleFlujoDevolucion         13527             98.39
# 127             fdp_IdUsuarioDevolucion         13527             98.39
# 128               fdp_UsuarioDevolucion         13527             98.39
# 129         fdp_NombreUsuarioDevolucion         13527             98.39
# 130           fgs_ObservacionDevolucion         13527             98.39
# 131                 fdp_FechaDevolucion         13527             98.39
# 132      fdp_FechaVencimientoDevolucion         13527             98.39
# 133            CodigoGrupoRolDevolucion         13527             98.39
# 134                  GrupoRolDevolucion         13527             98.39
# 135                fdp_MotivoDevolucion         13569             98.70
# 136                 fdp_NivelDevolucion         13527             98.39
# 140          fdp_IdDetalleFlujoSolucion         10621             77.25
# 154        fdp_IdHistoricoPqrReapertura         13747             99.99
# 155               fdp_IdGrupoReapertura         13747             99.99
# 156           fdp_NombreGrupoReapertura         13747             99.99
# 157        fdp_IdDetalleFlujoReapertura         13747             99.99
# 158             fdp_IdUsuarioReapertura         13747             99.99
# 159               fdp_UsuarioReapertura         13747             99.99
# 160         fdp_NombreUsuarioReapertura         13747             99.99
# 161           fgs_ObservacionReapertura         13747             99.99
# 162                 fdp_FechaReapertura         13747             99.99
# 163      fdp_FechaVencimientoReapertura         13747             99.99
# 164            CodigoGrupoRolReapertura         13747             99.99
# 165                  GrupoRolReapertura         13747             99.99
# 167                 fdp_NivelReapertura         13747             99.99
# 171            fdp_IdDetalleFlujoCierre         10622             77.26
# 182                    T_Objetivo_Total         10752             78.21
# 188     fdp_IdDetalleFlujoGestionActual         10592             77.04
# 197             fdp_MotivoGestionActual         13746             99.99
# 199                            Ajustado          6962             50.64
# 200                          TipoAjuste          6962             50.64
#
#     Columna_vacia
# 34             NO
# 35             NO
# 40             NO
# 41             NO
# 42             NO
# 44             NO
# 45             NO
# 63             NO
# 68             NO
# 84             NO
# 89             NO
# 90             NO
# 91             NO
# 92             NO
# 93             NO
# 94             NO
# 95             NO
# 96             NO
# 97             NO
# 98             NO
# 99             NO
# 100            NO
# 102            NO
# 103            NO
# 123            NO
# 124            NO
# 125            NO
# 126            NO
# 127            NO
# 128            NO
# 129            NO
# 130            NO
# 131            NO
# 132            NO
# 133            NO
# 134            NO
# 135            NO
# 136            NO
# 140            NO
# 154            NO
# 155            NO
# 156            NO
# 157            NO
# 158            NO
# 159            NO
# 160            NO
# 161            NO
# 162            NO
# 163            NO
# 164            NO
# 165            NO
# 167            NO
# 171            NO
# 182            NO
# 188            NO
# 197            NO
# 199            NO
# 200            NO

# %% [markdown]
# Lista de columnas a eliminar: columnas vacias o con un porcentaje de vacio 100%

# %%
DropCol_P= list(df_Faltantes_P[(df_Faltantes_P['Porcentaje_vacio'] >50)].Nombre_Columnas)

# %%
#total de columnas a eliminar
len(DropCol_P)
# Out:
# 114

# %%
df_P = Eliminar_columnas(df_Registros_P,DropCol_P )
# Out:
# Cantidad de columnas iniciales :  222
# Cantidad despues de eliminar :  108

# %%
df_P.shape
# Out:
# (13748, 108)

# %% [markdown]
# Columnas con menos del 50% de valores vacios

# %%
df_Faltantes_P[df_Faltantes_P['Porcentaje_vacio'] < 50]
# Out:
#                        Nombre_Columnas  Total_Vacios  Porcentaje_vacio  \
# 5          fgs_SiglasDocumentoContacto            14              0.10
# 17                              fgs_Ip            14              0.10
# 36              fgs_CiudadDireccion_01            14              0.10
# 37        fgs_DepartamentoDireccion_01            14              0.10
# 38                fgs_PaisDireccion_01            14              0.10
# 47                        ude_Regional           868              6.31
# 48                   ude_CiudadCliente           786              5.72
# 49             ude_DepartamentoCliente           786              5.72
# 51                          ude_CodUni           933              6.79
# 52              ude_UnidadOrganizativa          5910             42.99
# 53                            ude_CECO           933              6.79
# 54                  ude_CentroDeCostos           944              6.87
# 55                    ude_EmailCliente           862              6.27
# 87           T_Real_RegistradoEscalado             2              0.01
# 104                    T_Real_EnNivel2           187              1.36
# 121                    T_Real_EnNivel3          3156             22.96
# 137         fdp_IdHistoricoPqrSolucion            29              0.21
# 138                fdp_IdGrupoSolucion            29              0.21
# 139            fdp_NombreGrupoSolucion            29              0.21
# 141              fdp_IdUsuarioSolucion            29              0.21
# 142                fdp_UsuarioSolucion            29              0.21
# 143          fdp_NombreUsuarioSolucion            29              0.21
# 144            fgs_ObservacionSolucion            29              0.21
# 145                  fdp_FechaSolucion            29              0.21
# 146       fdp_FechaVencimientoSolucion            40              0.29
# 147             CodigoGrupoRolSolucion            29              0.21
# 148                   GrupoRolSolucion            29              0.21
# 150                  fdp_NivelSolucion            29              0.21
# 152          T_Real_SolucionadoCerrado            30              0.22
# 168           fdp_IdHistoricoPqrCierre            30              0.22
# 169                  fdp_IdGrupoCierre            30              0.22
# 170              fdp_NombreGrupoCierre            30              0.22
# 172                fdp_IdUsuarioCierre            30              0.22
# 173                  fdp_UsuarioCierre            30              0.22
# 174            fdp_NombreUsuarioCierre            30              0.22
# 175              fgs_ObservacionCierre            30              0.22
# 176                    fdp_FechaCierre            30              0.22
# 177         fdp_FechaVencimientoCierre            41              0.30
# 178               CodigoGrupoRolCierre            30              0.22
# 179                     GrupoRolCierre            30              0.22
# 181                    fdp_NivelCierre            30              0.22
# 194  fdp_FechaVencimientoGestionActual            11              0.08
# 220                    T_Real_EnNivel4          3156             22.96
#
#     Columna_vacia
# 5              NO
# 17             NO
# 36             NO
# 37             NO
# 38             NO
# 47             NO
# 48             NO
# 49             NO
# 51             NO
# 52             NO
# 53             NO
# 54             NO
# 55             NO
# 87             NO
# 104            NO
# 121            NO
# 137            NO
# 138            NO
# 139            NO
# 141            NO
# 142            NO
# 143            NO
# 144            NO
# 145            NO
# 146            NO
# 147            NO
# 148            NO
# 150            NO
# 152            NO
# 168            NO
# 169            NO
# 170            NO
# 172            NO
# 173            NO
# 174            NO
# 175            NO
# 176            NO
# 177            NO
# 178            NO
# 179            NO
# 181            NO
# 194            NO
# 220            NO

# %% [markdown]
# ###  **Columnas duplicadas**

# %%
df_sindup = df_P.T
#SE MUESTRAN TODAS LAS COLUMNAS CON DUPLICADOS
df_sindup[df_sindup.duplicated(keep =False)]
# Out:
#                                                                       0      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       1      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       2      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       3      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       4      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       5      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       6      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       7      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       8      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       9      \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Legal / Reconocimiento Pensionados (Incluye Su...
# fgs_Nivel4                Legal / Reconocimiento Pensionados (Incluye Su...
# ServicioPortafolio        Legal / Reconocimiento Pensionados (Incluye Su...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                           ...  \
# fgs_NombreCampana         ...
# fgs_Nivel3                ...
# fgs_Nivel4                ...
# ServicioPortafolio        ...
# AreaServicio              ...
# fdp_NivelEstado           ...
# fdp_IdGrupoCreacion       ...
# T_Real_EnNivel3           ...
# Cumple_Objetivo_EnNivel3  ...
# fdp_NivelGestionActual    ...
# Pruebas                   ...
# T_Real_EnNivel4           ...
# Cumple_Objetivo_EnNivel4  ...
#
#                                                                       13738  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13739  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13740  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13741  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13742  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13743  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13744  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13745  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13746  \
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel2
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                         NaN
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel2
# Pruebas                                                               False
# T_Real_EnNivel4                                                         NaN
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
#                                                                       13747
# fgs_NombreCampana                                                  Personal
# fgs_Nivel3                Soporte Plataforma para Instituciones Educativ...
# fgs_Nivel4                Soporte Plataforma para Instituciones Educativ...
# ServicioPortafolio        Soporte Plataforma para Instituciones Educativ...
# AreaServicio                                                       Personal
# fdp_NivelEstado                                                      Nivel1
# fdp_IdGrupoCreacion                                                       0
# T_Real_EnNivel3                                                           0
# Cumple_Objetivo_EnNivel3                                          No Aplica
# fdp_NivelGestionActual                                               Nivel1
# Pruebas                                                               False
# T_Real_EnNivel4                                                           0
# Cumple_Objetivo_EnNivel4                                          No Aplica
#
# [13 rows x 13748 columns]

# %%
#nueva tabla con columnas no duplicadas
df_P = columnas_nodup(df_P)
# Out:
# Total de columnas antes de eliminar dup:  108
# Total de columnas duplicadas :  7
# Total de columnas no duplicadas: 101

# %% [markdown]
# ### **Filas con valores faltantes**

# %% [markdown]
# Columnas de observaciones con valores faltantes

# %%
df_Faltantes_P_new = Valores_Faltantes(df_P[['fgs_ObservacionCreacion','fgs_ObservacionEscalamientoN2','fgs_ObservacionSolucion','fgs_ObservacionDevolucion']], 1)
df_Faltantes_P_new
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-5c3e910b1f2c> in <module>
# ----> 1 df_Faltantes_P_new = Valores_Faltantes(df_P[['fgs_ObservacionCreacion','fgs_ObservacionEscalamientoN2','fgs_ObservacionSolucion','fgs_ObservacionDevolucion']], 1)
#       2 df_Faltantes_P_new
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['fgs_ObservacionEscalamientoN2', 'fgs_ObservacionDevolucion'] not in index"

# %% [markdown]
# Puesto que son necesarios por lo menos los campos de observacion de creacion y de solucion, se eliminan las columnas que no cuenten con estos campos

# %%
DropCol_P_2= ['fgs_ObservacionSolucion']

# %%
print ('Total filas antes de suprimir : ', df_P.shape[0])
df_P.dropna(subset = DropCol_P_2, inplace =True)
print ('Total filas despues de suprimir : ', df_P.shape[0])

# %% [markdown]
# Se vuelve a revisar valores faltates en la nueva base

# %%
df_Faltantes_P_2 = Valores_Faltantes(df_P, 30)
# Out:
# Total columnas con valores faltantes : 42
# Total columnas vacias : 0
# Total columnas no vacias con mas del 30% de valores faltantes : 1

# %%
df_Faltantes_P_2
# Out:
#                       Nombre_Columnas  Total_Vacios  Porcentaje_vacio  \
# 5         fgs_SiglasDocumentoContacto            14              0.10
# 8                              fgs_Ip            14              0.10
# 17             fgs_CiudadDireccion_01            14              0.10
# 18       fgs_DepartamentoDireccion_01            14              0.10
# 19               fgs_PaisDireccion_01            14              0.10
# 23                       ude_Regional           868              6.31
# 24                  ude_CiudadCliente           786              5.72
# 25            ude_DepartamentoCliente           786              5.72
# 27                         ude_CodUni           933              6.79
# 28             ude_UnidadOrganizativa          5910             42.99
# 29                           ude_CECO           933              6.79
# 30                 ude_CentroDeCostos           944              6.87
# 31                   ude_EmailCliente           862              6.27
# 55          T_Real_RegistradoEscalado             2              0.01
# 57                    T_Real_EnNivel2           187              1.36
# 59                    T_Real_EnNivel3          3156             22.96
# 61         fdp_IdHistoricoPqrSolucion            29              0.21
# 62                fdp_IdGrupoSolucion            29              0.21
# 63            fdp_NombreGrupoSolucion            29              0.21
# 64              fdp_IdUsuarioSolucion            29              0.21
# 65                fdp_UsuarioSolucion            29              0.21
# 66          fdp_NombreUsuarioSolucion            29              0.21
# 67            fgs_ObservacionSolucion            29              0.21
# 68                  fdp_FechaSolucion            29              0.21
# 69       fdp_FechaVencimientoSolucion            40              0.29
# 70             CodigoGrupoRolSolucion            29              0.21
# 71                   GrupoRolSolucion            29              0.21
# 72                  fdp_NivelSolucion            29              0.21
# 74          T_Real_SolucionadoCerrado            30              0.22
# 76           fdp_IdHistoricoPqrCierre            30              0.22
# 77                  fdp_IdGrupoCierre            30              0.22
# 78              fdp_NombreGrupoCierre            30              0.22
# 79                fdp_IdUsuarioCierre            30              0.22
# 80                  fdp_UsuarioCierre            30              0.22
# 81            fdp_NombreUsuarioCierre            30              0.22
# 82              fgs_ObservacionCierre            30              0.22
# 83                    fdp_FechaCierre            30              0.22
# 84         fdp_FechaVencimientoCierre            41              0.30
# 85               CodigoGrupoRolCierre            30              0.22
# 86                     GrupoRolCierre            30              0.22
# 87                    fdp_NivelCierre            30              0.22
# 96  fdp_FechaVencimientoGestionActual            11              0.08
#
#    Columna_vacia
# 5             NO
# 8             NO
# 17            NO
# 18            NO
# 19            NO
# 23            NO
# 24            NO
# 25            NO
# 27            NO
# 28            NO
# 29            NO
# 30            NO
# 31            NO
# 55            NO
# 57            NO
# 59            NO
# 61            NO
# 62            NO
# 63            NO
# 64            NO
# 65            NO
# 66            NO
# 67            NO
# 68            NO
# 69            NO
# 70            NO
# 71            NO
# 72            NO
# 74            NO
# 76            NO
# 77            NO
# 78            NO
# 79            NO
# 80            NO
# 81            NO
# 82            NO
# 83            NO
# 84            NO
# 85            NO
# 86            NO
# 87            NO
# 96            NO

# %%
vacio = list(df_Faltantes_P_2[df_Faltantes_P_2['Columna_vacia']=='SI'].Nombre_Columnas.unique() )
vacio
# Out:
# []

# %%
df_P = Eliminar_columnas(df_P,vacio)
# Out:
# Cantidad de columnas iniciales :  101
# Cantidad despues de eliminar :  101

# %% [markdown]
# ## **Revisión y supresión de columnas por tipo y relevancia en el análisis**

# %% [markdown]
# Tipo de columnas

# %%
list(set(df_P.dtypes.tolist()))
# Out:
# [dtype('O')]

# %% [markdown]
# No hay columnas de tipo número*

# %% [markdown]
# ### **Columnas tipo texto**

# %%
df_Ptext = df_P.select_dtypes(include = ['O'])
df_Ptext.head()
# Out:
#   fgs_IdCampana fgs_IdGestion fgs_IdGestionDetalle fgs_NombreCampana  \
# 0             3      13908445          1.01137e+06          Personal
# 1             3      13908527          1.01142e+06          Personal
# 2             3      13908581          1.01144e+06          Personal
# 3             3      13908589          1.01148e+06          Personal
# 4             3      13908640          1.01151e+06          Personal
#
#   fgs_NombrePlataforma fgs_SiglasDocumentoContacto fgs_NumeroDocumContacto  \
# 0                  Web                          CC                19322865
# 1                  Web                          CC              1053843731
# 2                  Web                          CC                17043647
# 3                  Web                          CC                19105812
# 4                  Web                          CC                51659165
#
#          fgs_NombreCompletoContacto         fgs_Ip          fgs_FechaInicio  \
# 0      SANCHEZ MORA JOAQUIN ERNESTO   172.27.40.50  2021-02-01 06:40:30.150
# 1         SANTA GAVIRIA MERY ANGELA  192.168.73.74  2021-02-01 06:55:42.110
# 2  CONTRERAS GAITAN JOSE DEL CARMEN   172.27.40.50  2021-02-01 07:03:59.197
# 3                MOLANO PINZON HUGO  192.168.73.91  2021-02-01 07:04:56.607
# 4       AMAYA CAMPOS MARIA CRISTINA   172.27.40.50  2021-02-01 07:11:56.000
#
#    ... fdp_IdUsuarioGestionActual fdp_UsuarioGestionActual  \
# 0  ...                       2901                 52835092
# 1  ...                        106               1013600392
# 2  ...                       2486               9128158500
# 3  ...                         58                 52779150
# 4  ...                       2486               9128158500
#
#     fdp_NombreUsuarioGestionActual  \
# 0  AIDA ALEXANDRA RODRIGUEZ AMAYA
# 1   DIANA MILENA GUERRERO MELLIZO
# 2      REINALDO  HUDGSON GUERRERO
# 3       ELIANA ELIZABETH ESQUIVEL
# 4      REINALDO  HUDGSON GUERRERO
#
#                         fgs_ObservacionGestionActual   fdp_FechaGestionActual  \
# 0  "se informa que su caso no puede ser tramitado...  2021-02-01 06:47:23.443
# 1  Se realizó el ajuste de semestre y se encuentr...  2021-02-01 07:01:31.857
# 2  SE INFORMA A LA PETICIONARIA QUE ESTE CASO FUE...  2021-02-01 07:09:37.667
# 3  GESTIÓN REALIZADA:<br>Dando respuesta a la con...  2021-02-01 07:19:12.327
# 4  SE INFORMA QUE DEBE ANEXAR CERTIFICACION DE UN...  2021-02-01 07:23:02.490
#
#   fdp_FechaVencimientoGestionActual CodigoGrupoRolGestionActual  \
# 0           2020-02-25 16:30:00.000                           3
# 1           2020-02-25 16:30:00.000                           1
# 2           2020-02-25 16:30:00.000                           4
# 3           2020-02-25 16:30:00.000                           1
# 4           2020-02-25 16:30:00.000                           4
#
#                      GrupoRolGestionActual fdp_FechaVencimientoTotal  \
# 0  Asesor de Servicio Front Contact Center   2021-02-01 09:45:00.000
# 1        Asesor de Servicio Contact Center   2021-02-01 09:45:00.000
# 2       Asesor de Servicio Front Ecopetrol   2021-02-01 09:45:00.000
# 3        Asesor de Servicio Contact Center   2021-02-01 09:45:00.000
# 4       Asesor de Servicio Front Ecopetrol   2021-02-01 09:45:00.000
#
#   NoReprocesar
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#
# [5 rows x 101 columns]

# %%
print ('Total de columnas tipo texto : ', df_Ptext.shape[1])
df_Faltantes_text = Valores_Faltantes(df_Ptext, 10)
# Out:
# Total de columnas tipo texto :  101
# Total columnas con valores faltantes : 42
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 2

# %%
df_Faltantes_text
# Out:
#                       Nombre_Columnas  Total_Vacios  Porcentaje_vacio  \
# 5         fgs_SiglasDocumentoContacto            14              0.10
# 8                              fgs_Ip            14              0.10
# 17             fgs_CiudadDireccion_01            14              0.10
# 18       fgs_DepartamentoDireccion_01            14              0.10
# 19               fgs_PaisDireccion_01            14              0.10
# 23                       ude_Regional           868              6.31
# 24                  ude_CiudadCliente           786              5.72
# 25            ude_DepartamentoCliente           786              5.72
# 27                         ude_CodUni           933              6.79
# 28             ude_UnidadOrganizativa          5910             42.99
# 29                           ude_CECO           933              6.79
# 30                 ude_CentroDeCostos           944              6.87
# 31                   ude_EmailCliente           862              6.27
# 55          T_Real_RegistradoEscalado             2              0.01
# 57                    T_Real_EnNivel2           187              1.36
# 59                    T_Real_EnNivel3          3156             22.96
# 61         fdp_IdHistoricoPqrSolucion            29              0.21
# 62                fdp_IdGrupoSolucion            29              0.21
# 63            fdp_NombreGrupoSolucion            29              0.21
# 64              fdp_IdUsuarioSolucion            29              0.21
# 65                fdp_UsuarioSolucion            29              0.21
# 66          fdp_NombreUsuarioSolucion            29              0.21
# 67            fgs_ObservacionSolucion            29              0.21
# 68                  fdp_FechaSolucion            29              0.21
# 69       fdp_FechaVencimientoSolucion            40              0.29
# 70             CodigoGrupoRolSolucion            29              0.21
# 71                   GrupoRolSolucion            29              0.21
# 72                  fdp_NivelSolucion            29              0.21
# 74          T_Real_SolucionadoCerrado            30              0.22
# 76           fdp_IdHistoricoPqrCierre            30              0.22
# 77                  fdp_IdGrupoCierre            30              0.22
# 78              fdp_NombreGrupoCierre            30              0.22
# 79                fdp_IdUsuarioCierre            30              0.22
# 80                  fdp_UsuarioCierre            30              0.22
# 81            fdp_NombreUsuarioCierre            30              0.22
# 82              fgs_ObservacionCierre            30              0.22
# 83                    fdp_FechaCierre            30              0.22
# 84         fdp_FechaVencimientoCierre            41              0.30
# 85               CodigoGrupoRolCierre            30              0.22
# 86                     GrupoRolCierre            30              0.22
# 87                    fdp_NivelCierre            30              0.22
# 96  fdp_FechaVencimientoGestionActual            11              0.08
#
#    Columna_vacia
# 5             NO
# 8             NO
# 17            NO
# 18            NO
# 19            NO
# 23            NO
# 24            NO
# 25            NO
# 27            NO
# 28            NO
# 29            NO
# 30            NO
# 31            NO
# 55            NO
# 57            NO
# 59            NO
# 61            NO
# 62            NO
# 63            NO
# 64            NO
# 65            NO
# 66            NO
# 67            NO
# 68            NO
# 69            NO
# 70            NO
# 71            NO
# 72            NO
# 74            NO
# 76            NO
# 77            NO
# 78            NO
# 79            NO
# 80            NO
# 81            NO
# 82            NO
# 83            NO
# 84            NO
# 85            NO
# 86            NO
# 87            NO
# 96            NO

# %% [markdown]
# Se tienen dos grupos de columnas con información aparentemente similar (ciudad,departamento,mail), solo que unas estan mas completas que las otras de acuerdo al porcentaje de valores faltantes.

# %%
df_Ptext[['fgs_Direccion_01',
       'fgs_CiudadDireccion_01', 'fgs_DepartamentoDireccion_01',
       'fgs_PaisDireccion_01', 'fgs_Telefono_01', 'fgs_Email_01',
        'ude_CiudadCliente', 'ude_DepartamentoCliente',
       'ude_PaisCliente',
       'ude_EmailCliente']]
# Out:
#                                         fgs_Direccion_01  \
# 0                                          CL 170 53C 27
# 1                    MCCA 21 CONJ PORTAL DE LAS AVENIDAS
# 2                                         CL 5 N 3 E 143
# 3                       MZ DCA 5 BALCONES DEL LIBERTADOR
# 4                                    CL 145 7 A 40 CA 19
# ...                                                  ...
# 13743  CR 16 127 B 43 BL 4 AP 204 CONJ. RETIRO DE STA...
# 13744                                         CR 6 13 12
# 13745                                     CL 6 B 23 A 31
# 13746                      CR 54 A 167 A 41 IN 2 AP 1102
# 13747                                     CL 6 B 23 A 31
#
#       fgs_CiudadDireccion_01 fgs_DepartamentoDireccion_01  \
# 0               BOGOTA, D.C.                       BOGOTA
# 1                SANTA MARTA                    MAGDALENA
# 2                     CUCUTA              N. DE SANTANDER
# 3                SANTA MARTA                    MAGDALENA
# 4               BOGOTA, D.C.                       BOGOTA
# ...                      ...                          ...
# 13743           BOGOTA, D.C.                       BOGOTA
# 13744           BOGOTA, D.C.                       BOGOTA
# 13745                BARANOA                    ATLANTICO
# 13746           BOGOTA, D.C.                       BOGOTA
# 13747                  NEIVA                        HUILA
#
#       fgs_PaisDireccion_01 fgs_Telefono_01                   fgs_Email_01  \
# 0                 Colombia        12572213          JOSAMO_57@HOTMAIL.COM
# 1                 Colombia      3124964423          ANGY15_95@HOTMAIL.COM
# 2                 Colombia        75924310     GLADISMARIA316@OUTLOOK.COM
# 3                 Colombia        54389035         HUGO_MOL18@HOTMAIL.COM
# 4                 Colombia      3157237219    MARIACRIS.AMAYA@HOTMAIL.COM
# ...                    ...             ...                            ...
# 13743             Colombia        15202720           LCASALLA@HOTMAIL.COM
# 13744             Colombia      3112452551          PILARES02@HOTMAIL.COM
# 13745             Colombia        88703560  EDGAR.SANTOS@ECOPETROL.COM.CO
# 13746             Colombia        17517253  JAIME.PLAZAS@ECOPETROL.COM.CO
# 13747             Colombia        88703560  EDGAR.SANTOS@ECOPETROL.COM.CO
#
#         ude_CiudadCliente ude_DepartamentoCliente ude_PaisCliente  \
# 0                  BOGOTA                  BOGOTA        COLOMBIA
# 1             SANTA MARTA               MAGDALENA        COLOMBIA
# 2      SAN JOSE DE CUCUTA         N. DE SANTANDER        COLOMBIA
# 3             SANTA MARTA               MAGDALENA        COLOMBIA
# 4                  BOGOTA                  BOGOTA        COLOMBIA
# ...                   ...                     ...             ...
# 13743              BOGOTA                  BOGOTA        COLOMBIA
# 13744       PUERTO SALGAR            CUNDINAMARCA        COLOMBIA
# 13745               NEIVA                   HUILA        COLOMBIA
# 13746        BOGOTA, D.C.                  BOGOTA        COLOMBIA
# 13747               NEIVA                   HUILA        COLOMBIA
#
#                     ude_EmailCliente
# 0              JOSAMO_57@HOTMAIL.COM
# 1              ANGY15_95@HOTMAIL.COM
# 2         GLADISMARIA316@OUTLOOK.COM
# 3             HUGO_MOL18@HOTMAIL.COM
# 4        MARIACRIS.AMAYA@HOTMAIL.COM
# ...                              ...
# 13743           LCASALLA@HOTMAIL.COM
# 13744          PILARES02@HOTMAIL.COM
# 13745  EDGAR.SANTOS@ECOPETROL.COM.CO
# 13746  JAIME.PLAZAS@ECOPETROL.COM.CO
# 13747  EDGAR.SANTOS@ECOPETROL.COM.CO
#
# [13748 rows x 10 columns]

# %% [markdown]
# Se unifica la información que hay en las columnas similares

# %%
#CIUDAD
df_P.loc[df_P['fgs_CiudadDireccion_01'].isna(), 'fgs_CiudadDireccion_01'] = df_P[df_P['fgs_CiudadDireccion_01'].isna()].ude_CiudadCliente
#DEPARTAMENTO
df_P.loc[df_P['fgs_DepartamentoDireccion_01'].isna(), 'fgs_DepartamentoDireccion_01'] = df_P[df_P['fgs_DepartamentoDireccion_01'].isna()].ude_DepartamentoCliente
#PAIS
df_P.loc[df_P['fgs_PaisDireccion_01'].isna(), 'fgs_PaisDireccion_01'] = df_P[df_P['fgs_PaisDireccion_01'].isna()].ude_PaisCliente

# %%
df_P[df_P['fgs_PaisDireccion_01'].isna()]
# Out:
# Empty DataFrame
# Columns: [fgs_IdCampana, fgs_IdGestion, fgs_IdGestionDetalle, fgs_NombreCampana, fgs_NombrePlataforma, fgs_SiglasDocumentoContacto, fgs_NumeroDocumContacto, fgs_NombreCompletoContacto, fgs_Ip, fgs_FechaInicio, fgs_FechaFin, fgs_IdTipificacionGestionDetalle, fgs_Tipificación, fgs_Nivel1, fgs_Nivel2, fgs_Nivel3, fgs_Direccion_01, fgs_CiudadDireccion_01, fgs_DepartamentoDireccion_01, fgs_PaisDireccion_01, fgs_Telefono_01, fgs_Email_01, fmf_Canal, ude_Regional, ude_CiudadCliente, ude_DepartamentoCliente, ude_PaisCliente, ude_CodUni, ude_UnidadOrganizativa, ude_CECO, ude_CentroDeCostos, ude_EmailCliente, SistemaPago, TipoTransacción, TipoComplejidad, Funcionalidad, DependenciaLínea, fdp_IdPqr, fdp_IdEstado, fdp_NombreEstado, fdp_NivelEstado, fdp_IdHistoricoPqrCreacion, fdp_IdGrupoCreacion, fdp_NombreGrupoCreacion, fdp_IdUsuarioCreacion, fdp_UsuarioCreacion, fdp_NombreUsuarioCreacion, fgs_ObservacionCreacion, fdp_FechaCreacion, CodigoGrupoRolCreacion, GrupoRolCreacion, fdp_NivelCreacion, T_Objetivo_SolicitadoRegistrado, Cumple_Objetivo_SolicitadoRegistrado, T_Objetivo_RegistradoEscalado, T_Real_RegistradoEscalado, Cumple_Objetivo_RegistradoEscalado, T_Real_EnNivel2, Cumple_Objetivo_EnNivel2, T_Real_EnNivel3, Cumple_Objetivo_EnNivel3, fdp_IdHistoricoPqrSolucion, fdp_IdGrupoSolucion, fdp_NombreGrupoSolucion, fdp_IdUsuarioSolucion, fdp_UsuarioSolucion, fdp_NombreUsuarioSolucion, fgs_ObservacionSolucion, fdp_FechaSolucion, fdp_FechaVencimientoSolucion, CodigoGrupoRolSolucion, GrupoRolSolucion, fdp_NivelSolucion, T_Objetivo_SolucionadoCerrado, T_Real_SolucionadoCerrado, Cumple_Objetivo_SolucionadoCerrado, fdp_IdHistoricoPqrCierre, fdp_IdGrupoCierre, fdp_NombreGrupoCierre, fdp_IdUsuarioCierre, fdp_UsuarioCierre, fdp_NombreUsuarioCierre, fgs_ObservacionCierre, fdp_FechaCierre, fdp_FechaVencimientoCierre, CodigoGrupoRolCierre, GrupoRolCierre, fdp_NivelCierre, fdp_IdHistoricoPqrGestionActual, fdp_IdGrupoGestionActual, fdp_NombreGrupoGestionActual, fdp_IdUsuarioGestionActual, fdp_UsuarioGestionActual, fdp_NombreUsuarioGestionActual, fgs_ObservacionGestionActual, fdp_FechaGestionActual, fdp_FechaVencimientoGestionActual, CodigoGrupoRolGestionActual, GrupoRolGestionActual, fdp_FechaVencimientoTotal, ...]
# Index: []
#
# [0 rows x 101 columns]

# %% [markdown]
# **Se eliminan columnas de tipo texto con información redundante y con mayor porcentaje de valores faltantes:**

# %%
Col_Redunt = {'ude_CiudadCliente', 'ude_DepartamentoCliente','ude_PaisCliente','ude_EmailCliente'}
df_Ptext = Eliminar_columnas(df_Ptext, list(Col_Redunt))
# Out:
# Cantidad de columnas iniciales :  101
# Cantidad despues de eliminar :  97

# %% [markdown]
# **Columnas relevantes**

# %% [markdown]
#  * Se selecciones las columnas que en primera instancia parezcan relevantes. Se empieza por eliminar las columnas que representen el id de algun apartado que ya se tenga, por ejemplo: se borraria la columna idCampaña ya que se cuenta con la columna NombreCampaña

# %%
#TOTAL DE COLUMNAS DE TEXTO
df_Ptext.columns
# Out:
# Index(['fgs_IdCampana', 'fgs_IdGestion', 'fgs_IdGestionDetalle',
#        'fgs_NombreCampana', 'fgs_NombrePlataforma',
#        'fgs_SiglasDocumentoContacto', 'fgs_NumeroDocumContacto',
#        'fgs_NombreCompletoContacto', 'fgs_Ip', 'fgs_FechaInicio',
#        'fgs_FechaFin', 'fgs_IdTipificacionGestionDetalle', 'fgs_Tipificación',
#        'fgs_Nivel1', 'fgs_Nivel2', 'fgs_Nivel3', 'fgs_Direccion_01',
#        'fgs_CiudadDireccion_01', 'fgs_DepartamentoDireccion_01',
#        'fgs_PaisDireccion_01', 'fgs_Telefono_01', 'fgs_Email_01', 'fmf_Canal',
#        'ude_Regional', 'ude_CodUni', 'ude_UnidadOrganizativa', 'ude_CECO',
#        'ude_CentroDeCostos', 'SistemaPago', 'TipoTransacción',
#        'TipoComplejidad', 'Funcionalidad', 'DependenciaLínea', 'fdp_IdPqr',
#        'fdp_IdEstado', 'fdp_NombreEstado', 'fdp_NivelEstado',
#        'fdp_IdHistoricoPqrCreacion', 'fdp_IdGrupoCreacion',
#        'fdp_NombreGrupoCreacion', 'fdp_IdUsuarioCreacion',
#        'fdp_UsuarioCreacion', 'fdp_NombreUsuarioCreacion',
#        'fgs_ObservacionCreacion', 'fdp_FechaCreacion',
#        'CodigoGrupoRolCreacion', 'GrupoRolCreacion', 'fdp_NivelCreacion',
#        'T_Objetivo_SolicitadoRegistrado',
#        'Cumple_Objetivo_SolicitadoRegistrado', 'T_Objetivo_RegistradoEscalado',
#        'T_Real_RegistradoEscalado', 'Cumple_Objetivo_RegistradoEscalado',
#        'T_Real_EnNivel2', 'Cumple_Objetivo_EnNivel2', 'T_Real_EnNivel3',
#        'Cumple_Objetivo_EnNivel3', 'fdp_IdHistoricoPqrSolucion',
#        'fdp_IdGrupoSolucion', 'fdp_NombreGrupoSolucion',
#        'fdp_IdUsuarioSolucion', 'fdp_UsuarioSolucion',
#        'fdp_NombreUsuarioSolucion', 'fgs_ObservacionSolucion',
#        'fdp_FechaSolucion', 'fdp_FechaVencimientoSolucion',
#        'CodigoGrupoRolSolucion', 'GrupoRolSolucion', 'fdp_NivelSolucion',
#        'T_Objetivo_SolucionadoCerrado', 'T_Real_SolucionadoCerrado',
#        'Cumple_Objetivo_SolucionadoCerrado', 'fdp_IdHistoricoPqrCierre',
#        'fdp_IdGrupoCierre', 'fdp_NombreGrupoCierre', 'fdp_IdUsuarioCierre',
#        'fdp_UsuarioCierre', 'fdp_NombreUsuarioCierre', 'fgs_ObservacionCierre',
#        'fdp_FechaCierre', 'fdp_FechaVencimientoCierre', 'CodigoGrupoRolCierre',
#        'GrupoRolCierre', 'fdp_NivelCierre', 'fdp_IdHistoricoPqrGestionActual',
#        'fdp_IdGrupoGestionActual', 'fdp_NombreGrupoGestionActual',
#        'fdp_IdUsuarioGestionActual', 'fdp_UsuarioGestionActual',
#        'fdp_NombreUsuarioGestionActual', 'fgs_ObservacionGestionActual',
#        'fdp_FechaGestionActual', 'fdp_FechaVencimientoGestionActual',
#        'CodigoGrupoRolGestionActual', 'GrupoRolGestionActual',
#        'fdp_FechaVencimientoTotal', 'NoReprocesar'],
#       dtype='object')

# %%
#LISTADO DE COLUMNAS RELEVANTES SELECCIONADAS
col_rel_text = {'fgs_IdGestion','fgs_NombreCampana',
       'fgs_NombrePlataforma', 'fgs_SiglasDocumentoContacto',
       'fgs_NumeroDocumContacto', 'fgs_NombreCompletoContacto',
       'fgs_Tipificación', 'fgs_Nivel1',
       'fgs_Nivel2', 'fgs_Nivel3', 'fgs_Direccion_01',
       'fgs_CiudadDireccion_01', 'fgs_DepartamentoDireccion_01',
       'fgs_PaisDireccion_01', 'fgs_Telefono_01', 'fgs_Email_01', 'fmf_Canal',
       'ude_Regional', 'ude_CiudadCliente', 'ude_DepartamentoCliente',
       'ude_PaisCliente', 'ude_EmailCliente', 'SistemaPago', 'TipoTransacción',
       'TipoComplejidad', 'Funcionalidad', 'DependenciaLínea',
       'fdp_NombreEstado',
       'fdp_NombreGrupoCreacion', 'fdp_NombreUsuarioCreacion',
       'fgs_ObservacionCreacion', 'GrupoRolCreacion',
       'fdp_NivelCreacion', 'T_Objetivo_SolicitadoRegistrado',
       'Cumple_Objetivo_SolicitadoRegistrado', 'T_Objetivo_RegistradoEscalado',
       'Cumple_Objetivo_RegistradoEscalado', 'Cumple_Objetivo_EnNivel2',
       'Cumple_Objetivo_EnNivel3', 'fdp_NombreGrupoSolucion','fdp_NombreUsuarioSolucion',
       'fgs_ObservacionSolucion', 'GrupoRolSolucion',
       'T_Objetivo_SolucionadoCerrado', 'Cumple_Objetivo_SolucionadoCerrado',
       'fgs_ObservacionCierre', 'fdp_NombreUsuarioGestionActual','NoReprocesar'} - Col_Redunt

# %% [markdown]
# ### **Columnas tipo fecha**

# %%
df_Pfecha = df_P.select_dtypes(include = ['<M8[ns]'])
df_Pfecha.head(20)
# Out:
#            fgs_FechaInicio            fgs_FechaFin       fdp_FechaCreacion  \
# 0  2021-02-01 06:40:30.150 2021-02-01 06:47:23.443 2021-02-01 06:47:23.443
# 1  2021-02-01 06:55:42.110 2021-02-01 07:01:31.857 2021-02-01 07:01:31.857
# 2  2021-02-01 07:03:59.197 2021-02-01 07:09:37.667 2021-02-01 07:09:37.667
# 3  2021-02-01 07:04:56.607 2021-02-01 07:19:12.327 2021-02-01 07:19:12.327
# 4  2021-02-01 07:11:56.000 2021-02-01 07:23:02.490 2021-02-01 07:23:02.490
# 5  2021-02-01 07:19:09.377 2021-02-01 07:23:09.490 2021-02-01 07:23:08.427
# 6  2021-02-01 07:23:18.927 2021-02-01 07:37:47.393 2021-02-01 07:37:47.393
# 7  2021-02-01 07:33:50.860 2021-02-01 08:06:45.797 2021-02-01 08:06:45.797
# 8  2021-02-01 08:06:17.970 2021-02-01 08:12:30.983 2021-02-01 08:12:30.983
# 9  2021-02-01 08:06:22.970 2021-02-01 08:13:24.597 2021-02-01 08:13:24.597
# 10 2021-02-01 08:11:06.237 2021-02-01 08:16:42.440 2021-02-01 08:16:42.440
# 11 2021-02-01 08:18:46.133 2021-02-01 08:24:12.237 2021-02-01 08:24:12.237
# 12 2021-02-01 08:18:52.680 2021-02-01 08:36:27.057 2021-02-01 08:36:27.057
# 13 2021-02-01 08:20:18.573 2021-02-01 08:45:10.150 2021-02-01 08:45:10.150
# 14 2021-02-01 08:28:26.663 2021-02-01 08:34:59.777 2021-02-01 08:34:59.777
# 15 2021-02-01 08:29:04.350 2021-02-01 08:37:29.217 2021-02-01 08:37:29.217
# 16 2021-02-01 08:37:35.323 2021-02-01 08:38:28.607 2021-02-01 08:38:28.607
# 17 2021-02-01 08:41:25.180 2021-02-01 08:44:42.697 2021-02-01 08:44:42.697
# 18 2021-02-01 08:45:13.040 2021-02-01 08:57:22.560 2021-02-01 08:57:22.560
# 19 2021-02-01 08:48:32.947 2021-02-01 09:06:43.880 2021-02-01 09:06:43.880
#
#          fdp_FechaSolucion fdp_FechaVencimientoSolucion  \
# 0  2021-02-01 06:47:23.443          2020-02-25 16:30:00
# 1  2021-02-01 07:01:31.857          2020-02-25 16:30:00
# 2  2021-02-01 07:09:37.667          2020-02-25 16:30:00
# 3  2021-02-01 07:19:12.327          2020-02-25 16:30:00
# 4  2021-02-01 07:23:02.490          2020-02-25 16:30:00
# 5  2021-02-02 15:55:07.317          2021-03-08 07:30:00
# 6  2021-02-01 07:37:47.393          2020-02-25 16:30:00
# 7  2021-02-01 08:06:45.797          2020-02-25 16:30:00
# 8  2021-02-01 08:12:30.983          2020-02-25 16:30:00
# 9  2021-02-01 08:13:24.597          2020-02-25 16:30:00
# 10 2021-02-01 08:16:42.440          2020-02-25 16:30:00
# 11 2021-02-01 08:24:12.237          2020-02-25 16:30:00
# 12 2021-02-01 08:36:27.057          2020-02-25 16:30:00
# 13 2021-02-01 08:45:10.150          2020-02-25 16:30:00
# 14 2021-02-01 08:34:59.777          2020-02-25 16:30:00
# 15 2021-02-01 08:37:29.217          2020-02-25 16:30:00
# 16 2021-02-01 08:38:28.607          2020-02-25 16:30:00
# 17 2021-02-01 08:44:42.697          2020-02-25 16:30:00
# 18 2021-02-01 08:57:22.560          2020-02-25 16:30:00
# 19 2021-02-01 09:06:43.880          2020-02-25 16:30:00
#
#            fdp_FechaCierre fdp_FechaVencimientoCierre  fdp_FechaGestionActual  \
# 0  2021-02-01 06:47:23.443        2020-02-25 16:30:00 2021-02-01 06:47:23.443
# 1  2021-02-01 07:01:31.857        2020-02-25 16:30:00 2021-02-01 07:01:31.857
# 2  2021-02-01 07:09:37.667        2020-02-25 16:30:00 2021-02-01 07:09:37.667
# 3  2021-02-01 07:19:12.327        2020-02-25 16:30:00 2021-02-01 07:19:12.327
# 4  2021-02-01 07:23:02.490        2020-02-25 16:30:00 2021-02-01 07:23:02.490
# 5  2021-02-02 15:55:07.317        2021-03-08 07:30:00 2021-02-02 15:55:07.317
# 6  2021-02-01 07:37:47.393        2020-02-25 16:30:00 2021-02-01 07:37:47.393
# 7  2021-02-01 08:06:45.797        2020-02-25 16:30:00 2021-02-01 08:06:45.797
# 8  2021-02-01 08:12:30.983        2020-02-25 16:30:00 2021-02-01 08:12:30.983
# 9  2021-02-01 08:13:24.597        2020-02-25 16:30:00 2021-02-01 08:13:24.597
# 10 2021-02-01 08:16:42.440        2020-02-25 16:30:00 2021-02-01 08:16:42.440
# 11 2021-02-01 08:24:12.237        2020-02-25 16:30:00 2021-02-01 08:24:12.237
# 12 2021-02-01 08:36:27.057        2020-02-25 16:30:00 2021-02-01 08:36:27.057
# 13 2021-02-01 08:45:10.150        2020-02-25 16:30:00 2021-02-01 08:45:10.150
# 14 2021-02-01 08:34:59.777        2020-02-25 16:30:00 2021-02-01 08:34:59.777
# 15 2021-02-01 08:37:29.217        2020-02-25 16:30:00 2021-02-01 08:37:29.217
# 16 2021-02-01 08:38:28.607        2020-02-25 16:30:00 2021-02-01 08:38:28.607
# 17 2021-02-01 08:44:42.697        2020-02-25 16:30:00 2021-02-01 08:44:42.697
# 18 2021-02-01 08:57:22.560        2020-02-25 16:30:00 2021-02-01 08:57:22.560
# 19 2021-02-01 09:06:43.880        2020-02-25 16:30:00 2021-02-01 09:06:43.880
#
#    fdp_FechaVencimientoGestionActual fdp_FechaVencimientoTotal
# 0                2020-02-25 16:30:00   2021-02-01 09:45:00.000
# 1                2020-02-25 16:30:00   2021-02-01 09:45:00.000
# 2                2020-02-25 16:30:00   2021-02-01 09:45:00.000
# 3                2020-02-25 16:30:00   2021-02-01 09:45:00.000
# 4                2020-02-25 16:30:00   2021-02-01 09:45:00.000
# 5                2021-03-08 07:30:00   2021-03-08 07:30:00.000
# 6                2020-02-25 16:30:00   2021-02-01 09:52:47.393
# 7                2020-02-25 16:30:00   2021-02-01 10:21:45.797
# 8                2020-02-25 16:30:00   2021-02-01 10:27:30.983
# 9                2020-02-25 16:30:00   2021-02-01 10:28:24.597
# 10               2020-02-25 16:30:00   2021-02-01 10:31:42.440
# 11               2020-02-25 16:30:00   2021-02-01 10:39:12.237
# 12               2020-02-25 16:30:00   2021-02-01 10:51:27.057
# 13               2020-02-25 16:30:00   2021-02-01 11:00:10.150
# 14               2020-02-25 16:30:00   2021-02-01 10:49:59.777
# 15               2020-02-25 16:30:00   2021-02-01 10:52:29.217
# 16               2020-02-25 16:30:00   2021-02-01 10:53:28.607
# 17               2020-02-25 16:30:00   2021-02-01 10:59:42.697
# 18               2020-02-25 16:30:00   2021-02-01 11:12:22.560
# 19               2020-02-25 16:30:00   2021-02-01 11:21:43.880

# %%
print ('Total de columnas tipo fecha : ', df_Pfecha.shape[1])
df_Faltantes_fecha = Valores_Faltantes(df_Pfecha, 10)
# Out:
# Total de columnas tipo fecha :  10
# Total columnas con valores faltantes : 3
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 0

# %%
df_Faltantes_fecha
# Out:
#                      Nombre_Columnas  Total_Vacios  Porcentaje_vacio  \
# 4       fdp_FechaVencimientoSolucion            11              0.08
# 6         fdp_FechaVencimientoCierre            11              0.08
# 8  fdp_FechaVencimientoGestionActual            11              0.08
#
#   Columna_vacia
# 4            NO
# 6            NO
# 8            NO

# %% [markdown]
# **Columnas relevantes**

# %%
col_rel_fecha = {'fgs_FechaInicio','fgs_FechaFin'}

# %% [markdown]
# ## **Selección de columnas relevantes en primera instancia**

# %%
print('Total Columnas antes de la selección : ' ,df_P.shape[1])
col_relevantes = list(col_rel_fecha) + list(col_rel_text)
df_P_relevante = df_P[list(col_relevantes)]
print('Total Columnas después de la selección : ',df_P_relevante.shape[1])
# Out:
# Total Columnas antes de la selección :  101
# Total Columnas después de la selección :  46

# %% [markdown]
# ### **Revisión de variables categoricas**

# %%
columnas_categoricas = df_P_relevante.select_dtypes(include = ['O']).columns
total_categorias = []

# %%
columnas_categoricas
# Out:
# Index(['fgs_FechaInicio', 'fgs_FechaFin', 'Cumple_Objetivo_RegistradoEscalado',
#        'fdp_NombreGrupoSolucion', 'TipoComplejidad', 'fgs_ObservacionCierre',
#        'fgs_CiudadDireccion_01', 'fgs_SiglasDocumentoContacto',
#        'fgs_Direccion_01', 'Cumple_Objetivo_SolucionadoCerrado',
#        'NoReprocesar', 'fgs_ObservacionCreacion', 'fgs_Telefono_01',
#        'fgs_Nivel1', 'fgs_Email_01', 'DependenciaLínea',
#        'T_Objetivo_SolicitadoRegistrado', 'fmf_Canal', 'TipoTransacción',
#        'fgs_Nivel2', 'GrupoRolSolucion', 'Cumple_Objetivo_EnNivel3',
#        'Funcionalidad', 'fdp_NombreUsuarioCreacion', 'fdp_NombreEstado',
#        'T_Objetivo_SolucionadoCerrado', 'GrupoRolCreacion',
#        'fgs_NumeroDocumContacto', 'SistemaPago', 'Cumple_Objetivo_EnNivel2',
#        'fdp_NombreUsuarioSolucion', 'fgs_DepartamentoDireccion_01',
#        'fdp_NombreUsuarioGestionActual', 'fgs_NombreCompletoContacto',
#        'fgs_Tipificación', 'fgs_PaisDireccion_01', 'fdp_NombreGrupoCreacion',
#        'T_Objetivo_RegistradoEscalado', 'ude_Regional',
#        'fgs_ObservacionSolucion', 'fgs_NombreCampana', 'fgs_Nivel3',
#        'fdp_NivelCreacion', 'fgs_IdGestion',
#        'Cumple_Objetivo_SolicitadoRegistrado', 'fgs_NombrePlataforma'],
#       dtype='object')

# %%
for i in columnas_categoricas:
    categorias = len(list(df_P_relevante[i].value_counts()))
    total_categorias.append(categorias)

# %%
#tabla nombre de columna y cantidad de categorias (o valores distintos)
df_columnasCat = pd.DataFrame({'Nombre_columna': columnas_categoricas , '# categorias dintintas':total_categorias})
df_columnasCat
# Out:
#                           Nombre_columna  # categorias dintintas
# 0                        fgs_FechaInicio                   13727
# 1                           fgs_FechaFin                   13737
# 2     Cumple_Objetivo_RegistradoEscalado                       3
# 3                fdp_NombreGrupoSolucion                       7
# 4                        TipoComplejidad                       1
# 5                  fgs_ObservacionCierre                    9541
# 6                 fgs_CiudadDireccion_01                     186
# 7            fgs_SiglasDocumentoContacto                       5
# 8                       fgs_Direccion_01                    4669
# 9     Cumple_Objetivo_SolucionadoCerrado                       3
# 10                          NoReprocesar                       2
# 11               fgs_ObservacionCreacion                   11953
# 12                       fgs_Telefono_01                    4392
# 13                            fgs_Nivel1                       1
# 14                          fgs_Email_01                    4642
# 15                      DependenciaLínea                       1
# 16       T_Objetivo_SolicitadoRegistrado                       1
# 17                             fmf_Canal                       5
# 18                       TipoTransacción                       1
# 19                            fgs_Nivel2                       3
# 20                      GrupoRolSolucion                       4
# 21              Cumple_Objetivo_EnNivel3                       1
# 22                         Funcionalidad                       1
# 23             fdp_NombreUsuarioCreacion                      60
# 24                      fdp_NombreEstado                       4
# 25         T_Objetivo_SolucionadoCerrado                       1
# 26                      GrupoRolCreacion                       3
# 27               fgs_NumeroDocumContacto                    4453
# 28                           SistemaPago                       3
# 29              Cumple_Objetivo_EnNivel2                       3
# 30             fdp_NombreUsuarioSolucion                      67
# 31          fgs_DepartamentoDireccion_01                      28
# 32        fdp_NombreUsuarioGestionActual                      66
# 33            fgs_NombreCompletoContacto                    4463
# 34                      fgs_Tipificación                       2
# 35                  fgs_PaisDireccion_01                       2
# 36               fdp_NombreGrupoCreacion                       1
# 37         T_Objetivo_RegistradoEscalado                       1
# 38                          ude_Regional                       6
# 39               fgs_ObservacionSolucion                   11654
# 40                     fgs_NombreCampana                       1
# 41                            fgs_Nivel3                      20
# 42                     fdp_NivelCreacion                       1
# 43                         fgs_IdGestion                   13748
# 44  Cumple_Objetivo_SolicitadoRegistrado                       3
# 45                  fgs_NombrePlataforma                       1

# %% [markdown]
# * Se identifican columnas que solo poseen una categoria (es decir un solo tipo de valor diferente), se procede a eliminarlas puesto que no aportan información al análisis

# %%
df_P_relevante = Eliminar_columnas(df_P_relevante, list(df_columnasCat[df_columnasCat['# categorias dintintas'] == 1].Nombre_columna))
# Out:
# Cantidad de columnas iniciales :  46
# Cantidad despues de eliminar :  33

# %% [markdown]
# ## **Reemplazo de valores faltantes**

# %% [markdown]
# * Despues de haber hecho todo el proceso de elimar las columnas vacias, las que tenian gran porcentaje de vacios, las que poseian informacion redundante y las que no posean información que aportara al análisis, se revisan los valores faltantes en esta nueva base

# %%
 Valores_Faltantes(df_P_relevante, 10)
# Out:
# Total columnas con valores faltantes : 7
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 0
#                 Nombre_Columnas  Total_Vacios  Porcentaje_vacio Columna_vacia
# 3       fdp_NombreGrupoSolucion            29              0.21            NO
# 4         fgs_ObservacionCierre            30              0.22            NO
# 6   fgs_SiglasDocumentoContacto            14              0.10            NO
# 15             GrupoRolSolucion            29              0.21            NO
# 22    fdp_NombreUsuarioSolucion            29              0.21            NO
# 28                 ude_Regional           868              6.31            NO
# 29      fgs_ObservacionSolucion            29              0.21            NO

# %% [markdown]
# La columna de regional tiene valores faltantes, sin embargo la de departamento y ciudad si estan completas

# %%
#Con la información que se tiene se crea una tabla con Regionales,departamentos y ciudades
df_PaisRegCiu = df_P_relevante[['ude_Regional', 'fgs_CiudadDireccion_01', 'fgs_DepartamentoDireccion_01']].drop_duplicates().dropna()
df_PaisRegCiu.rename(columns = {'fgs_DepartamentoDireccion_01':'Departamento','ude_Regional':'Regional','fgs_CiudadDireccion_01':'Ciudad'}, inplace = True)

# %%
df_PaisRegCiu.drop_duplicates('Ciudad', keep = 'first', inplace = True)
df_PaisRegCiu.drop_duplicates('Departamento', keep = 'first', inplace = True)
df_PaisRegCiu
# Out:
#                Regional            Ciudad     Departamento
# 0        CENTRO ORIENTE      BOGOTA, D.C.           BOGOTA
# 1                 NORTE       SANTA MARTA        MAGDALENA
# 2        CENTRO ORIENTE            CUCUTA  N. DE SANTANDER
# 9                   SUR             NEIVA            HUILA
# 10       CENTRO ORIENTE            PARAMO        SANTANDER
# 15            OCCIDENTE          MARSELLA        RISARALDA
# 21                NORTE          MONTERIA          CORDOBA
# 26            OCCIDENTE      BARRANQUILLA        ATLANTICO
# 38    LLANOS ORIENTALES     VILLAVICENCIO             META
# 49            OCCIDENTE         MANIZALES           CALDAS
# 58       CENTRO ORIENTE  CARMEN DE CARUPA     CUNDINAMARCA
# 61                  SUR             ORITO         PUTUMAYO
# 67            OCCIDENTE          MEDELLIN        ANTIOQUIA
# 69                NORTE         CARTAGENA          BOLIVAR
# 81            OCCIDENTE              CALI  VALLE DEL CAUCA
# 84      MAGDALENA MEDIO            FRESNO           TOLIMA
# 95                NORTE          EL COPEY            CESAR
# 137               NORTE         SINCELEJO            SUCRE
# 304     MAGDALENA MEDIO             YOPAL         CASANARE
# 313      CENTRO ORIENTE         MONIQUIRA           BOYACA
# 462           OCCIDENTE           ARMENIA          QUINDIO
# 1336  LLANOS ORIENTALES          SARAVENA           ARAUCA
# 1512          OCCIDENTE             PASTO           NARIÑO
# 1883  LLANOS ORIENTALES         FLORENCIA          CAQUETA
# 4148    MAGDALENA MEDIO          ALMAGUER            CAUCA

# %% [markdown]
# Se cruza la tabla creada de regionales-ciudades con la base de trabajo, esto con el fin de sustituir los valores faltantes usando como llave la información de la ciudad

# %%
df_reemplazo = df_P_relevante.merge( df_PaisRegCiu, how = 'left', left_on = 'fgs_CiudadDireccion_01', right_on = 'Ciudad')
#se reemplazan regionales
df_reemplazo.loc[df_reemplazo['ude_Regional'].isna(), 'ude_Regional'] = df_reemplazo['Regional']
df_reemplazo.loc[df_reemplazo['ude_Regional']!= df_reemplazo['Regional'], 'ude_Regional'] = df_reemplazo['Regional']
#se reemplazan departamentos ya que se evidencion que algunas ciudades tienian asociados mas de un departamento
df_reemplazo.loc[(df_reemplazo['fgs_DepartamentoDireccion_01']!=df_reemplazo['Departamento']) & (~df_reemplazo['Departamento'].isna()), 'fgs_DepartamentoDireccion_01'] = df_reemplazo['Departamento']

# %%
df_reemplazo.shape
# Out:
# (13748, 36)

# %%
Valores_Faltantes(df_reemplazo[list(df_P_relevante.columns)], 10)
# Out:
# Total columnas con valores faltantes : 7
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 1
#                 Nombre_Columnas  Total_Vacios  Porcentaje_vacio Columna_vacia
# 3       fdp_NombreGrupoSolucion            29              0.21            NO
# 4         fgs_ObservacionCierre            30              0.22            NO
# 6   fgs_SiglasDocumentoContacto            14              0.10            NO
# 15             GrupoRolSolucion            29              0.21            NO
# 22    fdp_NombreUsuarioSolucion            29              0.21            NO
# 28                 ude_Regional          7317             53.22            NO
# 29      fgs_ObservacionSolucion            29              0.21            NO

# %% [markdown]
# **Regional**

# %% [markdown]
# Se revisan los departamentos que no tienen asignado regional:

# %%
df_reemplazo[df_reemplazo['ude_Regional'].isna()].fgs_DepartamentoDireccion_01.unique()
# Out:
# array(['SANTANDER', 'N. DE SANTANDER', 'MAGDALENA', 'ANTIOQUIA',
#        'CUNDINAMARCA', 'VALLE DEL CAUCA', 'ATLANTICO', 'BOLIVAR', 'CESAR',
#        'RISARALDA', 'META', 'BOYACA', 'TOLIMA', 'HUILA', 'CASANARE',
#        'SUCRE', 'ARAUCA', 'CALDAS', 'SAN ANDRES', 'PUTUMAYO', 'NARIÑO',
#        'CORDOBA', 'CHOCO', 'CAUCA', 'QUINDIO', 'VICHADA'], dtype=object)

# %%
df_reemplazo = df_reemplazo[list(df_P_relevante.columns)].merge(df_PaisRegCiu, how = 'left', left_on = 'fgs_DepartamentoDireccion_01', right_on = 'Departamento')
#se reemplazan regionales
df_reemplazo.loc[df_reemplazo['ude_Regional'].isna(), 'ude_Regional'] = df_reemplazo['Regional']
df_reemplazo.loc[df_reemplazo['ude_Regional']!= df_reemplazo['Regional'], 'ude_Regional'] = df_reemplazo['Regional']
Valores_Faltantes(df_reemplazo[list(df_P_relevante.columns)], 10)
# Out:
# Total columnas con valores faltantes : 7
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 0
#                 Nombre_Columnas  Total_Vacios  Porcentaje_vacio Columna_vacia
# 3       fdp_NombreGrupoSolucion            29              0.21            NO
# 4         fgs_ObservacionCierre            30              0.22            NO
# 6   fgs_SiglasDocumentoContacto            14              0.10            NO
# 15             GrupoRolSolucion            29              0.21            NO
# 22    fdp_NombreUsuarioSolucion            29              0.21            NO
# 28                 ude_Regional            16              0.12            NO
# 29      fgs_ObservacionSolucion            29              0.21            NO

# %%
df_reemplazo.shape
# Out:
# (13748, 36)

# %%
df_reemplazo[df_reemplazo['ude_Regional'].isna()].fgs_DepartamentoDireccion_01.unique()
# Out:
# array(['SAN ANDRES', 'CHOCO', 'VICHADA'], dtype=object)

# %%
df_reemplazo.shape
# Out:
# (13748, 36)

# %%
df_reemplazo['ude_Regional'].unique()
# Out:
# array(['CENTRO ORIENTE', 'NORTE', 'SUR', 'OCCIDENTE', 'LLANOS ORIENTALES',
#        'MAGDALENA MEDIO', nan], dtype=object)

# %% [markdown]
# Siguiendo con la notación de la base, se crea una lista con las regionales para los departamentos faltantes

# %%
departamentos = ['SAN ANDRES', 'CHOCO', 'VICHADA']
regionales = ['NORTE', 'OCCIDENTE', 'LLANOS ORIENTALES']

# %%
#df_reemplazo.loc[(df_reemplazo['ude_Regional'].isna()), 'ude_Regional' ] = df_reemplazo['fgs_DepartamentoDireccion_01']
df_reemplazo['ude_Regional'].replace(zip(departamentos,regionales), inplace = True)
Valores_Faltantes(df_reemplazo[list(df_P_relevante.columns)], 10)
# Out:
# Total columnas con valores faltantes : 7
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 0
#                 Nombre_Columnas  Total_Vacios  Porcentaje_vacio Columna_vacia
# 3       fdp_NombreGrupoSolucion            29              0.21            NO
# 4         fgs_ObservacionCierre            30              0.22            NO
# 6   fgs_SiglasDocumentoContacto            14              0.10            NO
# 15             GrupoRolSolucion            29              0.21            NO
# 22    fdp_NombreUsuarioSolucion            29              0.21            NO
# 28                 ude_Regional            16              0.12            NO
# 29      fgs_ObservacionSolucion            29              0.21            NO

# %%
df_reemplazo.shape
# Out:
# (13748, 36)

# %% [markdown]
# *Tipo de doc

# %%
df_documentos = df_reemplazo[['fgs_NumeroDocumContacto','fgs_SiglasDocumentoContacto']].drop_duplicates('fgs_NumeroDocumContacto',keep = 'first').dropna().rename(columns = {'fgs_SiglasDocumentoContacto':'Tipo doc'})
df_reemplazo = df_reemplazo.merge( df_documentos, how = 'left', on = 'fgs_NumeroDocumContacto')
df_reemplazo.loc[(df_reemplazo['fgs_SiglasDocumentoContacto'].isna()), 'fgs_SiglasDocumentoContacto' ] = df_reemplazo['Tipo doc']
Valores_Faltantes(df_reemplazo[list(df_P_relevante.columns)], 10)
# Out:
# Total columnas con valores faltantes : 7
# Total columnas vacias : 0
# Total columnas no vacias con mas del 10% de valores faltantes : 0
#                 Nombre_Columnas  Total_Vacios  Porcentaje_vacio Columna_vacia
# 3       fdp_NombreGrupoSolucion            29              0.21            NO
# 4         fgs_ObservacionCierre            30              0.22            NO
# 6   fgs_SiglasDocumentoContacto             4              0.03            NO
# 15             GrupoRolSolucion            29              0.21            NO
# 22    fdp_NombreUsuarioSolucion            29              0.21            NO
# 28                 ude_Regional            16              0.12            NO
# 29      fgs_ObservacionSolucion            29              0.21            NO

# %%
df_reemplazo.shape
# Out:
# (13748, 37)

# %%
df_reemplazo['fgs_SiglasDocumentoContacto'].unique()
# Out:
# array(['CC', 'TI', 'RC', 'CE', 'NIT', nan], dtype=object)

# %%
df_reemplazo[df_reemplazo['fgs_SiglasDocumentoContacto'].isna()]
# Out:
#                fgs_FechaInicio             fgs_FechaFin  \
# 6937   2020-09-23 09:12:48.000  2020-09-23 10:06:00.000
# 10142  2020-11-17 06:37:07.000  2020-11-27 08:33:24.000
# 10158  2020-11-30 16:25:44.000  2020-11-30 18:06:01.000
# 13554  2020-08-21 07:08:19.000  2020-09-10 17:59:27.000
#
#       Cumple_Objetivo_RegistradoEscalado  \
# 6937                              Cumple
# 10142                             Cumple
# 10158                             Cumple
# 13554                          No Cumple
#
#                         fdp_NombreGrupoSolucion fgs_ObservacionCierre  \
# 6937                    Equipo Plan Educacional     Sin Observaciones
# 10142           Profesional Educación Inclusiva     Sin Observaciones
# 10158           Profesional Educación Inclusiva     Sin Observaciones
# 13554  Profesional Transferencia de Información     Sin Observaciones
#
#       fgs_CiudadDireccion_01 fgs_SiglasDocumentoContacto  \
# 6937         BARRANCABERMEJA                         NaN
# 10142            BUCARAMANGA                         NaN
# 10158            SANTA MARTA                         NaN
# 13554        BARRANCABERMEJA                         NaN
#
#                                         fgs_Direccion_01  \
# 6937                                         CL 58 37 57
# 10142  CR 8 61 53 REAL DE MINAS METROPOLIS I AP 802 TO 4
# 10158                         CL 25 - 32 50 AP 1304 BL B
# 13554                                           CR 50 44
#
#       Cumple_Objetivo_SolucionadoCerrado NoReprocesar  ...  \
# 6937                              Cumple         True  ...
# 10142                             Cumple         True  ...
# 10158                             Cumple         True  ...
# 13554                             Cumple         True  ...
#
#       fgs_PaisDireccion_01    ude_Regional  \
# 6937              COLOMBIA  CENTRO ORIENTE
# 10142             COLOMBIA  CENTRO ORIENTE
# 10158             COLOMBIA           NORTE
# 13554             COLOMBIA  CENTRO ORIENTE
#
#                                  fgs_ObservacionSolucion  \
# 6937   Buen día, En atención a su solicitud,  nos per...
# 10142  Le informamos que recibimos el reintegro de: S...
# 10158                    Se adjunta la gestión del caso
# 13554      se procede a dar ciere según correo adjunto.
#
#                                               fgs_Nivel3 fgs_IdGestion  \
# 6937   Inscripción solicitud becas Comité de Educació...      13340108
# 10142           Anticipo Pensionados Educación Inclusiva      13577621
# 10158          Anticipo Trabajadores Educación Inclusiva      13644978
# 13554  Soporte Plataforma para Instituciones Educativ...      13191040
#
#       Cumple_Objetivo_SolicitadoRegistrado        Regional       Ciudad  \
# 6937                                Cumple  CENTRO ORIENTE       PARAMO
# 10142                               Cumple  CENTRO ORIENTE       PARAMO
# 10158                               Cumple           NORTE  SANTA MARTA
# 13554                               Cumple  CENTRO ORIENTE       PARAMO
#
#       Departamento Tipo doc
# 6937     SANTANDER      NaN
# 10142    SANTANDER      NaN
# 10158    MAGDALENA      NaN
# 13554    SANTANDER      NaN
#
# [4 rows x 37 columns]

# %% [markdown]
# La información es de personas naturales, se llena entonces esos campos vacios con la inicial de cc

# %%
df_reemplazo.loc[df_reemplazo['fgs_SiglasDocumentoContacto'].isna(), 'fgs_SiglasDocumentoContacto'] = 'CC'

# %% [markdown]
# Se guarda base reducida en primera etapa

# %%
df_reemplazo.shape
# Out:
# (13748, 37)

# %%
df_P_relevante = df_reemplazo[list(df_P_relevante.columns)]
df_P_relevante.to_csv('Base_Campaña_Personal.csv', index = False)

# %% [markdown]
# ## **Resultado de la limpieza y revisión general**

# %%
df_total_final = df_P_relevante[['fgs_Nivel3']].value_counts().to_frame(name = 'total final').reset_index()
df_total_anterior = df_General_P[['Nivel 3', 'total']].rename(columns = {'total':'total antes de revision'})
df_comparativo = pd.merge (df_total_anterior, df_total_final, how = 'left', left_on = 'Nivel 3', right_on = 'fgs_Nivel3') 

df_comparativo['Porcentaje eliminado %'] = ((df_comparativo['total antes de revision'] - df_comparativo['total final'])*100/df_comparativo['total antes de revision']).round(2) 
df_comparativo[['Nivel 3', 'total antes de revision', 'total final', 'Porcentaje eliminado %']].to_csv('reduccion_datos_BenEduc.csv', index = False)

# %%
df_comparativo[['Nivel 3', 'total antes de revision', 'total final', 'Porcentaje eliminado %']]
# Out:
#                                               Nivel 3  \
# 0   Legal / Reconocimiento Pensionados (Incluye Su...
# 1   Legal / Reconocimiento Trabajadores (Incluye B...
# 2                    Solicitud de educación inclusiva
# 3            Anticipo Pensionados Educación Inclusiva
# 4           Anticipo Trabajadores Educación Inclusiva
# 5           Anticipo Pensionados (Incluye Sustitutos)
# 6                 Anticipo Trabajadores (Incluye BXC)
# 7   Consulta Bachiller Ecopetrol (Incapacidad médi...
# 8   Consulta de información relacionadas con reemb...
# 9      Consulta especialista beneficios atención PQRS
# 10  Consulta sobre liquidación/pago préstamo para ...
# 11  Consulta Titulares Beneficio Eductivo - Desvin...
# 12  Consultas Titulares Beneficio Educativo (No In...
# 13  Solicitud / Consulta / revisión pagos colegios...
# 14  Soporte Plataforma para Instituciones Educativ...
# 15  Reintegro de dinero Pensionados Educación (Inc...
# 16  Reintegro de dinero trabajadores Educación (In...
# 17  Inscripción casos especiales comité de educaci...
# 18  Inscripción casos especiales comité educación ...
# 19  Inscripción solicitud becas Comité de Educació...
#
#     total antes de revision  total final  Porcentaje eliminado %
# 0                      2415         2415                     0.0
# 1                      4195         4195                     0.0
# 2                       414          414                     0.0
# 3                        20           20                     0.0
# 4                        15           15                     0.0
# 5                      1586         1586                     0.0
# 6                      1807         1807                     0.0
# 7                         3            3                     0.0
# 8                        12           12                     0.0
# 9                         1            1                     0.0
# 10                       10           10                     0.0
# 11                       52           52                     0.0
# 12                     1225         1225                     0.0
# 13                       45           45                     0.0
# 14                     1121         1121                     0.0
# 15                       58           58                     0.0
# 16                      303          303                     0.0
# 17                       99           99                     0.0
# 18                       14           14                     0.0
# 19                      353          353                     0.0

# %%
print ('Total filas en la base inicial sin revisar : ', df_Registros_P.shape[0])
print ('Total filas después de limpieza general y revisión : ', df_P_relevante.shape[0])
print ('Porcentaje de columnas removidas : ', round((df_Registros_P.shape[0] - df_P_relevante.shape[0])*100/df_Registros_P.shape[0],2), '%')
# Out:
# Total filas en la base inicial sin revisar :  13748
# Total filas después de limpieza general y revisión :  13748
# Porcentaje de columnas removidas :  0.0 %

# %%
print ('Total de columnas antes : ', df_Registros_P.shape[1])
print ('Total de columnas después : ', df_P_relevante.shape[1])
print ('Porcentaje de columnas removido : ', round((df_Registros_P.shape[1]-df_P_relevante.shape[1])*100/df_Registros_P.shape[1], 2), '%')
# Out:
# Total de columnas antes :  222
# Total de columnas después :  33
# Porcentaje de columnas removido :  85.14 %

# %%
df_P_relevante[['fgs_Nivel2','fgs_Nivel3']].drop_duplicates().to_csv('niveles_seleccionados_BenEduc.csv', index = False)

# %% [markdown]
# # **EXPLORACION DE DATOS**

# %%
df_P_relevante = pd.read_csv('Base_Campaña_Personal.csv').drop_duplicates()

# %%
df_P_relevante
# Out:
#                fgs_FechaInicio             fgs_FechaFin  \
# 0      2021-02-01 06:40:30.150  2021-02-01 06:47:23.443
# 1      2021-02-01 06:55:42.110  2021-02-01 07:01:31.857
# 2      2021-02-01 07:03:59.197  2021-02-01 07:09:37.667
# 3      2021-02-01 07:04:56.607  2021-02-01 07:19:12.327
# 4      2021-02-01 07:11:56.000  2021-02-01 07:23:02.490
# ...                        ...                      ...
# 13712  2020-08-31 16:02:09.000  2020-08-31 16:06:33.000
# 13713  2020-08-31 16:06:46.000  2020-08-31 16:11:26.000
# 13714  2020-08-31 16:11:39.000  2020-08-31 16:20:04.000
# 13715  2020-08-31 16:25:15.000  2020-08-31 16:29:56.000
# 13716  2020-08-31 16:35:54.000  2020-08-31 16:47:06.000
#
#              fdp_NombreUsuarioGestionActual  \
# 0           AIDA ALEXANDRA RODRIGUEZ AMAYA
# 1            DIANA MILENA GUERRERO MELLIZO
# 2               REINALDO  HUDGSON GUERRERO
# 3                ELIANA ELIZABETH ESQUIVEL
# 4               REINALDO  HUDGSON GUERRERO
# ...                                     ...
# 13712        JENNIFERCARDOZO CARDOZO DUQUE
# 13713        JENNIFERCARDOZO CARDOZO DUQUE
# 13714        JENNIFERCARDOZO CARDOZO DUQUE
# 13715        JENNIFERCARDOZO CARDOZO DUQUE
# 13716  WILLIAM GUILLERMO FERRUCHO FERRUCHO
#
#                                  fgs_ObservacionSolucion  \
# 0      "se informa que su caso no puede ser tramitado...
# 1      Se realizó el ajuste de semestre y se encuentr...
# 2      SE INFORMA A LA PETICIONARIA QUE ESTE CASO FUE...
# 3      GESTIÓN REALIZADA:<br>Dando respuesta a la con...
# 4      SE INFORMA QUE DEBE ANEXAR CERTIFICACION DE UN...
# ...                                                  ...
# 13712      se procede a dar cierre según correo adjunto.
# 13713     se procede a dar cierre según correo adjunto.
# 13714      se procede a dar cierre según correo adjunto.
# 13715     se procede a dar cierre según correo adjunto.
# 13716  Se valida historial de solicitudes y se eviden...
#
#       fgs_SiglasDocumentoContacto                     fgs_Nivel2  \
# 0                              CC  Beneficio Educativo - Regular
# 1                              CC  Beneficio Educativo - Regular
# 2                              CC  Beneficio Educativo - Regular
# 3                              CC  Beneficio Educativo - Regular
# 4                              CC  Beneficio Educativo - Regular
# ...                           ...                            ...
# 13712                          CC  Beneficio Educativo - Regular
# 13713                          CC  Beneficio Educativo - Regular
# 13714                          CC  Beneficio Educativo - Regular
# 13715                          CC  Beneficio Educativo - Regular
# 13716                          CC  Beneficio Educativo - Regular
#
#                   fdp_NombreUsuarioSolucion    ude_Regional  \
# 0           AIDA ALEXANDRA RODRIGUEZ AMAYA   CENTRO ORIENTE
# 1            DIANA MILENA GUERRERO MELLIZO            NORTE
# 2               REINALDO  HUDGSON GUERRERO   CENTRO ORIENTE
# 3                ELIANA ELIZABETH ESQUIVEL            NORTE
# 4               REINALDO  HUDGSON GUERRERO   CENTRO ORIENTE
# ...                                     ...             ...
# 13712        JENNIFERCARDOZO CARDOZO DUQUE   CENTRO ORIENTE
# 13713        JENNIFERCARDOZO CARDOZO DUQUE   CENTRO ORIENTE
# 13714        JENNIFERCARDOZO CARDOZO DUQUE        OCCIDENTE
# 13715        JENNIFERCARDOZO CARDOZO DUQUE   CENTRO ORIENTE
# 13716  WILLIAM GUILLERMO FERRUCHO FERRUCHO              SUR
#
#                               GrupoRolSolucion  \
# 0      Asesor de Servicio Front Contact Center
# 1            Asesor de Servicio Contact Center
# 2           Asesor de Servicio Front Ecopetrol
# 3            Asesor de Servicio Contact Center
# 4           Asesor de Servicio Front Ecopetrol
# ...                                        ...
# 13712            Asesor solucionador Ecopetrol
# 13713            Asesor solucionador Ecopetrol
# 13714            Asesor solucionador Ecopetrol
# 13715            Asesor solucionador Ecopetrol
# 13716        Asesor de Servicio Contact Center
#
#       Cumple_Objetivo_SolucionadoCerrado  ...        SistemaPago  \
# 0                                 Cumple  ...  Puesto de Trabajo
# 1                                 Cumple  ...      Transacciones
# 2                                 Cumple  ...          No Aplica
# 3                                 Cumple  ...      Transacciones
# 4                                 Cumple  ...          No Aplica
# ...                                  ...  ...                ...
# 13712                             Cumple  ...      Transacciones
# 13713                             Cumple  ...      Transacciones
# 13714                             Cumple  ...      Transacciones
# 13715                             Cumple  ...      Transacciones
# 13716                             Cumple  ...      Transacciones
#
#       fgs_Telefono_01 Cumple_Objetivo_RegistradoEscalado  \
# 0            12572213                             Cumple
# 1          3124964423                             Cumple
# 2            75924310                             Cumple
# 3            54389035                             Cumple
# 4          3157237219                             Cumple
# ...               ...                                ...
# 13712        15202720                             Cumple
# 13713      3112452551                             Cumple
# 13714        88703560                             Cumple
# 13715        17517253                             Cumple
# 13716        88703560                             Cumple
#
#                               GrupoRolCreacion fgs_CiudadDireccion_01  \
# 0      Asesor de Servicio Front Contact Center           BOGOTA, D.C.
# 1            Asesor de Servicio Contact Center            SANTA MARTA
# 2           Asesor de Servicio Front Ecopetrol                 CUCUTA
# 3            Asesor de Servicio Contact Center            SANTA MARTA
# 4           Asesor de Servicio Front Ecopetrol           BOGOTA, D.C.
# ...                                        ...                    ...
# 13712        Asesor de Servicio Contact Center           BOGOTA, D.C.
# 13713        Asesor de Servicio Contact Center           BOGOTA, D.C.
# 13714        Asesor de Servicio Contact Center                BARANOA
# 13715        Asesor de Servicio Contact Center           BOGOTA, D.C.
# 13716        Asesor de Servicio Contact Center                  NEIVA
#
#                                    fgs_ObservacionCierre  \
# 0      "se informa que su caso no puede ser tramitado...
# 1      Se realizó el ajuste de semestre y se encuentr...
# 2      SE INFORMA A LA PETICIONARIA QUE ESTE CASO FUE...
# 3      GESTIÓN REALIZADA:<br>Dando respuesta a la con...
# 4      SE INFORMA QUE DEBE ANEXAR CERTIFICACION DE UN...
# ...                                                  ...
# 13712                                  Sin Observaciones
# 13713                                  Sin Observaciones
# 13714                                  Sin Observaciones
# 13715                                  Sin Observaciones
# 13716  Se valida historial de solicitudes y se eviden...
#
#                                  fgs_ObservacionCreacion  \
# 0      Se recibe documentación del señor Joaquin Erne...
# 1      Solicitó el ajuste de semestre y se encuentra ...
# 2      SE RECIBE SOLICITUD DE LEGALIZACION 5 SEMESTRE...
# 3      SOLICITUD DEL USUARIO: Ayer envié este mismo d...
# 4      SE RECIBE SOLICITUD DE LEGALIZACION DE LUISA F...
# ...                                                  ...
# 13712  GESTIÓN: Su caso se escaló al área encargada p...
# 13713  GESTIÓN: Su caso se escaló al área encargada p...
# 13714  GESTIÓN: Su caso se escaló al área encargada p...
# 13715  Gestión: Su caso fue escalado con las siguient...
# 13716  Funcionario solicita creación de un caso por l...
#
#        fgs_NumeroDocumContacto Cumple_Objetivo_SolicitadoRegistrado  \
# 0                     19322865                            No Cumple
# 1                   1053843731                               Cumple
# 2                     17043647                            No Cumple
# 3                     19105812                               Cumple
# 4                     51659165                            No Cumple
# ...                        ...                                  ...
# 13712                  8288700                               Cumple
# 13713                 79000080                               Cumple
# 13714                 12119794                               Cumple
# 13715                 79238499                               Cumple
# 13716                 12119794                               Cumple
#
#                         fgs_Email_01
# 0              JOSAMO_57@HOTMAIL.COM
# 1              ANGY15_95@HOTMAIL.COM
# 2         GLADISMARIA316@OUTLOOK.COM
# 3             HUGO_MOL18@HOTMAIL.COM
# 4        MARIACRIS.AMAYA@HOTMAIL.COM
# ...                              ...
# 13712           LCASALLA@HOTMAIL.COM
# 13713          PILARES02@HOTMAIL.COM
# 13714  EDGAR.SANTOS@ECOPETROL.COM.CO
# 13715  JAIME.PLAZAS@ECOPETROL.COM.CO
# 13716  EDGAR.SANTOS@ECOPETROL.COM.CO
#
# [13717 rows x 31 columns]

# %%
df_P_relevante.shape
# Out:
# (13717, 31)

# %%
df_P_relevante.columns
# Out:
# Index(['fgs_FechaInicio', 'fgs_FechaFin', 'fdp_NombreUsuarioGestionActual',
#        'fgs_ObservacionSolucion', 'fgs_SiglasDocumentoContacto', 'fgs_Nivel2',
#        'fdp_NombreUsuarioSolucion', 'ude_Regional', 'GrupoRolSolucion',
#        'Cumple_Objetivo_SolucionadoCerrado', 'fgs_Tipificación',
#        'fdp_NombreGrupoSolucion', 'fgs_Direccion_01',
#        'fgs_NombreCompletoContacto', 'fmf_Canal', 'Cumple_Objetivo_EnNivel2',
#        'fgs_DepartamentoDireccion_01', 'fgs_IdGestion',
#        'fdp_NombreUsuarioCreacion', 'fgs_Nivel3', 'fgs_PaisDireccion_01',
#        'SistemaPago', 'fgs_Telefono_01', 'Cumple_Objetivo_RegistradoEscalado',
#        'GrupoRolCreacion', 'fgs_CiudadDireccion_01', 'fgs_ObservacionCierre',
#        'fgs_ObservacionCreacion', 'fgs_NumeroDocumContacto',
#        'Cumple_Objetivo_SolicitadoRegistrado', 'fgs_Email_01'],
#       dtype='object')

# %% [markdown]
# **Renombrar columnas**

# %%
renombrar =['Fecha_Inicio', 'Fecha_Fin', 'NombreUsuarioGestionActual',
       'ObservacionSolucion', 'SiglasDocumento', 'Nivel2',
       'NombreUsuarioSolucion', 'Regional', 'GrupoRolSolucion',
       'Cumple_Objetivo_SolucionadoCerrado', 'Tipificación',
       'NombreGrupoSolucion', 'Direccion',
       'NombreCompletoContacto', 'Canal', 'Cumple_Objetivo_EnNivel2',
       'Departamento', 'IdGestion',
       'NombreUsuarioCreacion', 'Nivel3', 'Pais',
       'SistemaPago', 'Telefono', 'Cumple_Objetivo_RegistradoEscalado',
       'GrupoRolCreacion', 'Ciudad', 'ObservacionCierre',
       'ObservacionCreacion', 'NumeroDocum',
       'Cumple_Objetivo_SolicitadoRegistrado', 'Email']

# %%
df = df_P_relevante.rename(columns  = dict(zip(df_P_relevante.columns,renombrar)))

# %% [markdown]
# ## **Descripción general**

# %% [markdown]
# ### **Tipo de datos**

# %%
#Tipo de columna
list(set(df.dtypes.tolist()))
# Out:
# [dtype('int64'), dtype('O')]

# %%
#Columnas de tipo numerico
df.select_dtypes(include = ['int64']).columns
# Out:
# Index(['IdGestion', 'Telefono', 'NumeroDocum'], dtype='object')

# %% [markdown]
# A pesar de existir columnas tipo numero, como la del número de documento o el id, no son cuantitativos sino de tipo categoricos nominal.

# %%
df = df.astype(str)
#se cambia el tipo de las columnas de fecha
df['Fecha_Inicio'] = pd.to_datetime(df['Fecha_Inicio'])
df['Fecha_Fin'] = pd.to_datetime(df['Fecha_Fin'])
df['año_ini'] =  pd.DatetimeIndex(df['Fecha_Inicio']).year
df['mes_ini'] =  pd.DatetimeIndex(df['Fecha_Inicio']).month
df['dia_ini'] =  pd.DatetimeIndex(df['Fecha_Inicio']).day 
df['mes_fin'] =  pd.DatetimeIndex(df['Fecha_Fin']).month
df['dia_fin'] =  pd.DatetimeIndex(df['Fecha_Fin']).day

# %%
df[(df['mes_ini']==2)&(df['año_ini']==2021)&(df['Nivel3']=='Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)')].shape
# Out:
# (647, 36)

# %% [markdown]
# Se agregan columnas contando palabras en las columnas de observacion

# %%
df['# Palabras_ObservacionCreacion'] = df['ObservacionCreacion'].str.split().str.len()
df['# Palabras_ObservacionSolucion'] = df['ObservacionSolucion'].str.split().str.len()
df['# Palabras_ObservacionCierre'] = df['ObservacionCierre'].str.split().str.len()

# %%
#PERFILAMIENTO

# %%
df.columns
# Out:
# Index(['Fecha_Inicio', 'Fecha_Fin', 'NombreUsuarioGestionActual',
#        'ObservacionSolucion', 'SiglasDocumento', 'Nivel2',
#        'NombreUsuarioSolucion', 'Regional', 'GrupoRolSolucion',
#        'Cumple_Objetivo_SolucionadoCerrado', 'Tipificación',
#        'NombreGrupoSolucion', 'Direccion', 'NombreCompletoContacto', 'Canal',
#        'Cumple_Objetivo_EnNivel2', 'Departamento', 'IdGestion',
#        'NombreUsuarioCreacion', 'Nivel3', 'Pais', 'SistemaPago', 'Telefono',
#        'Cumple_Objetivo_RegistradoEscalado', 'GrupoRolCreacion', 'Ciudad',
#        'ObservacionCierre', 'ObservacionCreacion', 'NumeroDocum',
#        'Cumple_Objetivo_SolicitadoRegistrado', 'Email', 'año_ini', 'mes_ini',
#        'dia_ini', 'mes_fin', 'dia_fin', '# Palabras_ObservacionCreacion',
#        '# Palabras_ObservacionSolucion', '# Palabras_ObservacionCierre'],
#       dtype='object')

# %%
columnas_sinObser =['Fecha_Inicio', 'Fecha_Fin', 'NombreUsuarioGestionActual', 'SiglasDocumento', 'Nivel2',
       'NombreUsuarioSolucion', 'Regional', 'GrupoRolSolucion',
       'Cumple_Objetivo_SolucionadoCerrado', 'Tipificación',
       'NombreGrupoSolucion', 'Direccion', 'NombreCompletoContacto', 'Canal',
       'Cumple_Objetivo_EnNivel2', 'Departamento', 'IdGestion',
       'NombreUsuarioCreacion', 'Nivel3', 'Pais', 'SistemaPago', 'Telefono',
       'Cumple_Objetivo_RegistradoEscalado', 'GrupoRolCreacion', 'Ciudad', 'NumeroDocum',
       'Cumple_Objetivo_SolicitadoRegistrado', 'Email', '# Palabras_ObservacionCreacion',
       '# Palabras_ObservacionSolucion', '# Palabras_ObservacionCierre']

# %%
df['total_palabras']= df['# Palabras_ObservacionCreacion']+ df['# Palabras_ObservacionSolucion'] +df['# Palabras_ObservacionCierre']

# %%
df[columnas_sinObser+['total_palabras','año_ini', 'mes_ini', 'dia_ini', 'mes_fin', 'dia_fin']].to_csv('base_eda_BeneficiosEducativos.csv', index = False)

# %% [markdown]
# ### **Perfilamiento**

# %%
profile = df[columnas_sinObser].profile_report(title = 'Pandas Profiling Report')
profile.to_file(output_file = 'Perfilamiento_BaseLimpia_BeneficiosEducativos.html')
# Out:
# C:\Users\estduclui\Anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=44.0), HTML(value='')))
# HBox(children=(HTML(value='Generate report structure'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Render HTML'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Export report to file'), FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
columnas_categoricas = df.select_dtypes(exclude = ['<M8[ns]','int64' ]).columns
total_categorias = []
highes_unique = []

for i in columnas_categoricas:
    categorias = len(list(df[i].value_counts()))
    total_categorias.append(categorias)
    porcentaje = round(df[i].value_counts(normalize = True)[0]*100,1)
    highes_unique.append(porcentaje)
    


#tabla nombre de columna y cantidad de categorias (o valores distintos)
df_columnasCat = pd.DataFrame({'Nombre_columna': columnas_categoricas , '#valores dintintos':total_categorias, '% categoria mas comun': highes_unique})
df_columnasCat['Tipo Categórico'] = 'Nominal' 
df_columnasCat.loc[df_columnasCat['Nombre_columna'].str.contains('Fecha'), 'Tipo Categórico'] = 'Ordinal'
df_columnasCat.loc[df_columnasCat['#valores dintintos'] == 2, 'Tipo Categórico'] = 'Binario'

describe = df[columnas_categoricas].describe().T.reset_index()
df_columnasCat.merge(describe.rename(columns = {'index':'Nombre_columna'})[['Nombre_columna','top', 'freq']], how = 'left', on = 'Nombre_columna' ).sort_values('#valores dintintos',ascending = True)
# Out:
# <ipython-input-207-41eb2013eab2>:19: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   describe = df.describe().T.reset_index()
# <ipython-input-207-41eb2013eab2>:19: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   describe = df.describe().T.reset_index()
#                           Nombre_columna  #valores dintintos  \
# 31    Cumple_Objetivo_SolucionadoCerrado                   2
# 21                         No_Reprocesar                   2
# 3                                   Pais                   2
# 11    Cumple_Objetivo_RegistradoEscalado                   2
# 26                          Tipificación                   2
# 5   Cumple_Objetivo_SolicitadoRegistrado                   3
# 22                          Sistema_Pago                   3
# 27                    Grupo_Rol_Creacion                   3
# 18                               Nivel_2                   3
# 19              Cumple_Objetivo_EnNivel2                   3
# 13                    Grupo_Rol_Solucion                   4
# 10                            Siglas_Doc                   5
# 14                                 Canal                   5
# 30                              Regional                   6
# 25                  Nombre_GrupoSolucion                   7
# 16                               Nivel_3                  20
# 8                           Departamento                  28
# 6                 Nombre_UsuarioCreacion                  59
# 24          Nombre_Usuario_GestionActual                  66
# 12               Nombre_Usuario_Solucion                  66
# 4                                 Ciudad                 186
# 20                              Telefono                4383
# 17                             NumeroDoc                4445
# 23                       Nombre_Contacto                4455
# 15                                 Email                4634
# 2                              Direccion                4661
# 7                     Observacion_Cierre                9541
# 28                  Observacion_Solucion               11652
# 9                   Observacion_Creacion               11922
# 1                           Fecha_Inicio               13696
# 0                              Fecha_Fin               13706
# 29                            Id_Gestion               13717
#
#     % categoria mas comun Tipo Categórico  \
# 31                  100.0         Binario
# 21                  100.0         Binario
# 3                    99.9         Binario
# 11                   96.5         Binario
# 26                   78.4         Binario
# 5                    54.7         Nominal
# 22                   73.7         Nominal
# 27                   74.1         Nominal
# 18                   96.4         Nominal
# 19                   78.4         Nominal
# 13                   60.4         Nominal
# 10                   99.5         Nominal
# 14                   45.1         Nominal
# 30                   69.2         Nominal
# 25                   78.4         Nominal
# 16                   30.5         Nominal
# 8                    37.7         Nominal
# 6                     4.5         Nominal
# 24                    4.2         Nominal
# 12                    4.2         Nominal
# 4                    27.0         Nominal
# 20                    6.6         Nominal
# 17                    1.0         Nominal
# 23                    0.4         Nominal
# 15                    0.6         Nominal
# 2                     0.8         Nominal
# 7                    22.6         Nominal
# 28                    1.9         Nominal
# 9                     1.9         Nominal
# 1                     0.0         Ordinal
# 0                     0.0         Ordinal
# 29                    0.0         Nominal
#
#                                                   top   freq
# 31                                             Cumple  13716
# 21                                               True  13716
# 3                                            Colombia  13703
# 11                                             Cumple  13231
# 26                                           Contacto  10750
# 5                                           No Aplica   7504
# 22                                      Transacciones  10109
# 27                  Asesor de Servicio Contact Center  10163
# 18                      Beneficio Educativo - Regular  13224
# 19                                          No Aplica  10750
# 13                  Asesor de Servicio Contact Center   8286
# 10                                                 CC  13647
# 14                                   Email BackOffice   6193
# 30                                     CENTRO ORIENTE   9491
# 25                        Grupo Primer Nivel Personal  10750
# 16  Legal / Reconocimiento Trabajadores (Incluye B...   4189
# 8                                           SANTANDER   5175
# 6                        LEIDY TATIANA CARREÑO PEREZ     620
# 24                       LEIDY TATIANA CARREÑO PEREZ     579
# 12                       LEIDY TATIANA CARREÑO PEREZ     579
# 4                                     BARRANCABERMEJA   3699
# 20                                            2345000    912
# 17                                               1000    136
# 23                                    CLIENTE ANONIMO     59
# 15                        noregistra@ecopetrol.com.co     83
# 2                                         no registra    108
# 7                                   Sin Observaciones   3104
# 28      se procede a dar cierre según correo adjunto.    259
# 9           solicita información de plan educacional.    263
# 1                                 2020-08-28 09:52:38      2
# 0                                 2020-08-13 14:29:03      2
# 29                                           13581542      1

# %% [markdown]
# ### **Análisis univariado**

# %%
def univariado(data, columna):
    # Porcentaje para cada categoria
    i=columna
    print(data[i].value_counts(normalize=True))

    #plot the bar graph of percentage job categories
    data[i].value_counts(normalize=True).plot.barh()
    plt.show()

# %%
columnas = list(df_columnasCat[(df_columnasCat['#valores dintintos']>2) & (df_columnasCat['#valores dintintos'] < 30)].Nombre_columna)

# %%
data =  df[columnas]
data.columns
# Out:
# Index(['Cumple_Objetivo_SolicitadoRegistrado', 'Departamento', 'Siglas_Doc',
#        'Grupo_Rol_Solucion', 'Canal', 'Nivel_3', 'Nivel_2',
#        'Cumple_Objetivo_EnNivel2', 'Sistema_Pago', 'Nombre_GrupoSolucion',
#        'Grupo_Rol_Creacion', 'Regional'],
#       dtype='object')

# %%
for i in list(data.columns):
    print('----------------------------------------------------------------------------------------------------------------')
    print(i.upper())
    print (' ')
    univariado(data,i )
# Out:
# ----------------------------------------------------------------------------------------------------------------
# CUMPLE_OBJETIVO_SOLICITADOREGISTRADO
#
# No Aplica    0.547058
# Cumple       0.263542
# No Cumple    0.189400
# Name: Cumple_Objetivo_SolicitadoRegistrado, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# DEPARTAMENTO
#
# SANTANDER          0.377269
# BOGOTA             0.249180
# BOLIVAR            0.094263
# ANTIOQUIA          0.064154
# META               0.046439
# CUNDINAMARCA       0.030546
# N. DE SANTANDER    0.029161
# HUILA              0.015820
# MAGDALENA          0.012758
# VALLE DEL CAUCA    0.011664
# ATLANTICO          0.009988
# CASANARE           0.008821
# CESAR              0.008165
# CALDAS             0.007509
# PUTUMAYO           0.006270
# BOYACA             0.005759
# TOLIMA             0.005759
# SUCRE              0.004812
# RISARALDA          0.003135
# CORDOBA            0.002406
# NARIÑO             0.001750
# QUINDIO            0.001458
# ARAUCA             0.000875
# SAN ANDRES         0.000802
# CAUCA              0.000656
# CHOCO              0.000292
# CAQUETA            0.000219
# VICHADA            0.000073
# Name: Departamento, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# SIGLAS_DOC
#
# CC     0.994897
# TI     0.001895
# NIT    0.001750
# CE     0.001385
# RC     0.000073
# Name: Siglas_Doc, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# GRUPO_ROL_SOLUCION
#
# Asesor de Servicio Contact Center          0.604068
# Asesor de Servicio Front Ecopetrol         0.197055
# Asesor solucionador Ecopetrol              0.165707
# Asesor de Servicio Front Contact Center    0.033171
# Name: Grupo_Rol_Solucion, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# CANAL
#
# Email BackOffice           0.451484
# Telefónico                 0.435882
# Oficina De Atención CAL    0.102136
# Chat                       0.009040
# Escrito Radicado           0.001458
# Name: Canal, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# NIVEL_3
#
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                   0.305387
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)                       0.175986
# Anticipo Trabajadores (Incluye BXC)                                           0.131734
# Anticipo Pensionados (Incluye Sustitutos)                                     0.115550
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)            0.088212
# Soporte Plataforma para Instituciones Educativas vía TIB                      0.081723
# Solicitud de educación inclusiva                                              0.030182
# Inscripción solicitud becas Comité de Educación Convencional Activos          0.025734
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)            0.021579
# Inscripción casos especiales comité de educación convencional activos         0.007217
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)         0.004228
# Consulta Titulares Beneficio Eductivo - Desvinculados                         0.003791
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.    0.003281
# Anticipo Pensionados Educación Inclusiva                                      0.001458
# Anticipo Trabajadores Educación Inclusiva                                     0.001021
# Inscripción casos especiales comité educación convencional pensionados        0.001021
# Consulta de información relacionadas con reembolsos                           0.000875
# Consulta sobre liquidación/pago préstamo para educación                       0.000729
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)            0.000219
# Consulta especialista beneficios atención PQRS                                0.000073
# Name: Nivel_3, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# NIVEL_2
#
# Beneficio Educativo - Regular               0.964059
# Beneficio Educativo - Inclusiva             0.032660
# Beneficio Educativo - Colegios Ecopetrol    0.003281
# Name: Nivel_2, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# CUMPLE_OBJETIVO_ENNIVEL2
#
# No Aplica    0.783699
# Cumple       0.208063
# No Cumple    0.008238
# Name: Cumple_Objetivo_EnNivel2, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# SISTEMA_PAGO
#
# Transacciones        0.736969
# No Aplica            0.210760
# Puesto de Trabajo    0.052271
# Name: Sistema_Pago, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# NOMBRE_GRUPOSOLUCION
#
# Grupo Primer Nivel Personal                   0.783699
# Equipo Plan Educacional                       0.126340
# Profesional Transferencia de Información      0.049646
# Anticipos – Equipo Plan Educacional           0.019538
# Profesional Educación Inclusiva               0.018371
# Profdecolegios propiedad de Ecopetrol S.A.    0.002041
# Equipo Beneficio Educativo - Desvinculados    0.000365
# Name: Nombre_GrupoSolucion, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# GRUPO_ROL_CREACION
#
# Asesor de Servicio Contact Center          0.740905
# Asesor de Servicio Front Ecopetrol         0.206824
# Asesor de Servicio Front Contact Center    0.052271
# Name: Grupo_Rol_Creacion, dtype: float64
# ----------------------------------------------------------------------------------------------------------------
# REGIONAL
#
# CENTRO ORIENTE       0.691915
# NORTE                0.123205
# OCCIDENTE            0.099949
# LLANOS ORIENTALES    0.047605
# SUR                  0.022089
# MAGDALENA MEDIO      0.015237
# Name: Regional, dtype: float64

# %% [markdown]
# ### **Columnas con los textos a analizar**

# %%
df['# Palabras_ObservacionCreacion'] = df['Observacion_Creacion'].str.split().str.len()
df['# Palabras_ObservacionSolucion'] = df['Observacion_Solucion'].str.split().str.len()
df['# Palabras_ObservacionCierre'] = df['Observacion_Cierre'].str.split().str.len()

# %%
df_Obser = df[['# Palabras_ObservacionCreacion', '# Palabras_ObservacionSolucion','# Palabras_ObservacionCierre' ]]
describe_var = df_Obser.describe().round(1)
describe_var = describe_var.append(pd.Series(df_Obser.var(), name = 'Variance')) 
describe_var = describe_var.append(pd.Series(df_Obser.sum(), name = 'Sum')) 

#descripcion_observ = df_OF_relevante[['# Palabras_fgs_ObservacionCreacion', '# Palabras_fgs_ObservacionSolucion','# Palabras_fgs_ObservacionCierre' ]].describe()
describe_var.round(1)
# Out:
#           # Palabras_ObservacionCreacion  # Palabras_ObservacionSolucion  \
# count                            13717.0                         13717.0
# mean                                33.8                            50.8
# std                                 43.6                            69.4
# min                                  1.0                             1.0
# 25%                                 10.0                            12.0
# 50%                                 18.0                            26.0
# 75%                                 39.0                            52.0
# max                                518.0                           500.0
# Variance                          1903.8                          4820.6
# Sum                             463059.0                        696629.0
#
#           # Palabras_ObservacionCierre
# count                          13717.0
# mean                              40.9
# std                               68.3
# min                                2.0
# 25%                                4.0
# 50%                               15.0
# 75%                               40.0
# max                              500.0
# Variance                        4663.6
# Sum                           560905.0

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = df['Nivel_2'], y =df['# Palabras_ObservacionCreacion'])

plt.show()

# %%
plt.figure(figsize = (10,8))
sns.boxplot(df['Sistema_Pago'], df['# Palabras_ObservacionCreacion'])
plt.show()
# Out:
# C:\Users\estduclui\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plt.show?

# %%
plt.figure(figsize = (15,8))
sns.boxplot(x = df['Grupo_Rol_Solucion'], y = df['# Palabras_ObservacionCreacion'])

plt.show()

# %% [markdown]
# **Porcentaje de palabras por nivel**

# %%
df['total_palabras']= df['# Palabras_ObservacionCreacion']+ df['# Palabras_ObservacionSolucion'] +df['# Palabras_ObservacionCierre']
df['% total_palabras'] = df['total_palabras']/df['total_palabras'].sum()
df.groupby('Nivel_2')['% total_palabras'].sum().plot.barh()
plt.show()
print(df.groupby('Nivel_2')['% total_palabras'].sum())
# Out:
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol    0.003163
# Beneficio Educativo - Inclusiva             0.030203
# Beneficio Educativo - Regular               0.966634
# Name: % total_palabras, dtype: float64

# %%
df.groupby('Nivel_3')['% total_palabras'].sum().plot.barh()
plt.show()
#print(df.groupby('Nivel_3')['% total_palabras'].sum())
print(df.groupby('Nivel_3')['total_palabras'].sum())
# Out:
# Nivel_3
# Anticipo Pensionados (Incluye Sustitutos)                                     199846
# Anticipo Pensionados Educación Inclusiva                                        2048
# Anticipo Trabajadores (Incluye BXC)                                           238722
# Anticipo Trabajadores Educación Inclusiva                                       1465
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)               458
# Consulta Titulares Beneficio Eductivo - Desvinculados                           6379
# Consulta de información relacionadas con reembolsos                             1292
# Consulta especialista beneficios atención PQRS                                    24
# Consulta sobre liquidación/pago préstamo para educación                          933
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)            168435
# Inscripción casos especiales comité de educación convencional activos           8504
# Inscripción casos especiales comité educación convencional pensionados          1679
# Inscripción solicitud becas Comité de Educación Convencional Activos           32876
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)                       312419
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                   536449
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)           5435
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)             31563
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      5442
# Solicitud de educación inclusiva                                               48454
# Soporte Plataforma para Instituciones Educativas vía TIB                      118170
# Name: total_palabras, dtype: int64

# %% [markdown]
# ## **Análisis Multivariado**

# %% [markdown]
# ### **Mapas de calor**

# %% [markdown]
# * Nivel 2 vs Canal vs Total de palabras

# %%
result = pd.pivot_table(data=df, index='Nivel_2', columns='Canal',values='total_palabras', fill_value =0)
print(result)

#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()
# Out:
# Canal                                           Chat  Email BackOffice  \
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol    0.000000        128.459459
# Beneficio Educativo - Inclusiva             0.000000        130.609756
# Beneficio Educativo - Regular             221.508065        172.847975
#
# Canal                                     Escrito Radicado  \
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol          0.000000
# Beneficio Educativo - Inclusiva                 118.000000
# Beneficio Educativo - Regular                   195.210526
#
# Canal                                     Oficina De Atención CAL  Telefónico
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol                38.000000   93.000000
# Beneficio Educativo - Inclusiva                         65.625000   76.432432
# Beneficio Educativo - Regular                          105.619253   81.492578

# %% [markdown]
# * Nivel 2 vs Grupo_rol_solucion vs Total de palabras

# %%
result = pd.pivot_table(data=df, index='Nivel_2', columns='Grupo_Rol_Solucion',values='total_palabras', fill_value =0)
print(result)

#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()
# Out:
# Grupo_Rol_Solucion                        Asesor de Servicio Contact Center  \
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol                          90.555556
# Beneficio Educativo - Inclusiva                                   94.556338
# Beneficio Educativo - Regular                                    104.314444
#
# Grupo_Rol_Solucion                        Asesor de Servicio Front Contact Center  \
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol                                 0.000000
# Beneficio Educativo - Inclusiva                                        112.750000
# Beneficio Educativo - Regular                                          260.690745
#
# Grupo_Rol_Solucion                        Asesor de Servicio Front Ecopetrol  \
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol                          115.125000
# Beneficio Educativo - Inclusiva                                   170.047619
# Beneficio Educativo - Regular                                     177.004900
#
# Grupo_Rol_Solucion                        Asesor solucionador Ecopetrol
# Nivel_2
# Beneficio Educativo - Colegios Ecopetrol                     132.357143
# Beneficio Educativo - Inclusiva                              119.226190
# Beneficio Educativo - Regular                                115.156046

# %% [markdown]
# * Nivel 3 vs Canal vs Total de palabras

# %%
result = pd.pivot_table(data=df, index='Nivel_3', columns='Canal',values='total_palabras', fill_value =0)
#print(result)
plt.figure(figsize = (10,8))
#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()

# %% [markdown]
# * Grupo_Rol_Solucion vs Canal vs Total de palabras

# %%
result = pd.pivot_table(data=df, index='Grupo_Rol_Solucion', columns='Canal',values='total_palabras', fill_value =0)
#print(result)

#create heat map of education vs marital vs response_rate
sns.heatmap(result, annot=True, cmap = 'RdYlGn', center=0.117)
plt.show()

# %% [markdown]
# ### **Análisis de correspondencias multiples MCA**

# %%
columnas = list(df_columnasCat[(df_columnasCat['#valores dintintos'] <= 10)].Nombre_columna)
X = df[columnas]
mca = prince.MCA()
mca = mca.fit(X)
mca1 = mca.transform(X) 
#print(mca1)
ax = mca.plot_coordinates(
     X=X,
     ax=None,
     figsize=(12, 12),
     show_row_points=True,
     row_points_size=10,
     show_row_labels=False,
     show_column_points=True,
     column_points_size=30,
     show_column_labels=False,
     legend_n_cols=1
     )

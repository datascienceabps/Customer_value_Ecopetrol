# %%
package = ['boto3','es_lemmatizer','pyodbc','prince']
f= open("paquetes.txt","w+")

def install_txt(package):
  f= open("paquetes.txt","w+")
  for i in package:
    print(i)
    

    try:
        __import__(i)
        print('ya instalado {}'.format(i))
    except ImportError:
        # main(['install', package]) 
        f.write("{} \r\n".format(i))
        print('No instalado {}'.format(i))


install_txt(package)
# Out:
# boto3
# ya instalado boto3
# es_lemmatizer
# ya instalado es_lemmatizer
# pyodbc
# ya instalado pyodbc
# prince
# ya instalado prince

# %%
# !pip install -r paquetes.txt

# %% [markdown]
# #**Librerias**

# %%
#Librerias
import re
import numpy as np
import pandas as pd
import pandas_profiling
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
nltk.download('stopwords')
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import unicodedata
from es_lemmatizer import lemmatize
import spacy
import re
import pyodbc
import prince
import os
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# #**Rutas**

# %%
#RUTAS
#OF :Operaciones financieras
#P : Personal

# Campaña_OF = Path('C:/Users/estduclui/Documents/ECOPETROL- TA/Entendimiento del negocio/Modelo Analítico PCF - Cuentas por pagar.xlsx')
# Campaña_P = Path('C:/Users/estduclui/Documents/ECOPETROL- TA/Entendimiento del negocio/Modelo Analítico PCP - Beneficio Educativo.xlsx')

# %%
#Rutas en Drive colab
os.getcwd()
# Out:
# '/content'

# %%
Campaña_OF =  "/content/Modelo Analítico PCF - Cuentas por pagar.xlsx"
Campaña_P  = "/content/Modelo Analítico PCP - Beneficio Educativo.xlsx"

# %% [markdown]
# #**Funciones**

# %%
# CONEXION A SERVIDOR ###################################################################################
# def Conexion():
#     server = '172.27.48.148'
#     #database = 'bdcmp_NuevaEpsCrm' 
#     username = 'CienciaDatos' 
#     password = 'C13nc1aD47*5'  
#     cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';UID='+username+';PWD='+ password)
#     cursor = cnxn.cursor()
#     return cnxn


# DEFINICION DE PICOS Y FECHAS ##################################################################################
##Se definen fechas para realizar los respectivos filtros 
##cuando se extraiga la información correspondiente desde el servidor

def fechas(df_Tipo_OF):
    df_OF = df_Tipo_OF.astype(str).replace('NaT','20200101')
#######Operaciones financieras
    df_OF ['fecha_ini_1'] = df_OF['Picos de demanda  1'].replace(regex=r'-', value = '').replace('0','20200101')
    df_OF ['fecha_fin_1'] = ['20210401','20210301','20210301','20210301', '20210301', '20210301', '20210401']
    df_OF ['fecha_ini_2'] = df_OF['Picos de demanda  2'].replace(regex=r'-', value = '').replace('0','20200101')
    df_OF ['fecha_fin_2'] = ['20210501', '20210501', '20200101', '20210501', '20200101', '20210501', '20201001']
    df_OF ['fecha_ini_3'] = df_OF['Picos de demanda  3'].replace(regex=r'-', value = '').replace('0','20200101')
    df_OF ['fecha_fin_3'] = ['20210601', '20200101', '20200101', '20210601', '20200101', '20200101', '20210101']
    
    return df_OF  

## EXTRACCIÓN ########################################################################################################

def Extraccion(df_fechas, df_General, picos):
    #df_fechas : Nombre de la tabla con las tipologias seleccionadas y las fechas definidas correspondientes (con la función de fechas)
    #df_general : Nombre de tabla para cada campaña sin las fechas definidas 
    #picos : Número máximo de picos que se analizan [en OF son 2, en P son 3]
    
    query_base = "SELECT * FROM [172.27.90.50].[Ecopetrol_Reporting].[dbo].[Tbl_Ecopetrol_ResultadoBackOffice] "
    
    i = 0 
    cnxn = Conexion()
    query = "WHERE ([fgs_Nivel3] = '"+ df_fechas['Nivel 3'][i] + "') AND ([fgs_FechaInicio] BETWEEN '" + df_fechas['fecha_ini_1'][i]+ "' AND '" + df_fechas['fecha_fin_1'][i] +"')"  
    query_completa = query_base + query
    df_inicial = pd.read_sql(query_completa, cnxn)

    for j in range(1,picos+1):
        df_General["Datos_Pico_"+str(j)] = 0
        for i in range(0,len(df_fechas['Campaña'])):
            cnxn = Conexion()
            query = "WHERE ([fgs_Nivel3] = '"+ df_fechas['Nivel 3'][i] + "') AND ([fgs_FechaInicio] BETWEEN '" + df_fechas["fecha_ini_"+str(j)][i]+ "' AND '" + df_fechas["fecha_fin_"+str(j)][i] +"')"  
            query_completa = query_base + query
            df = pd.read_sql(query_completa, cnxn)
            df_total = pd.concat([df_inicial,df]).drop_duplicates()
            df_inicial = df_total
            df_General["Datos_Pico_"+str(j)][i] = df.shape[0] 
    print('Total de registros:', df_inicial.shape[0])
    print('Total de columnas:', df_inicial.shape[1])
            
    return df_total,df_General                 

# VALORES FALTANTES ###############################################################################################################################################################################################

def Valores_Faltantes(df, porcentaje):
    Faltantes = df.isnull().sum()
    df_Faltantes = pd.DataFrame({'Nombre_Columnas':Faltantes.index, 'Total_Vacios':Faltantes.values})#[df_Faltantes['Total_Vacios'] != 0]
    df_Faltantes = df_Faltantes[df_Faltantes['Total_Vacios'] != 0]

    df_Faltantes['Porcentaje_vacio'] = ((df_Faltantes['Total_Vacios']/df.shape[0])*100).round(2)
    df_Faltantes['Columna_vacia'] = 'NO'
    df_Faltantes.loc[df_Faltantes['Total_Vacios'] == df.shape[0], 'Columna_vacia'] = 'SI'
    
    print('Total columnas con valores faltantes :', df_Faltantes.shape[0])
    print('Total columnas vacias :', df_Faltantes[df_Faltantes['Columna_vacia'] == 'SI'].Columna_vacia.count())
    print('Total columnas no vacias con mas del ' + str(porcentaje) + '% de valores faltantes :', df_Faltantes[(df_Faltantes['Porcentaje_vacio'] >= porcentaje) & (df_Faltantes['Columna_vacia'] == 'NO') ].Columna_vacia.count())
    #print('Total columnas no vacias con menos del ' + str(porcentaje) + '% de valores faltantes :', df_Faltantes[(df_Faltantes['Porcentaje_vacio'] >= porcentaje) & (df_Faltantes['Columna_vacia'] == 'NO') ].Columna_vacia.count())
    
    return df_Faltantes

# ELIMINAR COLUMNAS##############################################################################################

#para eliminar columnas seleccionadas
def Eliminar_columnas(df, lista_columnas):
    df_drop = df.drop(columns = lista_columnas)
    print ('Cantidad de columnas iniciales : ', df.shape[1])
    print ('Cantidad despues de eliminar : ', df_drop.shape[1] )
    return df_drop
# columnas duplicadas
def columnas_dup(df):
    df_dup = df.T.duplicated().T
    return df_dup
#Para eliminar columnas duplicadas
def columnas_nodup(df):
    print ('Total de columnas antes de eliminar dup: ', df.shape[1])
    df_sindup = df.T.drop_duplicates().T
    print ('Total de columnas duplicadas : ', df.shape[1] - df_sindup.shape[1])
    print ('Total de columnas no duplicadas:', df_sindup.shape[1])
    return df_sindup    

def mytable(data):
    nulls = pd.DataFrame(data.isnull().sum()/data.shape[0]*100, columns=['% de datos nulos'])
    ceros = pd.DataFrame((data==0).sum()/data.shape[0]*100, columns=['% de ceros'])
    tipo = pd.DataFrame(data.dtypes,columns=['Tipo de datos'])
    val = pd.DataFrame(data.nunique(),columns=['# de valores diferentes'])
    valpor = pd.DataFrame(data.nunique()/data.shape[0]*100,columns=['% de valores diferentes'])
    mis_val_table = pd.concat([nulls, ceros,tipo, val, valpor], axis=1)
    return mis_val_table

# %% [markdown]
# **CAMPAÑA OPERACIONES FINACIERAS - CUENTAS POR PAGAR**

# %% [markdown]
# # **EXTRACCIÓN**

# %% [markdown]
# ## **Definición de Tipologías y meses que se extraeran**

# %% [markdown]
# Se extrae tabla producto del entendimiento del negocio donde se encuentran definidas las tipologias y meses donde se presentaron los picos a estudiar

# %%
df_Tipo_P =  pd.read_excel(Campaña_P, sheet_name = '2. Esquema Tipologías de Servic', usecols = "B:H", skiprows= lambda x: x in [0, 1]).astype(str).replace('NaT','0')

# %% [markdown]
# -- Campaña Operaciones financieras

# %%
df_Tipo_P
# Out:
#      Campaña  ...       Gráficos análisis exploratorio
# 0   Personal  ...                      1. Legalización
# 1   Personal  ...                      1. Legalización
# 2   Personal  ...  2. Solicitud de educación inclusiva
# 3   Personal  ...                          3. Anticipo
# 4   Personal  ...                          3. Anticipo
# 5   Personal  ...                          3. Anticipo
# 6   Personal  ...                          3. Anticipo
# 7   Personal  ...                          4. Consulta
# 8   Personal  ...                          4. Consulta
# 9   Personal  ...                          4. Consulta
# 10  Personal  ...                          4. Consulta
# 11  Personal  ...                          4. Consulta
# 12  Personal  ...                          4. Consulta
# 13  Personal  ...                          4. Consulta
# 14  Personal  ...                5. Soporte Plataforma
# 15  Personal  ...                         6. Reintegro
# 16  Personal  ...                         6. Reintegro
# 17  Personal  ...                       7. Inscripción
# 18  Personal  ...                       7. Inscripción
# 19  Personal  ...                       7. Inscripción
#
# [20 rows x 6 columns]

# %% [markdown]
# Se definen fechas de los picos en cada tipologia con el fin de realizar el posterior filtro

# %%
# df_fechas_P = fechas(df_Tipo_P)

# %%
# df_fechas_P

# %% [markdown]
# ## **Pefilamiento inicial P**

# %%
#Lectura
df_Registros_P = pd.read_csv('Base_general_extraida_P.csv')
df_Registros_P.head(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (51,156,160,161,162,163,165,167,197) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    fgs_IdCampana  fgs_IdGestion  ...  T_Real_EnNivel4 Cumple_Objetivo_EnNivel4
# 0              3       13908445  ...              0.0                No Aplica
# 1              3       13908527  ...              0.0                No Aplica
#
# [2 rows x 222 columns]

# %%
tabla=mytable(df_Registros_P)
display(tabla,df_Registros_P.shape)
# Out:
#                           % de datos nulos  ...  % de valores diferentes
# fgs_IdCampana                     0.000000  ...                 0.007274
# fgs_IdGestion                     0.000000  ...               100.000000
# fgs_IdGestionDetalle              0.000000  ...               100.000000
# fgs_NombreCampana                 0.000000  ...                 0.007274
# fgs_NombrePlataforma              0.000000  ...                 0.007274
# ...                                    ...  ...                      ...
# fdp_MotivoEscalamientoN4        100.000000  ...                 0.000000
# fdp_NivelEscalamientoN4         100.000000  ...                 0.000000
# T_Objetivo_EnNivel4             100.000000  ...                 0.000000
# T_Real_EnNivel4                  22.956066  ...                 0.007274
# Cumple_Objetivo_EnNivel4          0.000000  ...                 0.007274
#
# [222 rows x 5 columns]
# (13748, 222)

# %%
tabla.describe(percentiles=[.05,0.25,0.5,.75,.95])
# Out:
#        % de datos nulos  ...  % de valores diferentes
# count        222.000000  ...               222.000000
# mean          49.130717  ...                 7.700907
# std           47.506168  ...                22.281145
# min            0.000000  ...                 0.000000
# 5%             0.000000  ...                 0.000000
# 25%            0.000000  ...                 0.001818
# 50%           54.611580  ...                 0.021821
# 75%           99.998182  ...                 0.447338
# 95%          100.000000  ...                69.475196
# max          100.000000  ...               100.000000
#
# [10 rows x 4 columns]

# %%
vacios = tabla[tabla['% de datos nulos']==100]
vacios
# Out:
#                                     % de datos nulos  ...  % de valores diferentes
# fgs_NombreDocumentoContacto                    100.0  ...                      0.0
# fgs_FechaNacimientoContacto                    100.0  ...                      0.0
# fgs_HabeasContacto                             100.0  ...                      0.0
# fgs_NombreGeneroContacto                       100.0  ...                      0.0
# fgs_RoutingPointOrVdn                          100.0  ...                      0.0
# fgs_Extension                                  100.0  ...                      0.0
# fgs_CallId                                     100.0  ...                      0.0
# fgs_Skill                                      100.0  ...                      0.0
# fgs_Ani                                        100.0  ...                      0.0
# fgs_OpcionesIVR                                100.0  ...                      0.0
# fgs_Nivel5                                     100.0  ...                      0.0
# fgs_Nivel6                                     100.0  ...                      0.0
# fgs_Nivel7                                     100.0  ...                      0.0
# fgs_Nivel8                                     100.0  ...                      0.0
# fgs_Nivel9                                     100.0  ...                      0.0
# fgs_Nivel10                                    100.0  ...                      0.0
# fdp_IdDetalleFlujoCreacion                     100.0  ...                      0.0
# fdp_FechaVencimientoCreacion                   100.0  ...                      0.0
# fdp_MotivoCreacion                             100.0  ...                      0.0
# fdp_MotivoEscalamientoN2                       100.0  ...                      0.0
# fdp_IdHistoricoPqrEscalamientoN3               100.0  ...                      0.0
# fdp_IdGrupoEscalamientoN3                      100.0  ...                      0.0
# fdp_NombreGrupoEscalamientoN3                  100.0  ...                      0.0
# fdp_IdDetalleFlujoEscalamientoN3               100.0  ...                      0.0
# fdp_IdUsuarioEscalamientoN3                    100.0  ...                      0.0
# fdp_UsuarioEscalamientoN3                      100.0  ...                      0.0
# fdp_NombreUsuarioEscalamientoN3                100.0  ...                      0.0
# fgs_ObservacionEscalamientoN3                  100.0  ...                      0.0
# fdp_FechaEscalamientoN3                        100.0  ...                      0.0
# fdp_FechaVencimientoEscalamientoN3             100.0  ...                      0.0
# CodigoGrupoRolEscalamientoN3                   100.0  ...                      0.0
# GrupoRolEscalamientoN3                         100.0  ...                      0.0
# fdp_MotivoEscalamientoN3                       100.0  ...                      0.0
# fdp_NivelEscalamientoN3                        100.0  ...                      0.0
# T_Objetivo_EnNivel3                            100.0  ...                      0.0
# fdp_MotivoSolucion                             100.0  ...                      0.0
# fdp_MotivoReapertura                           100.0  ...                      0.0
# fdp_MotivoCierre                               100.0  ...                      0.0
# T_Real_Total                                   100.0  ...                      0.0
# Cumple_Objetivo_Total                          100.0  ...                      0.0
# Valido                                         100.0  ...                      0.0
# fdp_IdHistoricoPqrEscalamientoN4               100.0  ...                      0.0
# fdp_IdGrupoEscalamientoN4                      100.0  ...                      0.0
# fdp_NombreGrupoEscalamientoN4                  100.0  ...                      0.0
# fdp_IdDetalleFlujoEscalamientoN4               100.0  ...                      0.0
# fdp_IdUsuarioEscalamientoN4                    100.0  ...                      0.0
# fdp_UsuarioEscalamientoN4                      100.0  ...                      0.0
# fdp_NombreUsuarioEscalamientoN4                100.0  ...                      0.0
# fgs_ObservacionEscalamientoN4                  100.0  ...                      0.0
# fdp_FechaEscalamientoN4                        100.0  ...                      0.0
# fdp_FechaVencimientoEscalamientoN4             100.0  ...                      0.0
# CodigoGrupoRolEscalamientoN4                   100.0  ...                      0.0
# GrupoRolEscalamientoN4                         100.0  ...                      0.0
# fdp_MotivoEscalamientoN4                       100.0  ...                      0.0
# fdp_NivelEscalamientoN4                        100.0  ...                      0.0
# T_Objetivo_EnNivel4                            100.0  ...                      0.0
#
# [56 rows x 5 columns]

# %%
cardinalidad100 = tabla[tabla['% de valores diferentes']==100]
cardinalidad100
# Out:
#                       % de datos nulos  ...  % de valores diferentes
# fgs_IdGestion                      0.0  ...                    100.0
# fgs_IdGestionDetalle               0.0  ...                    100.0
#
# [2 rows x 5 columns]

# %%
tabla
# Out:
#                           % de datos nulos  ...  % de valores diferentes
# fgs_IdCampana                     0.000000  ...                 0.007274
# fgs_IdGestion                     0.000000  ...               100.000000
# fgs_IdGestionDetalle              0.000000  ...               100.000000
# fgs_NombreCampana                 0.000000  ...                 0.007274
# fgs_NombrePlataforma              0.000000  ...                 0.007274
# ...                                    ...  ...                      ...
# fdp_MotivoEscalamientoN4        100.000000  ...                 0.000000
# fdp_NivelEscalamientoN4         100.000000  ...                 0.000000
# T_Objetivo_EnNivel4             100.000000  ...                 0.000000
# T_Real_EnNivel4                  22.956066  ...                 0.007274
# Cumple_Objetivo_EnNivel4          0.000000  ...                 0.007274
#
# [222 rows x 5 columns]

# %%
cardinalidad1 = tabla[tabla['# de valores diferentes']==1]
cardinalidad1
# Out:
#                                  % de datos nulos  ...  % de valores diferentes
# fgs_IdCampana                            0.000000  ...                 0.007274
# fgs_NombreCampana                        0.000000  ...                 0.007274
# fgs_NombrePlataforma                     0.000000  ...                 0.007274
# fgs_Nivel1                               0.000000  ...                 0.007274
# fgs_PaisDireccion_01                     0.101833  ...                 0.007274
# TipoTransacción                          0.000000  ...                 0.007274
# TipoComplejidad                          0.000000  ...                 0.007274
# Funcionalidad                            0.000000  ...                 0.007274
# DependenciaLínea                         0.000000  ...                 0.007274
# AreaServicio                             0.000000  ...                 0.007274
# fdp_IdGrupoCreacion                      0.000000  ...                 0.007274
# fdp_NombreGrupoCreacion                  0.000000  ...                 0.007274
# fdp_NivelCreacion                        0.000000  ...                 0.007274
# T_Objetivo_SolicitadoRegistrado          0.000000  ...                 0.007274
# T_Objetivo_RegistradoEscalado            0.000000  ...                 0.007274
# fdp_NivelEscalamientoN2                 78.207739  ...                 0.007274
# T_Real_EnNivel3                         22.956066  ...                 0.007274
# Cumple_Objetivo_EnNivel3                 0.000000  ...                 0.007274
# fdp_IdGrupoDevolucion                   98.392493  ...                 0.007274
# fdp_NombreGrupoDevolucion               98.392493  ...                 0.007274
# fdp_NivelDevolucion                     98.392493  ...                 0.007274
# T_Objetivo_SolucionadoCerrado            0.000000  ...                 0.007274
# fdp_IdHistoricoPqrReapertura            99.992726  ...                 0.007274
# fdp_IdGrupoReapertura                   99.992726  ...                 0.007274
# fdp_NombreGrupoReapertura               99.992726  ...                 0.007274
# fdp_IdDetalleFlujoReapertura            99.992726  ...                 0.007274
# fdp_IdUsuarioReapertura                 99.992726  ...                 0.007274
# fdp_UsuarioReapertura                   99.992726  ...                 0.007274
# fdp_NombreUsuarioReapertura             99.992726  ...                 0.007274
# fgs_ObservacionReapertura               99.992726  ...                 0.007274
# fdp_FechaReapertura                     99.992726  ...                 0.007274
# fdp_FechaVencimientoReapertura          99.992726  ...                 0.007274
# CodigoGrupoRolReapertura                99.992726  ...                 0.007274
# GrupoRolReapertura                      99.992726  ...                 0.007274
# fdp_NivelReapertura                     99.992726  ...                 0.007274
# Ajustado                                50.640093  ...                 0.007274
# Pruebas                                  0.000000  ...                 0.007274
# T_Real_EnNivel4                         22.956066  ...                 0.007274
# Cumple_Objetivo_EnNivel4                 0.000000  ...                 0.007274
#
# [39 rows x 5 columns]

# %%
(tabla['# de valores diferentes']==1).loc['fgs_Nivel1']
# Out:
# True

# %%
tabla.loc['fgs_Nivel1']
# Out:
# % de datos nulos                    0
# % de ceros                          0
# Tipo de datos                  object
# # de valores diferentes             1
# % de valores diferentes    0.00727379
# Name: fgs_Nivel1, dtype: object

# %%
tabla.loc['fgs_Nivel1']['# de valores diferentes']==1
# Out:
# True

# %%
(tabla['# de valores diferentes']==1).loc['fgs_Nivel1']
# Out:
# True

# %%
# tabla[tabla['# de valores diferentes']==1].loc['fgs_Nivel1']

# %%
# profile = df_Registros_OF.profile_report(title = 'Pandas Profiling Report', correlations={"cramers": {"calculate": False}})
# profile.to_file(output_file = 'Perfilamiento_BaseInicial_CuentasPorPagar.html')

# %%
df_Registros_P = df_Registros_P[df_Registros_P['fgs_Nivel1'] != 'Prestador de Servicios de Salud']
# se fue solo un dato y estefania lo borro.

# %%
variables_eliminar=vacios.index.tolist()+cardinalidad1.index.tolist()+cardinalidad100.index.tolist()# no aportan informacion
len(variables_eliminar)
# Out:
# 97

# %%
mapa_columnas = [i not in variables_eliminar for i in df_Registros_P.columns]

# %%
sum(mapa_columnas)
# Out:
# 125

# %%
df_Registros_P.shape
# Out:
# (13748, 222)

# %%
125+97
# Out:
# 222

# %%
nuevas_columnas = df_Registros_P.columns[mapa_columnas]

# %%
df_Registros_P = df_Registros_P[nuevas_columnas]

# %%
df_Registros_P.shape
# Out:
# (13748, 125)

# %%
tabla = mytable(df_Registros_P)

# %%
tabla
# Out:
#                              % de datos nulos  ...  % de valores diferentes
# fgs_SiglasDocumentoContacto          0.101833  ...                 0.036369
# fgs_NumeroDocumContacto              0.000000  ...                32.390166
# fgs_NombreCompletoContacto           0.000000  ...                32.462904
# fgs_Ip                               0.101833  ...                 1.709340
# fgs_FechaInicio                      0.000000  ...                99.847251
# ...                                       ...  ...                      ...
# fdp_MotivoGestionActual             99.985452  ...                 0.014548
# fdp_NivelGestionActual               0.000000  ...                 0.014548
# TipoAjuste                          50.640093  ...                 0.014548
# fdp_FechaVencimientoTotal            0.000000  ...                75.785569
# NoReprocesar                         0.000000  ...                 0.014548
#
# [125 rows x 5 columns]

# %%
tabla['Tipo de datos'].value_counts()
# Out:
# object     76
# float64    37
# int64      11
# bool        1
# Name: Tipo de datos, dtype: int64

# %%
df_Registros_P.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13748 entries, 0 to 13747
# Columns: 125 entries, fgs_SiglasDocumentoContacto to NoReprocesar
# dtypes: bool(1), float64(37), int64(11), object(76)
# memory usage: 13.1+ MB

# %%
objetos = df_Registros_P.select_dtypes(['object'])
numeros = df_Registros_P.select_dtypes(['int64','float64'])

# %%
objetos.describe()
# Out:
#        fgs_SiglasDocumentoContacto  ... fdp_FechaVencimientoTotal
# count                        13734  ...                     13748
# unique                           5  ...                     10419
# top                             CC  ...   2021-02-08 09:45:00.000
# freq                         13664  ...                        85
#
# [4 rows x 76 columns]

# %%
objetos.describe().T['unique'].astype('int').describe(percentiles=[0.25,0.5,0.75,0.85,0.90,0.95])
# Out:
# count       76.000000
# mean      2342.210526
# std       4372.155161
# min          2.000000
# 25%          4.000000
# 50%         34.000000
# 75%       2075.750000
# 85%       5465.500000
# 90%      11036.500000
# 95%      13715.000000
# max      13740.000000
# Name: unique, dtype: float64

# %%
# objetos['fgs_Nivel1'].value_counts()

# %%
lista_menores = []
lista_mayores = []
for i in objetos.columns:
  
  if objetos[i].nunique()<=100:
    display(objetos[i].value_counts())
    objetos[i].value_counts().plot.bar(title=i,figsize=(18,4))
    plt.show()
    lista_menores.append(i)
  else:
    lista_mayores.append(i)
# nota aparece un valor con un valor pero se deve a que despues de la limpieza se elimino 'Prestador de Servicios de Salud'
# Out:
# CC     13664
# TI        26
# NIT       24
# CE        19
# RC         1
# Name: fgs_SiglasDocumentoContacto, dtype: int64
# Contacto    10750
# Atención     2998
# Name: fgs_Tipificación, dtype: int64
# Beneficio Educativo - Regular               13254
# Beneficio Educativo - Inclusiva               449
# Beneficio Educativo - Colegios Ecopetrol       45
# Name: fgs_Nivel2, dtype: int64
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                   4195
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)                       2415
# Anticipo Trabajadores (Incluye BXC)                                           1807
# Anticipo Pensionados (Incluye Sustitutos)                                     1586
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)            1225
# Soporte Plataforma para Instituciones Educativas vía TIB                      1121
# Solicitud de educación inclusiva                                               414
# Inscripción solicitud becas Comité de Educación Convencional Activos           353
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)             303
# Inscripción casos especiales comité de educación convencional activos           99
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)           58
# Consulta Titulares Beneficio Eductivo - Desvinculados                           52
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      45
# Anticipo Pensionados Educación Inclusiva                                        20
# Anticipo Trabajadores Educación Inclusiva                                       15
# Inscripción casos especiales comité educación convencional pensionados          14
# Consulta de información relacionadas con reembolsos                             12
# Consulta sobre liquidación/pago préstamo para educación                         10
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)               3
# Consulta especialista beneficios atención PQRS                                   1
# Name: fgs_Nivel3, dtype: int64
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                   4195
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)                       2415
# Anticipo Trabajadores (Incluye BXC)                                           1807
# Anticipo Pensionados (Incluye Sustitutos)                                     1586
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)            1225
# Soporte Plataforma para Instituciones Educativas vía TIB                      1121
# Solicitud de educación inclusiva                                               414
# Inscripción solicitud becas Comité de Educación Convencional Activos           353
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)             303
# Inscripción casos especiales comité de educación convencional activos           99
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)           58
# Consulta Titulares Beneficio Eductivo - Desvinculados                           52
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      45
# Anticipo Pensionados Educación Inclusiva                                        20
# Anticipo Trabajadores Educación Inclusiva                                       15
# Inscripción casos especiales comité educación convencional pensionados          14
# Consulta de información relacionadas con reembolsos                             12
# Consulta sobre liquidación/pago préstamo para educación                         10
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)               3
# Consulta especialista beneficios atención PQRS                                   1
# Name: fgs_Nivel4, dtype: int64
# ACACIAS USAQUEN    26
# BARRANCAS          17
# COUNTRY CLUB        2
# CHICO               2
# CAOBOS SALAZAR      1
# B. EL CALLEJON      1
# Name: fgs_BarrioDireccion_01, dtype: int64
# Usaquén      46
# Chapinero     5
# Kennedy       1
# Comuna 01     1
# Name: fgs_LocalidadDireccion_01, dtype: int64
# SANTANDER          5175
# BOGOTA             3424
# BOLIVAR            1294
# ANTIOQUIA           883
# META                641
# CUNDINAMARCA        420
# N. DE SANTANDER     399
# HUILA               220
# MAGDALENA           174
# VALLE DEL CAUCA     160
# ATLANTICO           138
# CASANARE            121
# CESAR               112
# CALDAS              103
# PUTUMAYO             86
# BOYACA               79
# TOLIMA               79
# SUCRE                66
# RISARALDA            43
# CORDOBA              33
# NARIÑO               24
# QUINDIO              20
# ARAUCA               12
# SAN ANDRES           11
# CAUCA                 9
# CHOCO                 4
# CAQUETA               3
# VICHADA               1
# Name: fgs_DepartamentoDireccion_01, dtype: int64
# PILARES02@HOTMAIL.COM                       6
# secretaria.academica@uan.edu.co             3
# a.londono@losportales.edu.co                3
# PACHITOANTONIO2015@HOTMAIL.COM              3
# OSCEAM@HOTMAIL.COM                          2
# carlosuriberangel@hotmail.comHOTMAIL.COM    2
# katerinrosas@gmail.com                      2
# IPC7989@HOTMAIL.COM                         2
# mjarabaarevalo@gmail.com                    1
# ORLANDOVARGAS18@HOTMAIL.COM                 1
# CARLOSMARIOGOMEZN@HTMAIL.COM                1
# FAURE.EDGAR@GMAIL.COM                       1
# santhygrajales1999@gmail.com                1
# NONE                                        1
# WILLIAMR.VARGAS@ECOPETROL.COM.CO            1
# ongelogios@gmail.com                        1
# CARLOSANTIAGO7540@GMAIL.COM                 1
# NAJUA28@HOTMAIL.COM                         1
# MAPACO2001@GMAIL.COM                        1
# dinoralunaquintero@gmail.com                1
# JONNATHAN.PATINO@ECOPETROL.COM.CO           1
# luis.amortegui@hotmail.com                  1
# DANIEL.GIRALDO@ECOPETROL.COM.CO             1
# LUISFERNEYORTIZCUETO@GMAIL.COM              1
# TONIBENAVARRO@HOTMAIL.COM                   1
# zaharaaripollcastro@hotmail.com             1
# GILBERTO.ARIAS.TORREJANO@HOTMAIL.COM        1
# abcelmundodelosninos@hotmail.com            1
# CARLOSALIRIOR@GMAIL.COM                     1
# JOSEDA.RUIZ@ECOPETROL.COM.CO                1
# hernandobeltran48@hotmail.com               1
# paoladiaz199425@gmail.com                   1
# noregistra@ecopetrol.com.co                 1
# luzdaryc.88@hotmail.com                     1
# ELKIN.PINA@ECOPETROL.COM.CO                 1
# jesusrojasc47@gmail.com                     1
# carlos.acostalozano@gmail.com               1
# gustanriver@gmail.com                       1
# CARLOSAL.ARANGO@ECOPETROL.COM.CO            1
# gvallecorpas@gmail.com                      1
# TONY.DIAZ@ECOPETROL.COM.CO                  1
# LEGASA10@HOTMAIL.COM                        1
# JONATHAN.CACUA@ECOPETROL.COM.CO             1
# VICTOR.MOJICA@ECOPETROL.COM.CO              1
# jhonvargas49@hotmail.com                    1
# ORLANDOGONZALEZMARINO56@HOTMAIL.COM         1
# HERNAN.ESPINOSA@ECOPETROL.COM.CO            1
# vesgad123@gmail.com                         1
# notiene@notiene.com                         1
# EDGAR.MARIN@ECOPETROL.COM.CO                1
# FRANCISCO.ibanez15@HOTMAIL.COM              1
# Name: fgs_Email_02, dtype: int64
# adeco_nacional@yahoo.com             3
# noregistra@ecopetrol.com.co          2
# sinmail@hotmail.com                  2
# yolandavesga@gmail.com               1
# luis.renato.amortegui@hotmail.com    1
# GILBERTOARIAS2020@HOTMAIL.COM        1
# PIPE51098@GMAIL.COM                  1
# CARLOSED.ACOSTA@ECOPETROL.COM.CO     1
# adm.certificados@eafit.edu.co        1
# doraricoabogada@gmail.com            1
# luz.angarita@ecopetrol.com.co        1
# WRVARGAS16@HOTMAIL.COM               1
# noregistra@noregistra.com            1
# Name: fgs_Email_03, dtype: int64
# Email BackOffice           6220
# Telefónico                 5981
# Oficina De Atención CAL    1403
# Chat                        124
# Escrito Radicado             20
# Name: fmf_Canal, dtype: int64
# CENTRO ORIENTE       5309
# MAGDALENA MEDIO      3863
# NORTE                1859
# LLANOS ORIENTALES     864
# OCCIDENTE             615
# SUR                   370
# Name: ude_Regional, dtype: int64
# SANTANDER          5146
# BOGOTA             3049
# BOLIVAR            1390
# META                712
# N. DE SANTANDER     437
# CUNDINAMARCA        402
# ANTIOQUIA           284
# HUILA               250
# MAGDALENA           213
# VALLE DEL CAUCA     184
# CASANARE            132
# CESAR               125
# CALDAS              109
# PUTUMAYO             90
# ATLANTICO            88
# TOLIMA               88
# SUCRE                80
# BOYACA               63
# RISARALDA            42
# CORDOBA              31
# QUINDIO              21
# NARIÑO               17
# ARAUCA                9
# Name: ude_DepartamentoCliente, dtype: int64
# COLOMBIA    12962
# Colombia      786
# Name: ude_PaisCliente, dtype: int64
# Transacciones        10135
# No Aplica             2896
# Puesto de Trabajo      717
# Name: SistemaPago, dtype: int64
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                   4195
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)                       2415
# Anticipo Trabajadores (Incluye BXC)                                           1807
# Anticipo Pensionados (Incluye Sustitutos)                                     1586
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)            1225
# Soporte Plataforma para Instituciones Educativas vía TIB                      1121
# Solicitud de educación inclusiva                                               414
# Inscripción solicitud becas Comité de Educación Convencional Activos           353
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)             303
# Inscripción casos especiales comité de educación convencional activos           99
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)           58
# Consulta Titulares Beneficio Eductivo - Desvinculados                           52
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      45
# Anticipo Pensionados Educación Inclusiva                                        20
# Anticipo Trabajadores Educación Inclusiva                                       15
# Inscripción casos especiales comité educación convencional pensionados          14
# Consulta de información relacionadas con reembolsos                             12
# Consulta sobre liquidación/pago préstamo para educación                         10
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)               3
# Consulta especialista beneficios atención PQRS                                   1
# Name: ServicioPortafolio, dtype: int64
# Cerrado        13718
# Escalado          27
# Devuelto           2
# Solucionado        1
# Name: fdp_NombreEstado, dtype: int64
# Nivel1    10752
# Nivel2     2996
# Name: fdp_NivelEstado, dtype: int64
# LEIDY TATIANA CARREÑO PEREZ              621
# ALVARO MARIACA LEAL                      618
# LEYDA ROCIO MORENO YARA                  541
# DIANA MILENA GUERRERO MELLIZO            537
# GILBERTO SUÁREZ                          536
# LEYDI YASMIN CASTRO MORANTES             529
# WILLIAM GUILLERMO FERRUCHO FERRUCHO      511
# JIMMY SEBASTIAN GORDILLO GAMBOA          502
# MIRYAM NATALIA MORENO BAYONA             438
# INGRID GERALDIN OBANDO PEÑA              435
# YEIMY PATRICIA LOZADA ALFONSO            428
# ANDRES FELIPE BELTRAN URIBE              427
# ANGIE PAOLA LUENGAS TUNJANO              427
# EDWAR MAURICIO CRUZ                      419
# SAYAN MONIQUE ESPINOSA CIFUENTES         389
# MARIA FERNANDA DURAN HERRERA             385
# JUSTINE MARUETH EBRAT PEÑA               367
# ANDREA ANGELICA SABOGAL RODRIGUEZ        365
# JHON JAIRO GOMEZ SALAZAR                 350
# ANGELICA VALENTINA CAMARGO MURCIA        331
# JONATHAN DARIO DORIA DIAZ                329
# LIGIA OSORIO HERNÁNDEZ                   321
# REINALDO  HUDGSON GUERRERO               305
# ELIANA ELIZABETH ESQUIVEL                301
# MICHAEL JAIR ESPINOSA BUITRAGO           298
# BIANEY  DIAZ                             290
# ANDREA DAZA MOSQUERA                     282
# ANGIE CAROLINA ANGULO DELGADO            271
# LUZ AMPARO QUINTANILLA ARDILA            246
# ERIKA  ANDREA BERNA CASTRO               227
# SANDRA MILENA FUENTES MONGUI             200
# REINALDO HUDGSON GUERRERO                188
# LIGIA OSORIO HERNÁNDEZ                   184
# AIDA ALEXANDRA RODRIGUEZ AMAYA           170
# EDNA ROCIO RAMIREZ RUBIO                 139
# JENNY LILIANA GOMEZ VARGAS               125
# HEIDY  YOHANA\t GARCIA  GARCIA           118
# GEYDY  MARLIDA\t PAJOY  TITIMBO          111
# MELINA BLANCO TIRADO                     103
# ÍNGRID NATALIA\t MURCIA  MARTIN           85
# MAGDA VIVIAN CASTILLO PAZ                 75
# RUGGIERY BELEÑO LASCARRO                  48
# YARI ALEXANDRA GARZON QUEVEDO             44
# JOSE FIGUEREDO AMORTEGUI CRIOLLO          43
# LUZ ANGELA USUGA                          20
# BIANEY DIAZ                               20
# ASTRID NATALIA\t HORTUA  JIMENEZ          14
# ANA CELIA NIÑO ROJAS                       6
# KEMER CRISTANCHO SOTO                      6
# JOHANA ANDREA SOLIS MORRA\t                5
# FRANCY ELENA FORERO CORREA                 4
# FUENTES SANTAMARIA JHON JAIRO              3
# JOSE FERNANDO BRAVO FRANCO                 2
# YENI PATRICIA MORALES WILCHES              2
# SULMIRA GARCES MORENO\t                    2
# ROSA ELENA BARBOSA GOMEZ                   1
# MARCELA LUTFALLAH ELIAS SARRAF             1
# SONIA  ESPERANZA CUINEME   RUBIANO\t       1
# MARIA  FERNANDA MARTINEZ GAITAN            1
# SANABRIA PICO ROMAN ADRIANO                1
# Name: fdp_NombreUsuarioCreacion, dtype: int64
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# Asesor de Servicio Contact Center          10189
# Asesor de Servicio Front Ecopetrol          2842
# Asesor de Servicio Front Contact Center      717
# Name: GrupoRolCreacion, dtype: int64
# No Aplica    7508
# Cumple       3639
# No Cumple    2601
# Name: Cumple_Objetivo_SolicitadoRegistrado, dtype: int64
# Cumple       13252
# No Cumple      494
# No Aplica        2
# Name: Cumple_Objetivo_RegistradoEscalado, dtype: int64
# Equipo Plan Educacional                       1760
# Profesional Transferencia de Información       681
# Anticipos – Equipo Plan Educacional            269
# Profesional Educación Inclusiva                253
# Profdecolegios propiedad de Ecopetrol S.A.      28
# Equipo Beneficio Educativo - Desvinculados       5
# Name: fdp_NombreGrupoEscalamientoN2, dtype: int64
# CLAUDIA CONSUELO OSTOS RUIZ       846
# JENNIFERCARDOZO CARDOZO DUQUE     578
# NANCY CAICEDO SALINAS             407
# ASTRID GARZON RUIDIAZ             360
# MARTHA IRENE QUINTERO PABON       251
# LUCY STELLA CABRERA PÉREZ         206
# YULI SANDOVAL                     158
# LUZ ANGELA USUGA                  127
# MARIA FERNANDA ROJAS               28
# BIANEY DIAZ                         8
# BIANEY  DIAZ                        1
# Lady Lorena Coy Rozo                1
# ALVARO MARIACA LEAL                 1
# Name: fdp_NombreUsuarioEscalamientoN2, dtype: int64
# Asesor solucionador Ecopetrol         2265
# Asesor de Servicio Front Ecopetrol     707
# Name: GrupoRolEscalamientoN2, dtype: int64
# No Aplica    10779
# Cumple        2856
# No Cumple      113
# Name: Cumple_Objetivo_EnNivel2, dtype: int64
# JIMMY SEBASTIAN GORDILLO GAMBOA       18
# SANDRA MILENA FUENTES MONGUI          16
# MARIA FERNANDA DURAN HERRERA          13
# ALVARO MARIACA LEAL                   12
# LIGIA OSORIO HERNÁNDEZ                12
# REINALDO  HUDGSON GUERRERO            11
# DIANA MILENA GUERRERO MELLIZO         10
# GILBERTO SUÁREZ                        9
# LEYDI YASMIN CASTRO MORANTES           9
# LEIDY TATIANA CARREÑO PEREZ            8
# ANDRES FELIPE BELTRAN URIBE            7
# REINALDO HUDGSON GUERRERO              7
# EDNA ROCIO RAMIREZ RUBIO               6
# LIGIA OSORIO HERNÁNDEZ                 6
# INGRID GERALDIN OBANDO PEÑA            6
# MAGDA VIVIAN CASTILLO PAZ              6
# AIDA ALEXANDRA RODRIGUEZ AMAYA         5
# SAYAN MONIQUE ESPINOSA CIFUENTES       5
# BIANEY  DIAZ                           5
# ANDREA DAZA MOSQUERA                   5
# MIRYAM NATALIA MORENO BAYONA           5
# ELIANA ELIZABETH ESQUIVEL              4
# EDWAR MAURICIO CRUZ                    4
# LUZ AMPARO QUINTANILLA ARDILA          3
# JHON JAIRO GOMEZ SALAZAR               3
# RUGGIERY BELEÑO LASCARRO               3
# BIANEY DIAZ                            3
# ANGIE PAOLA LUENGAS TUNJANO            3
# HEIDY  YOHANA\t GARCIA  GARCIA         3
# LEYDA ROCIO MORENO YARA                2
# JUSTINE MARUETH EBRAT PEÑA             2
# ANDREA ANGELICA SABOGAL RODRIGUEZ      2
# GEYDY  MARLIDA\t PAJOY  TITIMBO        1
# JONATHAN DARIO DORIA DIAZ              1
# MICHAEL JAIR ESPINOSA BUITRAGO         1
# ERIKA  ANDREA BERNA CASTRO             1
# LUZ ANGELA USUGA                       1
# MELINA BLANCO TIRADO                   1
# ANGIE CAROLINA ANGULO DELGADO          1
# JOSE FIGUEREDO AMORTEGUI CRIOLLO       1
# Name: fdp_NombreUsuarioDevolucion, dtype: int64
# Asesor de Servicio Contact Center          124
# Asesor de Servicio Front Ecopetrol          70
# Asesor de Servicio Front Contact Center     27
# Name: GrupoRolDevolucion, dtype: int64
# Escalado al responsable de solución equivocado                                     73
# No se encuentra formato de soporte o no es legible                                 41
# Recepción de solicitud incompleta  no se validaron correctamente los requisitos    38
# La solución depende de otro nivel de soporte                                       15
# Escalado al responsable equivocado                                                 10
# No adjunto soportes                                                                 2
# Name: fdp_MotivoDevolucion, dtype: int64
# Grupo Primer Nivel Personal                   10750
# Equipo Plan Educacional                        1734
# Profesional Transferencia de Información        681
# Anticipos – Equipo Plan Educacional             268
# Profesional Educación Inclusiva                 253
# Profdecolegios propiedad de Ecopetrol S.A.       28
# Equipo Beneficio Educativo - Desvinculados        5
# Name: fdp_NombreGrupoSolucion, dtype: int64
# LEIDY TATIANA CARREÑO PEREZ             579
# JENNIFERCARDOZO CARDOZO DUQUE           543
# LEYDA ROCIO MORENO YARA                 525
# CLAUDIA CONSUELO OSTOS RUIZ             477
# WILLIAM GUILLERMO FERRUCHO FERRUCHO     471
#                                        ...
# LEIDY TATIANA CARREÑO PEREZ               1
# MARCELA LUTFALLAH ELIAS SARRAF            1
# ROSA ELENA BARBOSA GOMEZ                  1
# MARIA  FERNANDA MARTINEZ GAITAN           1
# FRANCY ELENA FORERO CORREA                1
# Name: fdp_NombreUsuarioSolucion, Length: 67, dtype: int64
# Asesor de Servicio Contact Center          8286
# Asesor de Servicio Front Ecopetrol         2704
# Asesor solucionador Ecopetrol              2274
# Asesor de Servicio Front Contact Center     455
# Name: GrupoRolSolucion, dtype: int64
# Nivel1    10750
# Nivel2     2969
# Name: fdp_NivelSolucion, dtype: int64
# Cumple       13717
# No Aplica       30
# No Cumple        1
# Name: Cumple_Objetivo_SolucionadoCerrado, dtype: int64
# Grupo Primer Nivel Personal                   10750
# Equipo Plan Educacional                        1733
# Profesional Transferencia de Información        681
# Anticipos – Equipo Plan Educacional             268
# Profesional Educación Inclusiva                 253
# Profdecolegios propiedad de Ecopetrol S.A.       28
# Equipo Beneficio Educativo - Desvinculados        5
# Name: fdp_NombreGrupoCierre, dtype: int64
# LEIDY TATIANA CARREÑO PEREZ              579
# JENNIFERCARDOZO CARDOZO DUQUE            543
# LEYDA ROCIO MORENO YARA                  525
# CLAUDIA CONSUELO OSTOS RUIZ              477
# WILLIAM GUILLERMO FERRUCHO FERRUCHO      471
#                                         ...
# SONIA  ESPERANZA CUINEME   RUBIANO\t       1
# LEIDY TATIANA CARREÑO PEREZ                1
# MARCELA LUTFALLAH ELIAS SARRAF             1
# MARIA  FERNANDA MARTINEZ GAITAN            1
# FRANCY ELENA FORERO CORREA                 1
# Name: fdp_NombreUsuarioCierre, Length: 66, dtype: int64
# Asesor de Servicio Contact Center          8254
# Asesor de Servicio Front Ecopetrol         2703
# Asesor solucionador Ecopetrol              2306
# Asesor de Servicio Front Contact Center     455
# Name: GrupoRolCierre, dtype: int64
# Nivel1    10750
# Nivel2     2968
# Name: fdp_NivelCierre, dtype: int64
# Grupo Primer Nivel Personal                   10752
# Equipo Plan Educacional                        1760
# Profesional Transferencia de Información        681
# Anticipos – Equipo Plan Educacional             269
# Profesional Educación Inclusiva                 253
# Profdecolegios propiedad de Ecopetrol S.A.       28
# Equipo Beneficio Educativo - Desvinculados        5
# Name: fdp_NombreGrupoGestionActual, dtype: int64
# LEIDY TATIANA CARREÑO PEREZ              579
# JENNIFERCARDOZO CARDOZO DUQUE            543
# LEYDA ROCIO MORENO YARA                  525
# CLAUDIA CONSUELO OSTOS RUIZ              477
# WILLIAM GUILLERMO FERRUCHO FERRUCHO      471
#                                         ...
# SONIA  ESPERANZA CUINEME   RUBIANO\t       1
# LEIDY TATIANA CARREÑO PEREZ                1
# MARCELA LUTFALLAH ELIAS SARRAF             1
# MARIA  FERNANDA MARTINEZ GAITAN            1
# FRANCY ELENA FORERO CORREA                 1
# Name: fdp_NombreUsuarioGestionActual, Length: 66, dtype: int64
# Asesor de Servicio Contact Center          8255
# Asesor de Servicio Front Ecopetrol         2732
# Asesor solucionador Ecopetrol              2306
# Asesor de Servicio Front Contact Center     455
# Name: GrupoRolGestionActual, dtype: int64
# Escalado al responsable de solución equivocado    1
# La solución depende de otro nivel de soporte      1
# Name: fdp_MotivoGestionActual, dtype: int64
# Nivel1    10752
# Nivel2     2996
# Name: fdp_NivelGestionActual, dtype: int64
# Fecha Superior a la fecha de creación o Fecha Nula      4107
# Fecha de Modificación Menor a la del estado anterior    2679
# Name: TipoAjuste, dtype: int64

# %%
for i in numeros.columns:
  plt.figure(figsize=(14,4))
  display(numeros[i].describe(percentiles=[0.05,0.25,0.5,0.75,0.95,0.99]))
  plt.subplot(1,2,1)
  numeros[i].plot.hist()
  plt.subplot(1,2,2)
  numeros[i].plot.hist()
  plt.yscale('log')
  
  
  plt.show()
# Out:
# count    1.374800e+04
# mean     1.912853e+08
# std      4.412214e+08
# min      1.000000e+03
# 5%       5.579628e+06
# 25%      1.388002e+07
# 50%      7.200537e+07
# 75%      9.134069e+07
# 95%      1.096238e+09
# 99%      1.142720e+09
# max      9.010660e+09
# Name: fgs_NumeroDocumContacto, dtype: float64
# count    13748.000000
# mean      4854.114926
# std         11.461088
# min       4831.000000
# 5%        4837.000000
# 25%       4839.000000
# 50%       4859.000000
# 75%       4861.000000
# 95%       4872.000000
# 99%       4872.000000
# max       4874.000000
# Name: fgs_IdTipificacionGestionDetalle, dtype: float64
# count    1.374800e+04
# mean     1.050014e+09
# std      1.446716e+09
# min      2.000000e+06
# 5%       2.345000e+06
# 25%      1.846617e+07
# 50%      7.620365e+07
# 75%      3.105888e+09
# 95%      3.202252e+09
# 99%      3.222417e+09
# max      3.512344e+09
# Name: fgs_Telefono_01, dtype: float64
# count    2.660000e+02
# mean     8.873552e+08
# std      1.392827e+09
# min      2.000000e+06
# 5%       2.345000e+06
# 25%      6.564960e+06
# 50%      1.834072e+07
# 75%      3.006113e+09
# 95%      3.183391e+09
# 99%      3.206259e+09
# max      3.507541e+09
# Name: fgs_Telefono_02, dtype: float64
# count    1.350000e+02
# mean     8.125224e+08
# std      1.354936e+09
# min      2.345000e+06
# 5%       2.345000e+06
# 25%      6.302574e+06
# 50%      4.333486e+07
# 75%      1.545971e+09
# 95%      3.188487e+09
# 99%      3.218807e+09
# max      3.233468e+09
# Name: fgs_Telefono_03, dtype: float64
# count    4.900000e+01
# mean     4.009778e+08
# std      1.030939e+09
# min      2.291399e+06
# 5%       2.345000e+06
# 25%      6.208631e+06
# 50%      1.234500e+07
# 75%      5.631044e+07
# 95%      3.132461e+09
# 99%      3.150114e+09
# max      3.153725e+09
# Name: fgs_Telefono_04, dtype: float64
# count     13748.00000
# mean      37509.84245
# std       71467.58521
# min           0.00000
# 5%            0.00000
# 25%           0.00000
# 50%           0.00000
# 75%           0.00000
# 95%      206732.20000
# 99%      215327.27000
# max      261201.00000
# Name: fdp_IdPqr, dtype: float64
# count    13748.000000
# mean         1.002764
# std          0.070277
# min          1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# 95%          1.000000
# 99%          1.000000
# max          5.000000
# Name: fdp_IdEstado, dtype: float64
# count    3156.000000
# mean      150.652725
# std        53.134627
# min        26.000000
# 5%         26.000000
# 25%       137.000000
# 50%       137.000000
# 75%       211.000000
# 95%       216.000000
# 99%       216.000000
# max       217.000000
# Name: fdp_IdFlujo, dtype: float64
# count    13748.000000
# mean         2.308918
# std          1.263237
# min          0.000000
# 5%           0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          3.000000
# 95%          3.000000
# 99%          3.000000
# max          3.000000
# Name: fdp_IdHistoricoPqrCreacion, dtype: float64
# count    13748.000000
# mean       741.165624
# std       1304.350690
# min         45.000000
# 5%          52.000000
# 25%        106.000000
# 50%        153.000000
# 75%        667.000000
# 95%       2901.000000
# 99%       7809.000000
# max       8082.000000
# Name: fdp_IdUsuarioCreacion, dtype: float64
# count    1.374800e+04
# mean     8.812888e+08
# std      1.734778e+09
# min      1.388963e+07
# 5%       3.021085e+07
# 25%      5.290282e+07
# 50%      1.002524e+09
# 75%      1.022981e+09
# 95%      1.100482e+09
# 99%      9.128158e+09
# max      9.128158e+09
# Name: fdp_UsuarioCreacion, dtype: float64
# count    13748.000000
# mean         1.724469
# std          1.242722
# min          1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# 95%          4.000000
# 99%          4.000000
# max          4.000000
# Name: CodigoGrupoRolCreacion, dtype: float64
# count     6240.000000
# mean       296.726923
# std        491.990115
# min          0.000000
# 5%           0.000000
# 25%          4.000000
# 50%         92.000000
# 75%        505.000000
# 95%       1080.000000
# 99%       2254.300000
# max      10610.000000
# Name: T_Real_SolicitadoRegistrado, dtype: float64
# count    13746.000000
# mean       139.450022
# std       1029.073902
# min          0.000000
# 5%           0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%          0.000000
# 99%       5136.250000
# max      21475.000000
# Name: T_Real_RegistradoEscalado, dtype: float64
# count      2996.000000
# mean     463620.505674
# std      135107.626033
# min      275423.000000
# 5%       285805.000000
# 25%      319907.750000
# 50%      455138.000000
# 75%      602545.000000
# 95%      632665.250000
# 99%      747388.600000
# max      806371.000000
# Name: fdp_IdHistoricoPqrEscalamientoN2, dtype: float64
# count    2996.000000
# mean      196.109813
# std        44.486620
# min        99.000000
# 5%         99.000000
# 25%       181.000000
# 50%       181.000000
# 75%       249.000000
# 95%       253.000000
# 99%       253.000000
# max       253.000000
# Name: fdp_IdGrupoEscalamientoN2, dtype: float64
# count    2996.000000
# mean      184.929239
# std        67.541583
# min        48.000000
# 5%         48.000000
# 25%       166.000000
# 50%       166.000000
# 75%       249.000000
# 95%       254.000000
# 99%       254.000000
# max       831.000000
# Name: fdp_IdDetalleFlujoEscalamientoN2, dtype: float64
# count    2972.000000
# mean      318.110363
# std        79.501649
# min        31.000000
# 5%        281.000000
# 25%       281.000000
# 50%       283.000000
# 75%       321.000000
# 95%       533.000000
# 99%       535.000000
# max       535.000000
# Name: fdp_IdUsuarioEscalamientoN2, dtype: float64
# count    2.972000e+03
# mean     2.431756e+08
# std      3.802506e+08
# min      4.032626e+07
# 5%       5.201427e+07
# 25%      5.201427e+07
# 50%      5.983548e+07
# 75%      6.346556e+07
# 95%      1.016001e+09
# 99%      1.016001e+09
# max      1.030571e+09
# Name: fdp_UsuarioEscalamientoN2, dtype: float64
# count    2972.000000
# mean        5.524226
# std         0.851722
# min         4.000000
# 5%          4.000000
# 25%         6.000000
# 50%         6.000000
# 75%         6.000000
# 95%         6.000000
# 99%         6.000000
# max         6.000000
# Name: CodigoGrupoRolEscalamientoN2, dtype: float64
# count     2996.000000
# mean     11788.618158
# std       2524.338124
# min       4320.000000
# 5%        8100.000000
# 25%       8640.000000
# 50%      13500.000000
# 75%      13500.000000
# 95%      13500.000000
# 99%      13500.000000
# max      13500.000000
# Name: T_Objetivo_EnNivel2, dtype: float64
# count    13561.000000
# mean      1384.678416
# std       3291.739678
# min          0.000000
# 5%           0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%       8446.000000
# 99%      13159.800000
# max      71820.000000
# Name: T_Real_EnNivel2, dtype: float64
# count       221.000000
# mean     504559.416290
# std      137153.113795
# min      288842.000000
# 5%       315300.000000
# 25%      351777.000000
# 50%      486347.000000
# 75%      630661.000000
# 95%      688027.000000
# 99%      734875.400000
# max      800727.000000
# Name: fdp_IdHistoricoPqrDevolucion, dtype: float64
# count     221.000000
# mean      795.932127
# std        52.190820
# min       706.000000
# 5%        706.000000
# 25%       738.000000
# 50%       831.000000
# 75%       831.000000
# 95%       831.000000
# 99%       831.000000
# max      1022.000000
# Name: fdp_IdDetalleFlujoDevolucion, dtype: float64
# count     221.000000
# mean      838.484163
# std      1270.541165
# min        52.000000
# 5%         66.000000
# 25%       115.000000
# 50%       186.000000
# 75%       715.000000
# 95%      2901.000000
# 99%      6846.000000
# max      7809.000000
# Name: fdp_IdUsuarioDevolucion, dtype: float64
# count    2.210000e+02
# mean     1.307710e+09
# std      2.412470e+09
# min      1.388963e+07
# 5%       3.021085e+07
# 25%      5.299017e+07
# 50%      1.015424e+09
# 75%      1.031165e+09
# 95%      9.128158e+09
# 99%      9.128158e+09
# max      9.128158e+09
# Name: fdp_UsuarioDevolucion, dtype: float64
# count    221.000000
# mean       2.194570
# std        1.386024
# min        1.000000
# 5%         1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        4.000000
# 95%        4.000000
# 99%        4.000000
# max        4.000000
# Name: CodigoGrupoRolDevolucion, dtype: float64
# count     13719.000000
# mean     113155.980757
# std      219043.295102
# min           0.000000
# 5%            4.000000
# 25%           4.000000
# 50%           4.000000
# 75%           4.000000
# 95%      643885.900000
# 99%      686093.020000
# max      838907.000000
# Name: fdp_IdHistoricoPqrSolucion, dtype: float64
# count    13719.000000
# mean        47.970406
# std         95.330934
# min          0.000000
# 5%           0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%        253.000000
# 99%        477.000000
# max        477.000000
# Name: fdp_IdGrupoSolucion, dtype: float64
# count    3127.000000
# mean      216.459866
# std       150.567870
# min        48.000000
# 5%         48.000000
# 25%       166.000000
# 50%       166.000000
# 75%       254.000000
# 95%       706.000000
# 99%       831.000000
# max       831.000000
# Name: fdp_IdDetalleFlujoSolucion, dtype: float64
# count    13719.000000
# mean       686.107296
# std       1235.660790
# min         45.000000
# 5%          58.000000
# 25%        115.000000
# 50%        186.000000
# 75%        533.000000
# 95%       2556.000000
# 99%       7808.000000
# max       8082.000000
# Name: fdp_IdUsuarioSolucion, dtype: float64
# count    1.371900e+04
# mean     7.098806e+08
# std      1.488151e+09
# min      1.388963e+07
# 5%       3.792905e+07
# 25%      5.283509e+07
# 50%      8.001099e+07
# 75%      1.019061e+09
# 95%      1.082312e+09
# 99%      9.128158e+09
# max      9.128158e+09
# Name: fdp_UsuarioSolucion, dtype: float64
# count    13719.000000
# mean         2.486406
# std          1.959928
# min          1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          4.000000
# 95%          6.000000
# 99%          6.000000
# max          6.000000
# Name: CodigoGrupoRolSolucion, dtype: float64
# count    13718.000000
# mean         1.349030
# std         46.007303
# min          0.000000
# 5%           0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%          0.000000
# 99%          0.000000
# max       3145.000000
# Name: T_Real_SolucionadoCerrado, dtype: float64
# count     13718.000000
# mean     113121.553506
# std      219011.456128
# min           0.000000
# 5%            4.000000
# 25%           4.000000
# 50%           4.000000
# 75%           4.000000
# 95%      643891.350000
# 99%      686083.300000
# max      838908.000000
# Name: fdp_IdHistoricoPqrCierre, dtype: float64
# count    13718.000000
# mean        47.960709
# std         95.327642
# min          0.000000
# 5%           0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%        253.000000
# 99%        477.000000
# max        477.000000
# Name: fdp_IdGrupoCierre, dtype: float64
# count    3126.000000
# mean      216.476008
# std       150.589253
# min        48.000000
# 5%         48.000000
# 25%       166.000000
# 50%       166.000000
# 75%       254.000000
# 95%       706.000000
# 99%       831.000000
# max       831.000000
# Name: fdp_IdDetalleFlujoCierre, dtype: float64
# count    13718.000000
# mean       686.108179
# std       1235.705826
# min         45.000000
# 5%          58.000000
# 25%        115.000000
# 50%        186.000000
# 75%        533.000000
# 95%       2556.000000
# 99%       7808.000000
# max       8082.000000
# Name: fdp_IdUsuarioCierre, dtype: float64
# count    1.371800e+04
# mean     7.099296e+08
# std      1.488194e+09
# min      1.388963e+07
# 5%       3.792905e+07
# 25%      5.283509e+07
# 50%      8.001099e+07
# 75%      1.019061e+09
# 95%      1.082763e+09
# 99%      9.128158e+09
# max      9.128158e+09
# Name: fdp_UsuarioCierre, dtype: float64
# count    13718.000000
# mean         2.497959
# std          1.965946
# min          1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          4.000000
# 95%          6.000000
# 99%          6.000000
# max          6.000000
# Name: CodigoGrupoRolCierre, dtype: float64
# count     2996.000000
# mean     11791.682243
# std       2520.838555
# min       4320.000000
# 5%        8100.000000
# 25%       8640.000000
# 50%      13500.000000
# 75%      13500.000000
# 95%      13500.000000
# 99%      13500.000000
# max      13500.000000
# Name: T_Objetivo_Total, dtype: float64
# count     13748.000000
# mean     113904.194501
# std      219463.598737
# min           0.000000
# 5%            4.000000
# 25%           4.000000
# 50%           4.000000
# 75%           4.000000
# 95%      644333.100000
# 99%      686104.480000
# max      838908.000000
# Name: fdp_IdHistoricoPqrGestionActual, dtype: float64
# count    13748.000000
# mean        48.288115
# std         95.546604
# min          0.000000
# 5%           0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# 95%        253.000000
# 99%        477.000000
# max        477.000000
# Name: fdp_IdGrupoGestionActual, dtype: float64
# count    3156.000000
# mean      216.380228
# std       150.770273
# min        48.000000
# 5%         48.000000
# 25%       166.000000
# 50%       166.000000
# 75%       254.000000
# 95%       706.000000
# 99%       831.000000
# max       831.000000
# Name: fdp_IdDetalleFlujoGestionActual, dtype: float64
# count    13748.00000
# mean       685.90515
# std       1234.33541
# min         45.00000
# 5%          58.00000
# 25%        115.00000
# 50%        186.00000
# 75%        533.00000
# 95%       2556.00000
# 99%       7808.00000
# max       8082.00000
# Name: fdp_IdUsuarioGestionActual, dtype: float64
# count    1.374800e+04
# mean     7.080941e+08
# std      1.486923e+09
# min      1.388963e+07
# 5%       3.792905e+07
# 25%      5.283509e+07
# 50%      8.001099e+07
# 75%      1.019061e+09
# 95%      1.081409e+09
# 99%      9.128158e+09
# max      9.128158e+09
# Name: fdp_UsuarioGestionActual, dtype: float64
# count    13748.000000
# mean         2.501018
# std          1.965050
# min          1.000000
# 5%           1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          4.000000
# 95%          6.000000
# 99%          6.000000
# max          6.000000
# Name: CodigoGrupoRolGestionActual, dtype: float64

# %% [markdown]
# # Nuevos analisis

# %%
niveles =df_Registros_P[['fgs_Nivel2','fgs_Nivel3','fgs_Nivel4']].copy()
niveles.head(2)
# Out:
#                       fgs_Nivel2  ...                                         fgs_Nivel4
# 0  Beneficio Educativo - Regular  ...  Legal / Reconocimiento Pensionados (Incluye Su...
# 1  Beneficio Educativo - Regular  ...  Legal / Reconocimiento Pensionados (Incluye Su...
#
# [2 rows x 3 columns]

# %%
niveles['union']  =  niveles['fgs_Nivel2']+'_*_'+niveles['fgs_Nivel3']+'_*_'+niveles['fgs_Nivel4']
niveles['union'].value_counts()
# Out:
# Beneficio Educativo - Regular_*_Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)_*_Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                                             4195
# Beneficio Educativo - Regular_*_Legal / Reconocimiento Pensionados (Incluye Sustitutos)_*_Legal / Reconocimiento Pensionados (Incluye Sustitutos)                                                     2415
# Beneficio Educativo - Regular_*_Anticipo Trabajadores (Incluye BXC)_*_Anticipo Trabajadores (Incluye BXC)                                                                                             1807
# Beneficio Educativo - Regular_*_Anticipo Pensionados (Incluye Sustitutos)_*_Anticipo Pensionados (Incluye Sustitutos)                                                                                 1586
# Beneficio Educativo - Regular_*_Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)_*_Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)                               1225
# Beneficio Educativo - Regular_*_Soporte Plataforma para Instituciones Educativas vía TIB_*_Soporte Plataforma para Instituciones Educativas vía TIB                                                   1121
# Beneficio Educativo - Inclusiva_*_Solicitud de educación inclusiva_*_Solicitud de educación inclusiva                                                                                                  414
# Beneficio Educativo - Regular_*_Inscripción solicitud becas Comité de Educación Convencional Activos_*_Inscripción solicitud becas Comité de Educación Convencional Activos                            353
# Beneficio Educativo - Regular_*_Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)_*_Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)                                303
# Beneficio Educativo - Regular_*_Inscripción casos especiales comité de educación convencional activos_*_Inscripción casos especiales comité de educación convencional activos                           99
# Beneficio Educativo - Regular_*_Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)_*_Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)                           58
# Beneficio Educativo - Regular_*_Consulta Titulares Beneficio Eductivo - Desvinculados_*_Consulta Titulares Beneficio Eductivo - Desvinculados                                                           52
# Beneficio Educativo - Colegios Ecopetrol_*_Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A._*_Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      45
# Beneficio Educativo - Inclusiva_*_Anticipo Pensionados Educación Inclusiva_*_Anticipo Pensionados Educación Inclusiva                                                                                   20
# Beneficio Educativo - Inclusiva_*_Anticipo Trabajadores Educación Inclusiva_*_Anticipo Trabajadores Educación Inclusiva                                                                                 15
# Beneficio Educativo - Regular_*_Inscripción casos especiales comité educación convencional pensionados_*_Inscripción casos especiales comité educación convencional pensionados                         14
# Beneficio Educativo - Regular_*_Consulta de información relacionadas con reembolsos_*_Consulta de información relacionadas con reembolsos                                                               12
# Beneficio Educativo - Regular_*_Consulta sobre liquidación/pago préstamo para educación_*_Consulta sobre liquidación/pago préstamo para educación                                                       10
# Beneficio Educativo - Regular_*_Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)_*_Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)                                  3
# Beneficio Educativo - Regular_*_Consulta especialista beneficios atención PQRS_*_Consulta especialista beneficios atención PQRS                                                                          1
# Name: union, dtype: int64

# %%
niveles['union']  =niveles['fgs_Nivel3']+'_*_'+niveles['fgs_Nivel4']
niveles['union'].value_counts()
# Out:
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)_*_Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                                  4195
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)_*_Legal / Reconocimiento Pensionados (Incluye Sustitutos)                                          2415
# Anticipo Trabajadores (Incluye BXC)_*_Anticipo Trabajadores (Incluye BXC)                                                                                  1807
# Anticipo Pensionados (Incluye Sustitutos)_*_Anticipo Pensionados (Incluye Sustitutos)                                                                      1586
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)_*_Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)                    1225
# Soporte Plataforma para Instituciones Educativas vía TIB_*_Soporte Plataforma para Instituciones Educativas vía TIB                                        1121
# Solicitud de educación inclusiva_*_Solicitud de educación inclusiva                                                                                         414
# Inscripción solicitud becas Comité de Educación Convencional Activos_*_Inscripción solicitud becas Comité de Educación Convencional Activos                 353
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)_*_Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)                     303
# Inscripción casos especiales comité de educación convencional activos_*_Inscripción casos especiales comité de educación convencional activos                99
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)_*_Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)                58
# Consulta Titulares Beneficio Eductivo - Desvinculados_*_Consulta Titulares Beneficio Eductivo - Desvinculados                                                52
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A._*_Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      45
# Anticipo Pensionados Educación Inclusiva_*_Anticipo Pensionados Educación Inclusiva                                                                          20
# Anticipo Trabajadores Educación Inclusiva_*_Anticipo Trabajadores Educación Inclusiva                                                                        15
# Inscripción casos especiales comité educación convencional pensionados_*_Inscripción casos especiales comité educación convencional pensionados              14
# Consulta de información relacionadas con reembolsos_*_Consulta de información relacionadas con reembolsos                                                    12
# Consulta sobre liquidación/pago préstamo para educación_*_Consulta sobre liquidación/pago préstamo para educación                                            10
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)_*_Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)                       3
# Consulta especialista beneficios atención PQRS_*_Consulta especialista beneficios atención PQRS                                                               1
# Name: union, dtype: int64

# %%
niveles['union'].value_counts().plot.barh(title = ' Diferentes niveles',figsize = (10,14))

# %%
niveles['fgs_Nivel3'].value_counts()
# Out:
# Legal / Reconocimiento Trabajadores (Incluye Bachiller ECP)                   4195
# Legal / Reconocimiento Pensionados (Incluye Sustitutos)                       2415
# Anticipo Trabajadores (Incluye BXC)                                           1807
# Anticipo Pensionados (Incluye Sustitutos)                                     1586
# Consultas Titulares Beneficio Educativo (No Incluye Bachiller ECP)            1225
# Soporte Plataforma para Instituciones Educativas vía TIB                      1121
# Solicitud de educación inclusiva                                               414
# Inscripción solicitud becas Comité de Educación Convencional Activos           353
# Reintegro de dinero trabajadores Educación (Incluye Bachiller ECP)             303
# Inscripción casos especiales comité de educación convencional activos           99
# Reintegro de dinero Pensionados Educación (Incluye sustitutos y Auto)           58
# Consulta Titulares Beneficio Eductivo - Desvinculados                           52
# Solicitud / Consulta / revisión pagos colegios propiedad de Ecopetrol S.A.      45
# Anticipo Pensionados Educación Inclusiva                                        20
# Anticipo Trabajadores Educación Inclusiva                                       15
# Inscripción casos especiales comité educación convencional pensionados          14
# Consulta de información relacionadas con reembolsos                             12
# Consulta sobre liquidación/pago préstamo para educación                         10
# Consulta Bachiller Ecopetrol (Incapacidad médica y/o Fuerza Mayor)               3
# Consulta especialista beneficios atención PQRS                                   1
# Name: fgs_Nivel3, dtype: int64

# %%
niveles['fgs_Nivel3'].value_counts().sort_values(ascending=True).plot.barh(title = ' Diferentes niveles',figsize = (10,14))

# %%
# correlacion

# %%
objetos.head(2)
# Out:
#   fgs_SiglasDocumentoContacto  ... fdp_FechaVencimientoTotal
# 0                          CC  ...   2021-02-01 09:45:00.000
# 1                          CC  ...   2021-02-01 09:45:00.000
#
# [2 rows x 76 columns]

# %%
mapas_nofechas = objetos.columns.str.findall('Fecha').map(lambda x : len(x)==0)# eliminar fecha
objetos_nofechas = objetos[objetos.columns[mapas_nofechas]]

# %%
objetos_nofechas.head()
# Out:
#   fgs_SiglasDocumentoContacto  ...                                         TipoAjuste
# 0                          CC  ...  Fecha Superior a la fecha de creación o Fecha ...
# 1                          CC  ...  Fecha Superior a la fecha de creación o Fecha ...
# 2                          CC  ...  Fecha Superior a la fecha de creación o Fecha ...
# 3                          CC  ...  Fecha Superior a la fecha de creación o Fecha ...
# 4                          CC  ...  Fecha Superior a la fecha de creación o Fecha ...
#
# [5 rows x 61 columns]

# %%
objetos_nofechas.columns
# Out:
# Index(['fgs_SiglasDocumentoContacto', 'fgs_NombreCompletoContacto', 'fgs_Ip',
#        'fgs_Tipificación', 'fgs_Nivel2', 'fgs_Nivel3', 'fgs_Nivel4',
#        'fgs_Direccion_01', 'fgs_BarrioDireccion_01',
#        'fgs_LocalidadDireccion_01', 'fgs_CiudadDireccion_01',
#        'fgs_DepartamentoDireccion_01', 'fgs_Email_01', 'fgs_Email_02',
#        'fgs_Email_03', 'fmf_Canal', 'ude_Regional', 'ude_CiudadCliente',
#        'ude_DepartamentoCliente', 'ude_PaisCliente', 'ude_CodUni',
#        'ude_UnidadOrganizativa', 'ude_CECO', 'ude_CentroDeCostos',
#        'ude_EmailCliente', 'SistemaPago', 'ServicioPortafolio',
#        'fdp_NombreEstado', 'fdp_NivelEstado', 'fdp_NombreUsuarioCreacion',
#        'fgs_ObservacionCreacion', 'GrupoRolCreacion',
#        'Cumple_Objetivo_SolicitadoRegistrado',
#        'Cumple_Objetivo_RegistradoEscalado', 'fdp_NombreGrupoEscalamientoN2',
#        'fdp_NombreUsuarioEscalamientoN2', 'fgs_ObservacionEscalamientoN2',
#        'GrupoRolEscalamientoN2', 'Cumple_Objetivo_EnNivel2',
#        'fdp_NombreUsuarioDevolucion', 'fgs_ObservacionDevolucion',
#        'GrupoRolDevolucion', 'fdp_MotivoDevolucion', 'fdp_NombreGrupoSolucion',
#        'fdp_NombreUsuarioSolucion', 'fgs_ObservacionSolucion',
#        'GrupoRolSolucion', 'fdp_NivelSolucion',
#        'Cumple_Objetivo_SolucionadoCerrado', 'fdp_NombreGrupoCierre',
#        'fdp_NombreUsuarioCierre', 'fgs_ObservacionCierre', 'GrupoRolCierre',
#        'fdp_NivelCierre', 'fdp_NombreGrupoGestionActual',
#        'fdp_NombreUsuarioGestionActual', 'fgs_ObservacionGestionActual',
#        'GrupoRolGestionActual', 'fdp_MotivoGestionActual',
#        'fdp_NivelGestionActual', 'TipoAjuste'],
#       dtype='object')

# %%
importa =objetos[['fgs_Nivel3','fgs_ObservacionCreacion','fgs_ObservacionSolucion']]

# %%
# %%time
importa['fgs_ObservacionCreacion'].str.split().str.len()
# Out:
# CPU times: user 52.8 ms, sys: 15.2 ms, total: 67.9 ms
# Wall time: 70.2 ms
# 0         18
# 1         12
# 2         20
# 3         22
# 4         10
#         ...
# 13743     77
# 13744     72
# 13745    153
# 13746    128
# 13747     13
# Name: fgs_ObservacionCreacion, Length: 13748, dtype: int64

# %%
# %%time
importa['1'] = importa['fgs_ObservacionCreacion'].map(lambda x : len(x.split()))
# Out:
# CPU times: user 39.3 ms, sys: 968 µs, total: 40.3 ms
# Wall time: 40.9 ms
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
importa['fgs_ObservacionSolucion'].map(lambda x : type(x)).value_counts()
# Out:
# <class 'str'>      13719
# <class 'float'>       29
# Name: fgs_ObservacionSolucion, dtype: int64

# %%
mapa = importa['fgs_ObservacionSolucion'].map(lambda x : type(x))==float

# %%
importa[mapa]## no hay solucion por que puede que se le diera solucion directa al cliente. :( )
# Out:
#                                               fgs_Nivel3  ...    1
# 163    Legal / Reconocimiento Pensionados (Incluye Su...  ...  131
# 2075   Legal / Reconocimiento Trabajadores (Incluye B...  ...    8
# 4018           Anticipo Pensionados (Incluye Sustitutos)  ...   54
# 6314   Reintegro de dinero trabajadores Educación (In...  ...   79
# 6356   Reintegro de dinero trabajadores Educación (In...  ...   68
# 6370   Reintegro de dinero trabajadores Educación (In...  ...   52
# 6402   Reintegro de dinero trabajadores Educación (In...  ...   48
# 6438   Reintegro de dinero trabajadores Educación (In...  ...  108
# 6512   Reintegro de dinero trabajadores Educación (In...  ...   30
# 6515   Reintegro de dinero trabajadores Educación (In...  ...   82
# 8432   Legal / Reconocimiento Trabajadores (Incluye B...  ...   32
# 8492   Legal / Reconocimiento Trabajadores (Incluye B...  ...   66
# 8706   Legal / Reconocimiento Trabajadores (Incluye B...  ...  157
# 10067  Legal / Reconocimiento Trabajadores (Incluye B...  ...  138
# 12865  Consultas Titulares Beneficio Educativo (No In...  ...   21
# 12884  Consultas Titulares Beneficio Educativo (No In...  ...  151
# 12885  Consultas Titulares Beneficio Educativo (No In...  ...   83
# 12928  Consultas Titulares Beneficio Educativo (No In...  ...  126
# 12948  Consultas Titulares Beneficio Educativo (No In...  ...  122
# 12977  Consultas Titulares Beneficio Educativo (No In...  ...   33
# 12987  Consultas Titulares Beneficio Educativo (No In...  ...   76
# 12996  Consultas Titulares Beneficio Educativo (No In...  ...  109
# 12997  Consultas Titulares Beneficio Educativo (No In...  ...  146
# 13014  Consultas Titulares Beneficio Educativo (No In...  ...  201
# 13060  Consultas Titulares Beneficio Educativo (No In...  ...  286
# 13064  Consultas Titulares Beneficio Educativo (No In...  ...   84
# 13163  Consultas Titulares Beneficio Educativo (No In...  ...   20
# 13199  Consultas Titulares Beneficio Educativo (No In...  ...   30
# 13260  Consultas Titulares Beneficio Educativo (No In...  ...   15
#
# [29 rows x 4 columns]

# %%
importasina = importa.dropna().copy()

# %%
importasina['fgs_ObservacionCreacion_cantidad_palabras'] = importasina['fgs_ObservacionCreacion'].map(lambda x : len(x.split())).copy()

# %%
importasina['fgs_ObservacionSolucion_cantidad_palabras'] = importasina['fgs_ObservacionSolucion'].copy().map(lambda x : len(x.split()))

# %%
importasina[['fgs_ObservacionCreacion_cantidad_palabras','fgs_ObservacionSolucion_cantidad_palabras']].corr()
# Out:
#                                            fgs_ObservacionCreacion_cantidad_palabras  fgs_ObservacionSolucion_cantidad_palabras
# fgs_ObservacionCreacion_cantidad_palabras                                     1.0000                                     0.0681
# fgs_ObservacionSolucion_cantidad_palabras                                     0.0681                                     1.0000

# %%
importasina[['fgs_ObservacionCreacion_cantidad_palabras','fgs_ObservacionSolucion_cantidad_palabras']].corr(method='spearman')
# Out:
#                                            fgs_ObservacionCreacion_cantidad_palabras  fgs_ObservacionSolucion_cantidad_palabras
# fgs_ObservacionCreacion_cantidad_palabras                                   1.000000                                   0.203493
# fgs_ObservacionSolucion_cantidad_palabras                                   0.203493                                   1.000000

# %%
# importasina['fgs_ObservacionCreacion_cantidad_palabras'].map(lambda x: x.replace('<br>',' '))

# %%
importasina['fgs_ObservacionCreacion'].map(lambda x: x.replace('<br>',' '))
# Out:
# 0        Se recibe documentación del señor Joaquin Erne...
# 1        Solicitó el ajuste de semestre y se encuentra ...
# 2        SE RECIBE SOLICITUD DE LEGALIZACION 5 SEMESTRE...
# 3        SOLICITUD DEL USUARIO: Ayer envié este mismo d...
# 4        SE RECIBE SOLICITUD DE LEGALIZACION DE LUISA F...
#                                ...
# 13743    GESTIÓN: Su caso se escaló al área encargada p...
# 13744    GESTIÓN: Su caso se escaló al área encargada p...
# 13745    GESTIÓN: Su caso se escaló al área encargada p...
# 13746    Gestión: Su caso fue escalado con las siguient...
# 13747    Funcionario solicita creación de un caso por l...
# Name: fgs_ObservacionCreacion, Length: 13719, dtype: object

# %%
importasina['fgs_ObservacionCreacion'][importasina['fgs_ObservacionCreacion'].str.findall('<br>').map(lambda x: len(x)>0)]
# Out:
# 5       Se recibe documentación del señor Carlos Alber...
# 37      su  caso fue escalado al area encargada con la...
# 59      Buenas Tardes <br><br><br>Solicitamos de su am...
# 77      Buenos dias señores de oficina virtual de pers...
# 90      solicitud OVP/ gestión : "La presente es para ...
#                               ...
# 6240    GESTIÓN: Su caso se escaló al área encargada p...
# 6241    GESTIÓN: Su caso se escaló al área encargada p...
# 6242    GESTIÓN: Su caso se escaló al área encargada p...
# 6243    GESTIÓN: Su caso se escaló al área encargada p...
# 6244    GESTIÓN: Su caso se escaló al área encargada p...
# Name: fgs_ObservacionCreacion, Length: 1042, dtype: object

# %%
importasina['fgs_ObservacionCreacion'].map(lambda x: x.replace('<br>',' '))[importasina['fgs_ObservacionCreacion'].str.findall('<br>').map(lambda x: len(x)>0)]
# Out:
# 5       Se recibe documentación del señor Carlos Alber...
# 37      su  caso fue escalado al area encargada con la...
# 59      Buenas Tardes    Solicitamos de su amable cola...
# 77      Buenos dias señores de oficina virtual de pers...
# 90      solicitud OVP/ gestión : "La presente es para ...
#                               ...
# 6240    GESTIÓN: Su caso se escaló al área encargada p...
# 6241    GESTIÓN: Su caso se escaló al área encargada p...
# 6242    GESTIÓN: Su caso se escaló al área encargada p...
# 6243    GESTIÓN: Su caso se escaló al área encargada p...
# 6244    GESTIÓN: Su caso se escaló al área encargada p...
# Name: fgs_ObservacionCreacion, Length: 1042, dtype: object

# %%
importasina['fgs_ObservacionCreacion'].map(lambda x: x.replace('<br>',' ')).value_counts()
# Out:
# solicita información de plan educacional.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        263
# solicita información.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            193
# SE RECIBE POR PARTE DE OFICINA VIRTUAL, SOLICITUD LEGALIZACIÓN PLAN EDUCACIONAL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  169
# LEGALIZACIÓN PLAN EDUCACIONAL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    125
# SOLICITUD LEGALIZACIÓN PLAN EDUCACIONAL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           75
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# Gestión: Su caso fue escalado con las siguientes observaciones\n\nAdjunto evidencia de reintegro de plan educacional de mi hija Luisa Maria De Las Salas Romero por descuento aplicado por el Colegio con ocasión de la pandemia.\n\nCualquier información adicional con gusto será suministrada.\n                                                                                                                                                                                                                                                                                                                                                                                1
# Señor Omar Romero pensionado se comunica porque tiene dudas con los valores pagos refente al alojamiento                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Pensionado solicita información sobre reintegro y sobre solicitud de reconocimiento educativo.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# usuario se comunica para validar el motivo de rechazo del caso 297781                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Buen día, agradezco su amable gestión revisando la presente solicitud de error Kactus para TIB. Se deja correo adjunto con evidencia requerida. Muchas gracias.\n\nAcuso recibo de la información de ecopetrol, de igual forma hago de su conocimiento que al ingresar a la plataforma a realizar el debido reporte aparece en el sistema un recuadro que menciona que "No existe autorización por parte del titular para la transferencia de información"  lo cual no me permite continuar con el proceso. (ver imagen adjunta)\n\nAgradezco por favor revisar con Ecopetrol en referencia a la autorización pertinente para dar continuidad al reporte.\n\nQuedo atenta, \n      1
# Name: fgs_ObservacionCreacion, Length: 11924, dtype: int64

# %%
importasina['fgs_ObservacionSolucion'].map(lambda x: x.replace('<br>',' ')).value_counts()
# Out:
# se procede a dar cierre según correo adjunto.                                                                                                                                                                                                                                                                                                                                            259
# se adjunta respuesta enviada                                                                                                                                                                                                                                                                                                                                                             206
# Buen día, en atención a su solicitud, nos permitimos informarle que su caso se encuentra radicado para el próximo Comité de Educación,  el cual se llevará a cabo durante el segundo semestre de 2020. Una vez analizado, se procederá a enviar respuesta a través de nuestros canales de comunicación.  Para Servicios Compartidos es un placer atenderle. Le deseamos un feliz día.     87
# se procede a dar cierre según correo adjunto.                                                                                                                                                                                                                                                                                                                                             73
# Se adjunta la gestión del caso                                                                                                                                                                                                                                                                                                                                                            72
#                                                                                                                                                                                                                                                                                                                                                                                         ...
# En atención a  su solicitud se indica que se valida en sistema y registra que en el año 2019 su beneficiaria curso  primero de primaria y en el año 2020 curso segundo de primaria debido a esta información es que el sistema no le permite solicitar nuevamente segundo de primaria.                                                                                                     1
# Se le explicó la normativa y se le sugirió enviar el caso a OVP.                                                                                                                                                                                                                                                                                                                           1
# En atención a su consulta, nos permitimos informarle que en la solicitud 212914 para la beneficiaria  RUBY YURLEY TORRES CASTRO 2-2020 (Sexto de Universidad) , le fue liquidado la tarifa de alojamiento por valor de 2.050.963.                                                                                                                                                          1
# Buen día, de manera atenta informamos que el pago del anticipo por su beneficiario  AURA CRISTINA ECHEVERRIA MORENO, se verá reflejado  en la segunda quincena de DICIEMBRE de  2020.  Tenga en cuenta que de conformidad con el Reglamento de Plan Educacional, dispone de 90 días para la legalización de este anticipo.                                                                 1
# Confirmamos que el plan educacional para la beneficiaria SOFIA POLANCO BALLESTAS para décimo de secundaria se cancelara junto con la segunda quincena de agosto de 2020.                                                                                                                                                                                                                   1
# Name: fgs_ObservacionSolucion, Length: 11653, dtype: int64

# %%
nombres_columnas = pd.Series(df_Registros_P.columns)
columnas_con_nombre = nombres_columnas [nombres_columnas.map(lambda x :x.lower()).str.findall('nombre').map(lambda x : len(x)>0)]

# %%
columnas_con_nombre.to_list()
# Out:
# ['fgs_NombreCompletoContacto',
#  'fdp_NombreEstado',
#  'fdp_NombreUsuarioCreacion',
#  'fdp_NombreGrupoEscalamientoN2',
#  'fdp_NombreUsuarioEscalamientoN2',
#  'fdp_NombreUsuarioDevolucion',
#  'fdp_NombreGrupoSolucion',
#  'fdp_NombreUsuarioSolucion',
#  'fdp_NombreGrupoCierre',
#  'fdp_NombreUsuarioCierre',
#  'fdp_NombreGrupoGestionActual',
#  'fdp_NombreUsuarioGestionActual']

# %%
nombres_columnas = pd.Series(df_Registros_P.columns)
columnas_con_nombre = nombres_columnas [nombres_columnas.map(lambda x :x.lower()).str.findall('fecha').map(lambda x : len(x)>0)]

# %%
columnas_con_nombre.to_list()
# Out:
# ['fgs_FechaInicio',
#  'fgs_FechaFin',
#  'fmf_FechaSolicitud',
#  'fdp_FechaCreacion',
#  'fdp_FechaEscalamientoN2',
#  'fdp_FechaVencimientoEscalamientoN2',
#  'fdp_FechaDevolucion',
#  'fdp_FechaVencimientoDevolucion',
#  'fdp_FechaSolucion',
#  'fdp_FechaVencimientoSolucion',
#  'fdp_FechaCierre',
#  'fdp_FechaVencimientoCierre',
#  'fdp_FechaGestionActual',
#  'fdp_FechaVencimientoGestionActual',
#  'fdp_FechaVencimientoTotal']

# %%
info_usuarios = df_Registros_P[['fgs_SiglasDocumentoContacto', 'fgs_NumeroDocumContacto','fgs_FechaInicio',
                'fgs_NombreCompletoContacto',
 'fdp_NombreEstado',
 'fdp_NombreUsuarioCreacion',
 'fdp_NombreGrupoEscalamientoN2',
 'fdp_NombreUsuarioEscalamientoN2',
 'fdp_NombreUsuarioDevolucion',
 'fdp_NombreGrupoSolucion',
 'fdp_NombreUsuarioSolucion',
 'fdp_NombreGrupoCierre',
 'fdp_NombreUsuarioCierre',
 'fdp_NombreGrupoGestionActual',
 'fdp_NombreUsuarioGestionActual',
 'fdp_FechaCreacion']].copy()

# %%
info_usuarios.head(2)
# Out:
#   fgs_SiglasDocumentoContacto  ...        fdp_FechaCreacion
# 0                          CC  ...  2021-02-01 06:47:23.443
# 1                          CC  ...  2021-02-01 07:01:31.857
#
# [2 rows x 16 columns]

# %%
info_clientes = pd.read_csv('Info_clientes.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,6,24,27,29,34,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
info_clientes.head(2)
# Out:
#    ID N_DOCUMENTO TIPO_DOCUMENTO  ...  REGISTRO   RG    UN_ORG
# 0   1  1006775793             CC  ...    282708   50  10000196
# 1   2  1006776140             CC  ...    104035  NaN       NaN
#
# [2 rows x 36 columns]

# %%
info_clientes.columns
# Out:
# Index(['ID', 'N_DOCUMENTO', 'TIPO_DOCUMENTO', 'IdTipoDoc', 'NOMBRE_COMPLETO',
#        'DIRECCION', 'DIRECCION_2', 'CIUDAD', 'IdCiudad', 'CIUDAD_SUCURSAL',
#        'DEPARTAMENTO', 'IdDepto', 'PAIS', 'IdPais', 'FECHA_NACIMIENTO', 'SEXO',
#        'CORREO_ELECT', 'TELEFONO_1', 'TELEFONO_2', 'TEL_CELULAR', 'TEL_FIJO',
#        'ECIVIL', 'REGIONAL_GSC', 'CDFPR', 'CECOSTE', 'CECO', 'CE_COSTE',
#        'CODIGO_POSICION', 'DESCRIPCIÓN_SUCURSAL', 'SUCURSAL', 'POSICION', 'PS',
#        'RAZON_SOCIAL', 'REGISTRO', 'RG', 'UN_ORG'],
#       dtype='object')

# %%
# info_usuarios['fgs_NumeroDocumContacto'] = info_usuarios['fgs_NumeroDocumContacto'].astype('O')

# %%
print(info_usuarios.shape)
x = info_usuarios.merge(right=info_clientes,how='left', left_on='fgs_NumeroDocumContacto',right_on='N_DOCUMENTO')
print(info_usuarios.shape, x.shape)
# Out:
# (13748, 16)
# (13748, 16) (13748, 52)

# %%
x[x['fgs_NumeroDocumContacto'].duplicated(keep=False)].sort_values(by = 'fgs_NumeroDocumContacto')
# Out:
#       fgs_SiglasDocumentoContacto fgs_NumeroDocumContacto  ...   RG UN_ORG
# 1041                           CC                    1000  ...  NaN    NaN
# 5279                           CC                    1000  ...  NaN    NaN
# 5276                           CC                    1000  ...  NaN    NaN
# 12509                          CC                    1000  ...  NaN    NaN
# 3690                           CC                    1000  ...  NaN    NaN
# ...                           ...                     ...  ...  ...    ...
# 11911                          CC              1234990667  ...  NaN    NaN
# 6485                           CC              1234990667  ...  NaN    NaN
# 13538                          CC              8604028477  ...  NaN    NaN
# 13435                         NIT              8604028477  ...  NaN    NaN
# 13640                         NIT              8604028477  ...  NaN    NaN
#
# [12013 rows x 52 columns]

# %%
info_usuarios['fgs_NumeroDocumContacto'].astype('O')
# Out:
# 0          19322865
# 1        1053843731
# 2          17043647
# 3          19105812
# 4          51659165
#             ...
# 13743       8288700
# 13744      79000080
# 13745      12119794
# 13746      79238499
# 13747      12119794
# Name: fgs_NumeroDocumContacto, Length: 13748, dtype: object

# %%
info_clientes['N_DOCUMENTO'].map(lambda x : type(x))#=='str')
# Out:
# 0         <class 'str'>
# 1         <class 'str'>
# 2         <class 'str'>
# 3         <class 'str'>
# 4         <class 'str'>
#               ...
# 380251    <class 'int'>
# 380252    <class 'int'>
# 380253    <class 'int'>
# 380254    <class 'int'>
# 380255    <class 'int'>
# Name: N_DOCUMENTO, Length: 380256, dtype: object

# %%
# info_clientes['N_DOCUMENTO'].astype('int')

# %%
info_clientes[info_clientes['N_DOCUMENTO']== 'EUSA760823R64' ]
# Out:
#         ID    N_DOCUMENTO TIPO_DOCUMENTO  ...  REGISTRO   RG UN_ORG
# 1716  1717  EUSA760823R64             CC  ...       NaN  NaN    NaN
#
# [1 rows x 36 columns]

# %%
def nonum(x):
 try:
   int(x)
   sal = False
 except:
    sal = True
 return sal 
mapa = info_clientes['N_DOCUMENTO'].map(lambda x: nonum(x))

# %%
info_clientes[mapa]# numero de identidad irreconocible
# Out:
#             ID    N_DOCUMENTO TIPO_DOCUMENTO  ...  REGISTRO   RG UN_ORG
# 1716      1717  EUSA760823R64             CC  ...       NaN  NaN    NaN
# 1774      1775       CC101022             CC  ...       NaN  NaN    NaN
# 1775      1776       CC101903             CC  ...       NaN  NaN    NaN
# 1776      1777       C8012516             CC  ...       NaN  NaN    NaN
# 1777      1778       CC113688             CC  ...       NaN  NaN    NaN
# ...        ...            ...            ...  ...       ...  ...    ...
# 370839  370840      51095593N             CC  ...       NaN  NaN    NaN
# 372998  372999      27046274K             CC  ...       NaN  NaN    NaN
# 374431  374432         794E11             CC  ...       NaN  NaN    NaN
# 374432  374433         763E11             CC  ...       NaN  NaN    NaN
# 374433  374434         436E11             CC  ...       NaN  NaN    NaN
#
# [708 rows x 36 columns]

# %%
def isnum(x):
 try:
   int(x)
   sal = True
 except:
    sal = False
 return sal 
mapa = info_clientes['N_DOCUMENTO'].map(lambda x: isnum(x))

# %%
print(info_clientes.shape,info_clientes[mapa].shape,info_clientes[mapa].shape[0]/info_clientes.shape[0]*100 )# porcentaj no numericos
# Out:
# (380256, 36) (379548, 36) 99.81380964402928

# %%
info_clientes = info_clientes[mapa]

# %%
info_clientes['N_DOCUMENTO'] = info_clientes['N_DOCUMENTO'].astype('int')

# %%
print(info_usuarios.shape)
info_usuarios.merge(right=info_clientes,how='left', left_on='fgs_NumeroDocumContacto',right_on='N_DOCUMENTO')
print(info_usuarios.shape)
# Out:
# (13748, 16)
# (13748, 16)

# %%
info_usuarios.head()
# Out:
#   fgs_SiglasDocumentoContacto  ...        fdp_FechaCreacion
# 0                          CC  ...  2021-02-01 06:47:23.443
# 1                          CC  ...  2021-02-01 07:01:31.857
# 2                          CC  ...  2021-02-01 07:09:37.667
# 3                          CC  ...  2021-02-01 07:19:12.327
# 4                          CC  ...  2021-02-01 07:23:02.490
#
# [5 rows x 16 columns]

# %%
print(info_usuarios.shape)
info_copilada = info_usuarios.merge(right=info_clientes,how='left', left_on='fgs_NumeroDocumContacto',right_on='N_DOCUMENTO')
print(info_usuarios.shape, info_copilada.shape)
# Out:
# (13748, 16)
# (13748, 16) (13748, 52)

# %%
info_copilada.head()
# Out:
#   fgs_SiglasDocumentoContacto  fgs_NumeroDocumContacto  ...  RG UN_ORG
# 0                          CC                 19322865  ...  11  1e+08
# 1                          CC               1053843731  ...  47  1e+08
# 2                          CC                 17043647  ...  54  1e+08
# 3                          CC                 19105812  ...  47  1e+08
# 4                          CC                 51659165  ...  11  1e+08
#
# [5 rows x 52 columns]

# %%
mytable(info_copilada)
# Out:
#                                  % de datos nulos  ...  % de valores diferentes
# fgs_SiglasDocumentoContacto              0.101833  ...                 0.036369
# fgs_NumeroDocumContacto                  0.000000  ...                32.390166
# fgs_FechaInicio                          0.000000  ...                99.847251
# fgs_NombreCompletoContacto               0.000000  ...                32.462904
# fdp_NombreEstado                         0.000000  ...                 0.029095
# fdp_NombreUsuarioCreacion                0.000000  ...                 0.436427
# fdp_NombreGrupoEscalamientoN2           78.207739  ...                 0.043643
# fdp_NombreUsuarioEscalamientoN2         78.382310  ...                 0.094559
# fdp_NombreUsuarioDevolucion             98.392493  ...                 0.290951
# fdp_NombreGrupoSolucion                  0.210940  ...                 0.050916
# fdp_NombreUsuarioSolucion                0.210940  ...                 0.487344
# fdp_NombreGrupoCierre                    0.218214  ...                 0.050916
# fdp_NombreUsuarioCierre                  0.218214  ...                 0.480070
# fdp_NombreGrupoGestionActual             0.000000  ...                 0.050916
# fdp_NombreUsuarioGestionActual           0.000000  ...                 0.480070
# fdp_FechaCreacion                        0.000000  ...                99.941810
# ID                                       4.851615  ...                31.153622
# N_DOCUMENTO                              4.851615  ...                31.153622
# TIPO_DOCUMENTO                           4.851615  ...                 0.029095
# IdTipoDoc                                4.851615  ...                 0.029095
# NOMBRE_COMPLETO                          4.851615  ...                31.153622
# DIRECCION                                4.960722  ...                30.891766
# DIRECCION_2                            100.000000  ...                 0.000000
# CIUDAD                                   4.851615  ...                 0.996509
# IdCiudad                                 4.851615  ...                 0.996509
# CIUDAD_SUCURSAL                         61.594414  ...                 0.341868
# DEPARTAMENTO                             4.851615  ...                 0.167297
# IdDepto                                  4.851615  ...                 0.167297
# PAIS                                     4.851615  ...                 0.007274
# IdPais                                   4.851615  ...                 0.007274
# FECHA_NACIMIENTO                         4.924353  ...                27.865871
# SEXO                                     4.953448  ...                 0.043643
# CORREO_ELECT                             5.244399  ...                30.702648
# TELEFONO_1                               6.088158  ...                30.528077
# TELEFONO_2                              17.267966  ...                26.542042
# TEL_CELULAR                             95.984871  ...                 1.498400
# TEL_FIJO                                96.028513  ...                 1.549316
# ECIVIL                                  11.165260  ...                 0.087285
# REGIONAL_GSC                             5.804481  ...                 0.043643
# CDFPR                                    4.924353  ...                 1.352924
# CECOSTE                                 99.956357  ...                 0.014548
# CECO                                     5.702648  ...                 5.084376
# CE_COSTE                                 5.753564  ...                 5.542624
# CODIGO_POSICION                          5.724469  ...                20.919406
# DESCRIPCIÓN_SUCURSAL                    42.966250  ...                 0.400058
# SUCURSAL                                 4.938900  ...                 1.069246
# POSICION                                 5.724469  ...                 3.476869
# PS                                       5.724469  ...                 0.021821
# RAZON_SOCIAL                            99.970905  ...                 0.029095
# REGISTRO                                 4.946174  ...                30.629910
# RG                                       5.724469  ...                 0.341868
# UN_ORG                                   5.709921  ...                 5.288042
#
# [52 rows x 5 columns]

# %%
info_copilada.head(2)
# Out:
#   fgs_SiglasDocumentoContacto  fgs_NumeroDocumContacto  ...  RG UN_ORG
# 0                          CC                 19322865  ...  11  1e+08
# 1                          CC               1053843731  ...  47  1e+08
#
# [2 rows x 52 columns]

# %%
info_copilada_filtrada = info_copilada[['fgs_SiglasDocumentoContacto','fgs_NumeroDocumContacto','N_DOCUMENTO','fgs_NombreCompletoContacto','NOMBRE_COMPLETO','CIUDAD',
               'POSICION'	,'PS','RG','FECHA_NACIMIENTO','fdp_FechaCreacion','SEXO']]

# %%
info_copilada_filtrada.head()
# Out:
#   fgs_SiglasDocumentoContacto  ...       SEXO
# 0                          CC  ...  MASCULINO
# 1                          CC  ...   FEMENINO
# 2                          CC  ...  MASCULINO
# 3                          CC  ...  MASCULINO
# 4                          CC  ...   FEMENINO
#
# [5 rows x 12 columns]

# %%
mytable(info_copilada_filtrada)
# Out:
#                              % de datos nulos  ...  % de valores diferentes
# fgs_SiglasDocumentoContacto          0.101833  ...                 0.036369
# fgs_NumeroDocumContacto              0.000000  ...                32.390166
# N_DOCUMENTO                          4.851615  ...                31.153622
# fgs_NombreCompletoContacto           0.000000  ...                32.462904
# NOMBRE_COMPLETO                      4.851615  ...                31.153622
# CIUDAD                               4.851615  ...                 0.996509
# POSICION                             5.724469  ...                 3.476869
# PS                                   5.724469  ...                 0.021821
# RG                                   5.724469  ...                 0.341868
# FECHA_NACIMIENTO                     4.924353  ...                27.865871
# fdp_FechaCreacion                    0.000000  ...                99.941810
# SEXO                                 4.953448  ...                 0.043643
#
# [12 rows x 5 columns]

# %%
print(info_copilada_filtrada.shape)
info_copilada_filtrada = info_copilada_filtrada.dropna()
info_copilada_filtrada['N_DOCUMENTO'] = info_copilada_filtrada['N_DOCUMENTO'].astype(int)
(info_copilada_filtrada.shape)
# Out:
# (13748, 12)
# (12943, 12)

# %%
df_entrada = info_copilada_filtrada.select_dtypes('O').copy()

# %%
lista_menores = []
lista_mayores = []
for i in df_entrada.columns:
  
  if df_entrada[i].nunique()<=100:
    display(df_entrada[i].value_counts())
    df_entrada[i].value_counts().plot.bar(title=i,figsize=(18,4))
    plt.show()
    lista_menores.append(i)
  else:
    lista_mayores.append(i)
# Out:
# CC    12908
# CE       19
# TI       16
# Name: fgs_SiglasDocumentoContacto, dtype: int64
# COL    12072
# CO       867
# ARE        4
# Name: PS, dtype: int64
# 68        2908
# 68.0      2346
# 11.0      1549
# 11        1366
# 13.0       761
# 13         626
# 50         395
# 50.0       321
# 25         297
# 54.0       266
# 25.0       200
# 5          181
# 41.0       169
# 54         165
# 5.0        130
# 76.0        92
# 76          87
# 20          81
# 85.0        81
# 85          76
# 41          71
# 8.0         61
# 17          59
# 73          57
# 17.0        53
# 86          52
# 47          51
# 8           45
# 20.0        43
# 86.0        38
# 70.0        38
# 66.0        36
# 47.0        35
# 15.0        34
# 70          32
# 15          25
# 73.0        22
# 63          21
# 23.0        18
# 23          13
# 52          11
# COLDEF      10
# 52.0         8
# 63.0         4
# 66           4
# 81           3
# 11.0         2
# Name: RG, dtype: int64
# MASCULINO    11091
# FEMENINO      1649
# M               91
# F               48
# Masculino       47
# Femenino        17
# Name: SEXO, dtype: int64

# %%
for i in df_entrada.columns:
  print(i)
  try:
   df_entrada[i]=df_entrada[i].map(lambda x: x.lower())
  except:
    print('{} no se puedo pponer en minuscula'.format(i))

lista ={'f':'femenino','m':'masculino'}
df_entrada['SEXO'] = df_entrada['SEXO'].replace(lista)#.map(lambda x : x.replace())


def solo_num(x):
  try:
    sal = float(x)
  except:
    sal = np.nan
  return sal 


df_entrada['RG'] = df_entrada['RG'].map(lambda x : solo_num(x))
# Out:
# fgs_SiglasDocumentoContacto
# fgs_NombreCompletoContacto
# NOMBRE_COMPLETO
# CIUDAD
# POSICION
# PS
# RG
# RG no se puedo pponer en minuscula
# FECHA_NACIMIENTO
# fdp_FechaCreacion
# SEXO

# %%
lista_menores = []
lista_mayores = []
for i in df_entrada.columns:
  
  if df_entrada[i].nunique()<=100:
    display(df_entrada[i].value_counts())
    df_entrada[i].value_counts().plot.bar(title=i,figsize=(18,4))
    plt.show()
    lista_menores.append(i)
  else:
    lista_mayores.append(i)
# Out:
# cc    12908
# ce       19
# ti       16
# Name: fgs_SiglasDocumentoContacto, dtype: int64
# col    12072
# co       867
# are        4
# Name: PS, dtype: int64
# 68.0    5254
# 11.0    2917
# 13.0    1387
# 50.0     716
# 25.0     497
# 54.0     431
# 5.0      311
# 41.0     240
# 76.0     179
# 85.0     157
# 20.0     124
# 17.0     112
# 8.0      106
# 86.0      90
# 47.0      86
# 73.0      79
# 70.0      70
# 15.0      59
# 66.0      40
# 23.0      31
# 63.0      25
# 52.0      19
# 81.0       3
# Name: RG, dtype: int64
# masculino    11229
# femenino      1714
# Name: SEXO, dtype: int64

# %%
df_entrada['RG'].plot.hist()

# %%
pd.to_datetime(df_entrada['FECHA_NACIMIENTO'],errors='coerce')
# Out:
# 0       1957-05-08
# 1       1995-07-23
# 2       1941-03-17
# 3       1950-04-18
# 4       1962-04-28
#            ...
# 13743   1948-11-08
# 13744   1958-08-16
# 13745   1962-02-18
# 13746   1965-02-28
# 13747   1962-02-18
# Name: FECHA_NACIMIENTO, Length: 12943, dtype: datetime64[ns]

# %%
from datetime import datetime

print(datetime.today())
# Out:
# 2021-06-09 20:45:07.670615

# %%
edad = datetime.today().year - pd.to_datetime(df_entrada['FECHA_NACIMIENTO'],errors='coerce').dt.year

# %%
df_entrada['edad']= edad

# %%
df_entrada['edad'].plot.hist()

# %%
# df_entrada['edad'].plot.bar()

# %%
df_entrada['edad'].describe(percentiles=[0.05,0.15,0.25,0.5,0.75,0.85,0.9,0.95,0.99])
# Out:
# count    12939.000000
# mean        52.166860
# std         13.566856
# min          5.000000
# 5%          26.000000
# 15%         39.000000
# 25%         43.000000
# 50%         53.000000
# 75%         62.000000
# 85%         66.000000
# 90%         69.000000
# 95%         72.000000
# 99%         79.000000
# max         93.000000
# Name: edad, dtype: float64

# %%
df_entrada[df_entrada['edad']==93]
# Out:
#      fgs_SiglasDocumentoContacto fgs_NombreCompletoContacto  ...       SEXO  edad
# 9159                          cc     feria miranda cipriano  ...  masculino  93.0
#
# [1 rows x 11 columns]

# %%
df_entrada[df_entrada['edad']==5]
# Out:
#       fgs_SiglasDocumentoContacto  ... edad
# 3550                           cc  ...  5.0
# 3555                           cc  ...  5.0
# 3606                           cc  ...  5.0
# 3813                           cc  ...  5.0
# 10180                          cc  ...  5.0
# 10181                          cc  ...  5.0
#
# [6 rows x 11 columns]

# %%
df_entrada['POSICION'].value_counts()
# Out:
# pensionados                                         5074
# operadora de planta mayor                            483
# operadora de planta                                  428
# técnicoa de operaciones a                            313
# supervisora a                                        284
#                                                     ...
# jefe departamento de balance con transportadores       1
# desarrollador de negocios gas  power                   1
# ingenieroa integral aseguramiento de proy              1
# business partner talento humano a                      1
# técnicoa de mantenimiento a                            1
# Name: POSICION, Length: 478, dtype: int64

# %%
df_entrada['POSICION'].value_counts().index.tolist()
# Out:
# ['pensionados',
#  'operadora de planta mayor',
#  'operadora de planta',
#  'técnicoa de operaciones a',
#  'supervisora a',
#  'operadora de planta senior',
#  'técnicoa de operaciones b',
#  'supervisora de centro de control remoto',
#  'técnicoa de mantenimiento y confiabilidad a',
#  'operador de planta',
#  'ingenieroa integral de mantto y confiab',
#  'ingenieroa de perf y compl a',
#  'auxiliar de salud',
#  'operadora de subsuelo mayor',
#  'administradora de contratos a',
#  'metalmecánico senior',
#  'mecánicoa senior',
#  'operadora de subsuelo senior',
#  'ingenieroa de producción a',
#  'profesional hse a',
#  'operador de planta mayor',
#  'operador de planta senior',
#  'integración posición por defecto',
#  'ingenieroa senior de perf y compl',
#  'ingenieroa de confiabilidad e integridad',
#  'analista de laboratorio a',
#  'asistente administrativoa',
#  'planeadora y programadora de mantenimiento',
#  'planeadora y programadora integ de mantto',
#  'instrumentista senior',
#  'supervisora b',
#  'ingenieroa integral de operaciones a',
#  'profesional integral hse',
#  'profesional entorno a',
#  'ingenieroa plenoa confiabilidad e integ',
#  'geólogoa senior',
#  'profesional de operaciones financieras a',
#  'profesional finan y desem emp a',
#  'técnico de operaciones a',
#  'profesional de abastecimiento a',
#  'ingenieroa integral de operaciones b',
#  'profesional innovación y tecnología a',
#  'company manwoman ii',
#  'ingenieroa senior de yacimientos',
#  'supervisor a',
#  'geólogoa a',
#  'técnico de operaciones b',
#  'profesional de servicios a proyectos a',
#  'auxiliar de materiales',
#  'profesional de servicios a proyectos b',
#  'ingeniero integral de mantto y confiab',
#  'ingenieroa integral de procesos',
#  'mecánicoa mayor',
#  'administradora de contratos b',
#  'oficinista',
#  'metalmecánico mayor',
#  'electricista senior',
#  'profesional especial fina y desem emp',
#  'técnico de mantenimiento a',
#  'ingenieroa de mantto y confiab a',
#  'técnicoa de mantenimiento y confiabilidad b',
#  'líder proyectos tipo 2',
#  'electricista mayor',
#  'loading master',
#  'abogadoa especializadoa a',
#  'profesional integral de entorno',
#  'profesional integral de abastecimiento',
#  'profesional de abastecimiento b',
#  'profesional de talento humano a',
#  'profesional integral de gestión',
#  'instrumentista mayor',
#  'ingenieroa de operaciones b',
#  'analista administrativo',
#  'operadora de planta susp contrato cenit',
#  'ingenieroa de proyectos a',
#  'prof de logística de comercialización',
#  'ingenieroa junior a',
#  'técnicoa administrativoa a',
#  'ingenieroa de perf y compl b',
#  'profesional integral de med y balance b',
#  'operadora de subsuelo',
#  'profesional hse b',
#  'geólogoa b',
#  'ingeniero de confiabilidad e integridad',
#  'ingenieroa integral de yacimientos',
#  'ingenieroa de operaciones a',
#  'ingenieroa senior de proyectos',
#  'obreroa',
#  'ingenieroa integral de perf y compl',
#  'coordinadora producción',
#  'coord opera y mante tipo 2',
#  'profesional de servicios inmobiliarios',
#  'profesional de logística e inventarios a',
#  'asistente administrativoa viceger gensecr gen',
#  'profesional senior hse',
#  'profesional de gestión',
#  'ingenieroa de construcción b',
#  'profesional especializado eval finan',
#  'profesional especializado talento hum a',
#  'ingenieroa senior de comisionamiento',
#  'mecanico senior',
#  'profesional integral digital b',
#  'profesional integral de innovación y tec',
#  'profesional i vpr',
#  'profesional especializado talento hum b',
#  'profesional de aseguramiento salud a',
#  'profesional innovación y tecnología b',
#  'profesional integral de logís e invent',
#  'comunicadora integral a',
#  'operadora de equipo pesado senior',
#  'analista de operac talento hum',
#  'geofísicoa senior',
#  'profesional senior desarr y competit emp',
#  'ingenieroa de yacimientos a',
#  'jefea de turno',
#  'profesional de servicios adtivo b',
#  'posición dummy',
#  'soldador senior',
#  'profesional integral med y contab a',
#  'gerente financiero comercial',
#  'ingeniero integral de operaciones a',
#  'coordinadora ingeniería de superficie regional',
#  'profesional senior de entorno',
#  'gerente general de proyectos',
#  'refractarista',
#  'ingenieroa de construcción a',
#  'prof integral de operación digital b',
#  'profesional de operaciones financieras b',
#  'administrador de contratos a',
#  'profesional senior de gestión',
#  'técnicoa administrativoa b',
#  'coordinadora de planta b',
#  'profesional entorno b',
#  'profesional especializado operac finan',
#  'abogadoa senior',
#  'profesional de prestación de salud a',
#  'analista de laboratorio b',
#  'técnicoa de operaciones b susp contrato',
#  'jefea dpto producción',
#  'operadora preven.  control emerg. senior',
#  'ingenieroa de comisionamiento a',
#  'operadora de planta mayor susp contrato',
#  'profesional integral digital a',
#  'operadora de planta senior susp contrat',
#  'geólogoa integral',
#  'programadora integrador',
#  'supervisor de centro de control remoto',
#  'metalmecanico senior',
#  'profesional integral operac talento hum',
#  'profesional senior digital',
#  'técnico de operaciones b susp contrato c',
#  'autoridad ingeniería de yacimientos',
#  'profesional integral servicios a proy',
#  'ingenieroa de planta a',
#  'líder a - operaciones',
#  'líder de paradas de planta a',
#  'gerente de hub',
#  'profesional de operac talento hum',
#  'ingenieroa de producción b',
#  'prof sop logístico de comercialización',
#  'profesional especializado de abast',
#  'profesional de pruebas y ensayos',
#  'líder proyectos tipo 1',
#  'desarrolladora de nuevos negocios',
#  'profesional de ética y cumplimiento a',
#  'profesional cco',
#  'operador de subsuelo',
#  'profesional de operaciones',
#  'autoridad geofísica',
#  'jefea dpto programacion y servicios mantto',
#  'metalmecánico',
#  'operador de subsuelo senior',
#  'profesional junior hse',
#  'ingenieroa integral de producción',
#  'desarrolladora de negocios crudos y productos',
#  'profesional de med y balance',
#  'líder b - activos con socios',
#  'jefea dept regional entorno surcaribe',
#  'auditora internoa b',
#  'coordinador de planta b',
#  'company manwoman i',
#  'profesional finan y desem emp b',
#  'ingenieroa aseguramiento de proy a',
#  'profesional senior de evaluaciones finan',
#  'líder proyectos tipo 3',
#  'profesional integral med y balance a',
#  'auditora internoa integral',
#  'profesional especializado aná mer y prec',
#  'soldadora senior',
#  'prof junior de ética y cumplimiento b',
#  'operadora preven.  control emerg. mayor',
#  'profesional senior de operaciones financieras',
#  'jefe departamento opera  mante',
#  'profesional senior de talento humano',
#  'jefe depto reg ing piedemonte',
#  'jefea dpt corp aseg ries  contr int proc',
#  'coordinadora energía y perdidas',
#  'profesional de análi de merca y prec a',
#  'planeadora y programador senior de mantto',
#  'jefe departamento nacional de prestación de salud',
#  'abogadoa especializadoa b',
#  'ingenieroa senior aseguramiento de proy',
#  'profesional de mercado de capitales a',
#  'ingenieroa aseguramiento de proy b',
#  'administrador de contratos b',
#  'gere opera de innovación y tecnología',
#  'profesional de riesgos y control int a',
#  'líder c - entorno',
#  'ingenieroa senior confiabilidad e integ',
#  'gerente de soporte tecnológico',
#  'business partner digital senior',
#  'business partner de talento humano b',
#  'analista de logística e inventarios a',
#  'gerente de qa y riesgos de proyectos',
#  'jefea de operaciones de mantenimiento',
#  'mecánico mayor',
#  'ingenieroa senior de procesos',
#  'jefe de inspeccion de calidad',
#  'ingenieroa integral de construcción',
#  'profesional senior de información',
#  'ingenieroa de yacimientos b',
#  'administradora senior de contratos',
#  'programadora',
#  'profesional integral oper de trans y log',
#  'coordinadora operaciones y mantenimiento tipo 1',
#  'profesional infraestructura no indus a',
#  'planeadora operativoa',
#  'profesional junior de gestión',
#  'petrofísicoa integral',
#  'ingenieroa integral de mantto y confiabilidad',
#  'líd c - finan de planeación y portafolio',
#  'líder a - completamiento',
#  'coordinadora de subsuelo',
#  'analista de logística e inventarios b',
#  'mensajeroa',
#  'profesional de maduración de proyectos b',
#  'auditora internoa senior',
#  'profesional senior finanzas y desem emp',
#  'autoridad geología',
#  'ger de oper de des y prod catatumbo-teca',
#  'profesional de talento humano b',
#  'líder a  riesgos operacionales',
#  'ingenieroa de mantto y confiabilidad a',
#  'abogadoa disciplinario especializado',
#  'soldadora mayor',
#  'asistente administrativo',
#  'coordinadora de gestión de beneficios',
#  'operadora de planta susp contrato - niv',
#  'ingeniero de proyectos a',
#  'business partner de talento humano a',
#  'jefea dpto de dominio',
#  'profesional de logística e inventarios b',
#  'ingeniero integral de procesos',
#  'lider c - mantenimiento',
#  'profesional de operación digital b',
#  'geofísicoa integral',
#  'abogadoa a',
#  'jefea dpto operaciones y mtto',
#  'líder b - operación directa',
#  'líder de mantenimiento',
#  'autoridad ingeniería de perf y compl',
#  'líder a - de desarrollo',
#  'coordinador de líneas andina',
#  'jefea dpto de planeación y programación',
#  'líder de proyectos tipo 1',
#  'ingeniero de construcción a',
#  'profesional integral de información a',
#  'profesional de ética y cumplimiento b',
#  'business partner digital a',
#  'soldador',
#  'profesional senior desarr y competit empresarial',
#  'vicepresid refinación y procesos industr',
#  'comunicadora integral b',
#  'técnicoa de operaciones a susp contrato',
#  'planeador y programador de mantenimiento',
#  'profesional senior de estrategia',
#  'jefe turno ccmo',
#  'profesional de negocios',
#  'profesional en año social obligatorio',
#  'jefea dpto confiabilidad equipo rotat y estat',
#  'company manwoman iii',
#  'líder a - ingeniería',
#  'profesional de maduración de proyectos a',
#  'metalmecanico mayor',
#  'prof integral de operación digital a',
#  'jefea dpto de ingeniería de plantas',
#  'geólogo integral',
#  'jefea dpto planeación operativa',
#  'geólogoa junior a',
#  'técnicoa de operaciones marítimas',
#  'ingeniero de operaciones a',
#  'jefe turno mantenimiento',
#  'ingenieroa senior de construcción',
#  'abogadoa disciplinarioa a',
#  'coordinadora transp terrest marítimo y fluvial',
#  'ingeniero integral de yacimientos',
#  'geren corp de control y reportes',
#  'profesional junior de innovación y tec a',
#  'profesional integral de servicios adtivo',
#  'jefea dpto de refinacion de fondos',
#  'gerente de excelencia operacional',
#  'gerente de operaciones',
#  'profesional operac de transp y log b',
#  'profesional digital b',
#  'jefea dpto de mantenimiento',
#  'profesional ii',
#  'analista de operación digital a',
#  'jefe departamento de automatización y control',
#  'asesor vrp',
#  'planeador y programador integ de mantto',
#  'ingeniero junior a',
#  'jefea dpto gestión infraestructura y activos id',
#  'vicepresidente comercial y de mercadeo',
#  'líder b - terminaciones',
#  'ingenieroa integral de proyectos',
#  'jefe departamento oper  manten',
#  'profesional de proyectos a',
#  'profesional especializado mercado de cap',
#  'jefea dpto de inteligencia de mercados',
#  'profesional de med y contab',
#  'ingeniero de perf y compl b',
#  'electricista',
#  'líder c - aseguramiento y control de inventatios',
#  'coordinadora de programación de la producción',
#  'profesional senior med y balance',
#  'jefea dpto operaciones y mantenimiento fluvial',
#  'jefea dpto corpo auditoría de filiales',
#  'ingeniero de producción a',
#  'profesional de opera de trans y log a',
#  'analista de información a',
#  'geofísico senior',
#  'petrofísicoa b',
#  'analista de atención operac talento hum',
#  'coordinadora mejoras infraestructura',
#  'coordinadora gestión y control ambiental',
#  'jefea dpto desa y transf tecnológica upstream',
#  'líder c - mantenimiento',
#  'jefea dpto alquilación',
#  'coordinadora de operación tributaria',
#  'analista de servicios administrativos a',
#  'ingenieroa de proyectos b',
#  'mecánico senior',
#  'jefe dpto producción',
#  'gerente de opera e infraes digital',
#  'coordinadora portafolio e inversiones vrovas',
#  'jefea dpto planeación y programación',
#  'profesional senior servicios a proy',
#  'senior trader',
#  'mecanico mayor',
#  'coordinadora de operaciones de producción',
#  'gerente de talento humano downstream',
#  'ingeniero de perf y compl a',
#  'profesional de evaluaciones finan a',
#  'profesional integral de infraes no indus',
#  'líder reg de inventarios orinoquíacasti',
#  'jefea dpto de gestión y transformacion tmo',
#  'profesional integral de cyberseguridad b',
#  'geofísicoa a',
#  'técnico de operaciones marítimas',
#  'mantenedora senior',
#  'líder de gestión de bodegas',
#  'jefe de centro de formación empresarial',
#  'conductora',
#  'coordinadora de confiabilidad equipo rotativo',
#  'profesional de activos fijos b',
#  'coord operaciones y mantenimiento tipo 1',
#  'jefea dpto de valoración de negocios',
#  'geólogo senior',
#  'jefea dpto de perforación y completamiento',
#  'petrofísicoa senior',
#  'comunicadora b',
#  'ingeniero senior de yacimientos',
#  'comunicador a',
#  'jefea centro de estrategias de aprendizaje',
#  'autoridad de ingeniería de proyectos',
#  'coord operaciones y mantenimiento tipo 2',
#  'jefea dpto gestión integ riesgo operacional',
#  'auxiliar de salud.',
#  'ingeniero integral de producción',
#  'líder a  regional',
#  'coordinador de gestión de contratación',
#  'petrofísicoa a',
#  'integración: posición por defecto',
#  'geofísicoa b',
#  'profesional digital a',
#  'técnico en movilidad - 15',
#  'jefea dpto regional hse',
#  'jefea dpto hse perforación',
#  'profesional de negocios gas y power',
#  'jefea dpto regional jurídico',
#  'profesional de nuevos negocios a',
#  'coordinador de producción',
#  'profesional senior servicios inmobil',
#  'gerente administrativoa tipo 1',
#  'jefea dpto de mantenimiento de planta',
#  'profesional de estrategia a',
#  'profesional especializadoa talento hum a',
#  'profesional especializado prest de salud',
#  'coordinadora de operaciones de energía',
#  'profesional deconfiabilidad e integridad',
#  'jefea dpto regional entorno centorieorino',
#  'ingenieroa de planta b',
#  'profesional de servicios adtivo a',
#  'coordinadora de producción y plantas de proceso',
#  'desarrolladora de negocios gas  power',
#  'jefea dpto medición y balance de hidrocarburos',
#  'desarrolladora senior de nuevos negocios',
#  'autoridad innovación y tecnología',
#  'gerente de desarrollo',
#  'profesional de mercado de capitales b',
#  'jefea dpto de selección',
#  'mantenedora',
#  'coordinador producción',
#  'jefea dpto ingeniería de procesos',
#  'profesional de riesgos y control int b',
#  'mecánicoa',
#  'coordinador gestión de cuentas por pagar',
#  'líder b  tecnologías de superficie',
#  'jefea dpto de gestión laboral',
#  'geren excelencia innova y tecnología',
#  'jefea de depto cumplimiento legal y relacionamiento',
#  'líder b - de desarrollo',
#  'ingeniero integral de operaciones b',
#  'ingeniero de proyectos b',
#  'coordinadora de planta a',
#  'desarrolladora de soluciones de transporte y logíst',
#  'profesional especializado evaluaciones financieras',
#  'gerente asesoría jur. downstream y trans',
#  'programador integrador',
#  'profesional junior de abastecimiento',
#  'profesional integral servicios inmobil',
#  'presidente',
#  'líder c - desarrollo y liderazgo',
#  'coordinadora de imc regional',
#  'coordinadora de logística de bienes',
#  'trainee',
#  'técnicoa de mantenimiento a.',
#  'prof de negocios crudos y productos',
#  'gerente operaciones desarrollo y prod a',
#  'coordinador conectividad',
#  'aprendiz tecnicoa lectivoa',
#  'vicepresidente de talento humano',
#  'ingeniero aseguramiento de proy a',
#  'aprendiz universitario',
#  'analista de entorno b',
#  'jef depto cent cont opera prin y altern',
#  'gerente de planeación operativa',
#  'jefe departamanto operaciones logisticas',
#  'aprendiz técnico productivo',
#  'soldadora',
#  'profesional senior desarrollo y competitividad empresarial',
#  'coordinadora de operación de facilidades',
#  'operadora de subsuelo.',
#  'jefea dpto de craqueo catalítico',
#  'operador preven.  control emerg.',
#  'coordinadora de gestión de nómina',
#  'ingeniero integral de perf y compl',
#  'gerente de control operacional',
#  'coordinadora de servicios administrativos salud',
#  'jefe dpto financiero vas',
#  'vicepresidente de desarrollo sostenible',
#  'instrumentista',
#  'coord operaciones y mantenimiento tipo 2 susp contrato cenit',
#  'gerente de servicios de ingeniería de exploración',
#  'líder grupo de gestión documental',
#  'profesional senior de innovación y tec',
#  'gerente de asuntos externos',
#  'vicepresidente corp. de cumplimiento',
#  'analista de entorno a',
#  'coordinadora de llenadero',
#  'jefea dpto planeación y arquitect organiz',
#  'jefea dpto reginoal servicios orient',
#  'coordinadora ingeniería de subsuelo regional',
#  'jefe departamento de balance con transportadores',
#  'desarrollador de negocios gas  power',
#  'ingenieroa integral aseguramiento de proy',
#  'business partner talento humano a',
#  'técnicoa de mantenimiento a']

# %% [markdown]
# #Nuevos datos

# %%
contratista = pd.read_csv('Contratistas.csv')
empleados = pd.read_csv('Empleados.csv')
beneficiarios =pd.read_csv('Beneficiarios.csv')
pension =pd.read_csv('Pensionados.csv')

# %%
df_entrada = info_copilada_filtrada

for i in df_entrada.columns:
  print(i)
  try:
   df_entrada[i]=df_entrada[i].map(lambda x: x.lower())
  except:
    print('{} no se puedo pponer en minuscula'.format(i))

lista ={'f':'femenino','m':'masculino'}
df_entrada['SEXO'] = df_entrada['SEXO'].replace(lista)#.map(lambda x : x.replace())


def solo_num(x):
  try:
    sal = float(x)
  except:
    sal = np.nan
  return sal 


df_entrada['RG'] = df_entrada['RG'].map(lambda x : solo_num(x))
# Out:
# fgs_SiglasDocumentoContacto
# fgs_NumeroDocumContacto
# fgs_NumeroDocumContacto no se puedo pponer en minuscula
# N_DOCUMENTO
# N_DOCUMENTO no se puedo pponer en minuscula
# fgs_NombreCompletoContacto
# NOMBRE_COMPLETO
# CIUDAD
# POSICION
# PS
# RG
# RG no se puedo pponer en minuscula
# FECHA_NACIMIENTO
# fdp_FechaCreacion
# SEXO

# %%
df_entrada.columns
# Out:
# Index(['fgs_SiglasDocumentoContacto', 'fgs_NumeroDocumContacto', 'N_DOCUMENTO',
#        'fgs_NombreCompletoContacto', 'NOMBRE_COMPLETO', 'CIUDAD', 'POSICION',
#        'PS', 'RG', 'FECHA_NACIMIENTO', 'fdp_FechaCreacion', 'SEXO'],
#       dtype='object')

# %%
def creacion_tabla(x):
  tabla_x = mytable(x)
  print(x.shape)
  return tabla_x

tablas ={}
contratista_tabla = creacion_tabla(contratista)

contratista_tabla
# Out:
# (10971, 18)
#                                 % de datos nulos  ...  % de valores diferentes
# ID                                      0.009115  ...                99.990885
# AREA                                    0.082034  ...                16.242822
# AREAORGANIZATIVA_UNIDADNEGOCIO         98.833288  ...                 0.182299
# CARGO                                   0.191414  ...                34.418011
# DESCRIPCION                             0.537781  ...                 1.057333
# DIRECCION_CONTRATO                     15.695926  ...                47.753167
# DIRECCION_OFICINA                       0.227873  ...                42.466503
# DN                                      0.100264  ...                99.653632
# EMPRESA                                 0.145839  ...                10.454835
# FAX                                    99.289035  ...                 0.328138
# FECHA_EXPIRACION                        0.401057  ...                 6.854434
# HOME                                   99.516908  ...                 0.437517
# LOGIN                                   0.027345  ...                99.653632
# MANAGER                                 2.032631  ...                 2.971470
# NOMBRE_A_MOSTRAR                        0.100264  ...                99.763012
# NOTAS                                  99.289035  ...                 0.246103
# PAGER                                  99.817701  ...                 0.136724
# WEB                                    99.653632  ...                 0.337253
#
# [18 rows x 5 columns]

# %%
mapa = contratista['ID'].map(lambda x: isnum(x))
print(contratista.shape,contratista[mapa].shape,contratista[mapa].shape[0]/contratista.shape[0]*100 )
contratista = contratista[mapa].copy()
contratista['ID'] = contratista['ID'].astype('int')
tablas['contratista_tabla']=[contratista_tabla,contratista]
# Out:
# (10971, 18) (10780, 18) 98.25904657734026

# %%
empleados_tabla = creacion_tabla(empleados)
tablas['empleados_tabla']=[empleados_tabla,empleados]
empleados_tabla
# Out:
# (9812, 13)
#                      % de datos nulos  ...  % de valores diferentes
# ID                                0.0  ...               100.000000
# ID_EMPLEADO                     100.0  ...                 0.000000
# USUARIO                           0.0  ...               100.000000
# APERS                             0.0  ...                 0.101916
# AREA_DE_PERSONAL                  0.0  ...                 0.081533
# CENTRO_COSTE                      0.0  ...                 8.214431
# CLASE DE FECHA                  100.0  ...                 0.000000
# DTYPE                           100.0  ...                 0.000000
# FECHA_LABORAL                     0.0  ...                19.007338
# GRPER                             0.0  ...                 0.030575
# GRUPO_PERSONAL                    0.0  ...                 0.030575
# NO_PERS                           0.0  ...               100.000000
# UNIDAD_ORGANIZATIVA               0.0  ...                 5.686914
#
# [13 rows x 5 columns]

# %%
beneficiarios_tabla = creacion_tabla(beneficiarios)

beneficiarios_tabla
# Out:
# (76607, 6)
#                          % de datos nulos  ...  % de valores diferentes
# ID                               0.001305  ...                99.030115
# CODIGO_FISCAL_PROVINCIA          0.039161  ...                 0.574360
# HISTORIA_CLINICA                 0.169697  ...                 0.127926
# NO_PERS                          0.001305  ...                26.254781
# NUMPER_HIS_FAM                  64.713407  ...                34.560810
# SUBTIPO                          0.001305  ...                 0.019580
#
# [6 rows x 5 columns]

# %%
mapa = beneficiarios['ID'].map(lambda x: isnum(x))
print(beneficiarios.shape,beneficiarios[mapa].shape,beneficiarios[mapa].shape[0]/beneficiarios.shape[0]*100 )
beneficiarios = beneficiarios[mapa].copy()
beneficiarios['ID'] = beneficiarios['ID'].astype('int')
tablas['beneficiarios_tabla']=[beneficiarios_tabla,beneficiarios]
# Out:
# (76607, 6) (68487, 6) 89.40044643439894

# %%
pension_tabla = creacion_tabla(pension)
tablas['pension_tabla']=[pension_tabla,pension]
pension_tabla
# Out:
# (12997, 13)
#                      % de datos nulos  ...  % de valores diferentes
# ID                           0.000000  ...               100.000000
# ID_PENSIONADO               96.045241  ...                 0.015388
# APERS                       96.637686  ...                 0.046164
# AREA_DE_PERSONAL             0.000000  ...                 0.069247
# CENTRO_COSTE                99.992306  ...                 0.007694
# CLASE DE FECHA              96.045241  ...                 0.030776
# DTYPE                       96.045241  ...                 0.023082
# FECHA_PENSIONADO             0.000000  ...                40.309302
# GRPER                        0.000000  ...                 0.015388
# GRUPO DE PERSONAL            0.000000  ...                 0.015388
# NO_PERS                      0.000000  ...               100.000000
# UNIDAD_ORGANIZATIVA          4.324075  ...                 0.015388
# NOMBRE_CECO                  0.377010  ...                 0.007694
#
# [13 rows x 5 columns]

# %%
def eliminacion_columnas(tabla):
  cardinalidad100 = tabla[tabla['% de valores diferentes']==100]
  cardinalidad1 = tabla[tabla['# de valores diferentes']==1]
  vacios = tabla[tabla['% de datos nulos']==100]
  variables_eliminar=vacios.index.tolist()+cardinalidad1.index.tolist()+cardinalidad100.index.tolist()# no aportan informacion
  print('numero de variables a eliminar : {}'.format(len(variables_eliminar)))
  return variables_eliminar

# %%
try:
 variables_eliminar.remove('ID')
except Exception as e: 
  print(e)
# Out:
# list.remove(x): x not in list

# %%
variables_eliminar
# Out:
# ['fgs_NombreDocumentoContacto',
#  'fgs_FechaNacimientoContacto',
#  'fgs_HabeasContacto',
#  'fgs_NombreGeneroContacto',
#  'fgs_RoutingPointOrVdn',
#  'fgs_Extension',
#  'fgs_CallId',
#  'fgs_Skill',
#  'fgs_Ani',
#  'fgs_OpcionesIVR',
#  'fgs_Nivel5',
#  'fgs_Nivel6',
#  'fgs_Nivel7',
#  'fgs_Nivel8',
#  'fgs_Nivel9',
#  'fgs_Nivel10',
#  'fdp_IdDetalleFlujoCreacion',
#  'fdp_FechaVencimientoCreacion',
#  'fdp_MotivoCreacion',
#  'fdp_MotivoEscalamientoN2',
#  'fdp_IdHistoricoPqrEscalamientoN3',
#  'fdp_IdGrupoEscalamientoN3',
#  'fdp_NombreGrupoEscalamientoN3',
#  'fdp_IdDetalleFlujoEscalamientoN3',
#  'fdp_IdUsuarioEscalamientoN3',
#  'fdp_UsuarioEscalamientoN3',
#  'fdp_NombreUsuarioEscalamientoN3',
#  'fgs_ObservacionEscalamientoN3',
#  'fdp_FechaEscalamientoN3',
#  'fdp_FechaVencimientoEscalamientoN3',
#  'CodigoGrupoRolEscalamientoN3',
#  'GrupoRolEscalamientoN3',
#  'fdp_MotivoEscalamientoN3',
#  'fdp_NivelEscalamientoN3',
#  'T_Objetivo_EnNivel3',
#  'fdp_MotivoSolucion',
#  'fdp_MotivoReapertura',
#  'fdp_MotivoCierre',
#  'T_Real_Total',
#  'Cumple_Objetivo_Total',
#  'Valido',
#  'fdp_IdHistoricoPqrEscalamientoN4',
#  'fdp_IdGrupoEscalamientoN4',
#  'fdp_NombreGrupoEscalamientoN4',
#  'fdp_IdDetalleFlujoEscalamientoN4',
#  'fdp_IdUsuarioEscalamientoN4',
#  'fdp_UsuarioEscalamientoN4',
#  'fdp_NombreUsuarioEscalamientoN4',
#  'fgs_ObservacionEscalamientoN4',
#  'fdp_FechaEscalamientoN4',
#  'fdp_FechaVencimientoEscalamientoN4',
#  'CodigoGrupoRolEscalamientoN4',
#  'GrupoRolEscalamientoN4',
#  'fdp_MotivoEscalamientoN4',
#  'fdp_NivelEscalamientoN4',
#  'T_Objetivo_EnNivel4',
#  'fgs_IdCampana',
#  'fgs_NombreCampana',
#  'fgs_NombrePlataforma',
#  'fgs_Nivel1',
#  'fgs_PaisDireccion_01',
#  'TipoTransacción',
#  'TipoComplejidad',
#  'Funcionalidad',
#  'DependenciaLínea',
#  'AreaServicio',
#  'fdp_IdGrupoCreacion',
#  'fdp_NombreGrupoCreacion',
#  'fdp_NivelCreacion',
#  'T_Objetivo_SolicitadoRegistrado',
#  'T_Objetivo_RegistradoEscalado',
#  'fdp_NivelEscalamientoN2',
#  'T_Real_EnNivel3',
#  'Cumple_Objetivo_EnNivel3',
#  'fdp_IdGrupoDevolucion',
#  'fdp_NombreGrupoDevolucion',
#  'fdp_NivelDevolucion',
#  'T_Objetivo_SolucionadoCerrado',
#  'fdp_IdHistoricoPqrReapertura',
#  'fdp_IdGrupoReapertura',
#  'fdp_NombreGrupoReapertura',
#  'fdp_IdDetalleFlujoReapertura',
#  'fdp_IdUsuarioReapertura',
#  'fdp_UsuarioReapertura',
#  'fdp_NombreUsuarioReapertura',
#  'fgs_ObservacionReapertura',
#  'fdp_FechaReapertura',
#  'fdp_FechaVencimientoReapertura',
#  'CodigoGrupoRolReapertura',
#  'GrupoRolReapertura',
#  'fdp_NivelReapertura',
#  'Ajustado',
#  'Pruebas',
#  'T_Real_EnNivel4',
#  'Cumple_Objetivo_EnNivel4',
#  'fgs_IdGestion',
#  'fgs_IdGestionDetalle']

# %%
df_filtradas={}
for i in tablas.keys():
  print(i)
  df_tablas = tablas[i][0]
  df =tablas[i][1]
  variables_eliminar = eliminacion_columnas(df_tablas)
  try:
    variables_eliminar.remove('ID')
  except Exception as e: 
    print(e)
  mapa_columnas = [i not in variables_eliminar for i in df.columns]  
  nuevas_columnas = df.columns[mapa_columnas]
  df_filtradas['{}_filtrada'.format(i)] =df[nuevas_columnas]
# Out:
# contratista_tabla
# numero de variables a eliminar : 0
# list.remove(x): x not in list
# empleados_tabla
# numero de variables a eliminar : 6
# beneficiarios_tabla
# numero de variables a eliminar : 0
# list.remove(x): x not in list
# pension_tabla
# numero de variables a eliminar : 4

# %%
df_filtradas.keys()
# Out:
# dict_keys(['contratista_tabla_filtrada', 'empleados_tabla_filtrada', 'beneficiarios_tabla_filtrada', 'pension_tabla_filtrada'])

# %%
mytable(df_filtradas['empleados_tabla_filtrada'])
# Out:
#                      % de datos nulos  ...  % de valores diferentes
# ID                                0.0  ...               100.000000
# APERS                             0.0  ...                 0.101916
# AREA_DE_PERSONAL                  0.0  ...                 0.081533
# CENTRO_COSTE                      0.0  ...                 8.214431
# FECHA_LABORAL                     0.0  ...                19.007338
# GRPER                             0.0  ...                 0.030575
# GRUPO_PERSONAL                    0.0  ...                 0.030575
# UNIDAD_ORGANIZATIVA               0.0  ...                 5.686914
#
# [8 rows x 5 columns]

# %%
mytable(df_entrada)
# Out:
#                              % de datos nulos  ...  % de valores diferentes
# fgs_SiglasDocumentoContacto          0.000000  ...                 0.023179
# fgs_NumeroDocumContacto              0.000000  ...                32.334080
# N_DOCUMENTO                          0.000000  ...                32.334080
# fgs_NombreCompletoContacto           0.000000  ...                32.372711
# NOMBRE_COMPLETO                      0.000000  ...                32.334080
# CIUDAD                               0.000000  ...                 1.058487
# POSICION                             0.000000  ...                 3.693116
# PS                                   0.000000  ...                 0.023179
# RG                                   0.077262  ...                 0.177702
# FECHA_NACIMIENTO                     0.000000  ...                28.926833
# fdp_FechaCreacion                    0.000000  ...                99.953643
# SEXO                                 0.000000  ...                 0.015452
#
# [12 rows x 5 columns]

# %%
mapa = beneficiarios['ID'].map(lambda x: isnum(x))
print(beneficiarios.shape,beneficiarios[mapa].shape,beneficiarios[mapa].shape[0]/beneficiarios.shape[0]*100 )
beneficiarios = beneficiarios[mapa].copy()
beneficiarios['ID'] = beneficiarios['ID'].astype('int')
# Out:
# (68487, 6) (68487, 6) 100.0

# %%
# df_filtradas[i].columns

# %%
for i in df_filtradas.keys():
  tam = df_entrada.shape
  print(i)
  df_entrada = df_entrada.merge(how='left', right=df_filtradas[i],left_on='fgs_NumeroDocumContacto',right_on='ID')
  print(tam,df_entrada.shape)
# Out:
# contratista_tabla_filtrada
# (12943, 12) (12943, 30)
# empleados_tabla_filtrada
# (12943, 30) (12943, 38)
# beneficiarios_tabla_filtrada
# (12943, 38) (12943, 44)
# pension_tabla_filtrada
# (12943, 44) (12943, 54)

# %%
df_entrada
# Out:
#       fgs_SiglasDocumentoContacto  ...  UNIDAD_ORGANIZATIVA_y
# 0                              cc  ...             99999999.0
# 1                              cc  ...             99999999.0
# 2                              cc  ...             99999999.0
# 3                              cc  ...             99999999.0
# 4                              cc  ...             99999999.0
# ...                           ...  ...                    ...
# 12938                          cc  ...             99999999.0
# 12939                          cc  ...             99999999.0
# 12940                          cc  ...                    NaN
# 12941                          cc  ...                    NaN
# 12942                          cc  ...                    NaN
#
# [12943 rows x 54 columns]

# %%
df_entrada.merge(how='left', right=df_filtradas[i],left_on='N_DOCUMENTO',right_on='ID')
# Out:
#       fgs_SiglasDocumentoContacto  ...  UNIDAD_ORGANIZATIVA
# 0                              cc  ...           99999999.0
# 1                              cc  ...           99999999.0
# 2                              cc  ...           99999999.0
# 3                              cc  ...           99999999.0
# 4                              cc  ...           99999999.0
# ...                           ...  ...                  ...
# 12938                          cc  ...           99999999.0
# 12939                          cc  ...           99999999.0
# 12940                          cc  ...                  NaN
# 12941                          cc  ...                  NaN
# 12942                          cc  ...                  NaN
#
# [12943 rows x 64 columns]

# %%
mytable(df_entrada)
# Out:
#                                 % de datos nulos  ...  % de valores diferentes
# fgs_SiglasDocumentoContacto             0.000000  ...                 0.023179
# fgs_NumeroDocumContacto                 0.000000  ...                32.334080
# N_DOCUMENTO                             0.000000  ...                32.334080
# fgs_NombreCompletoContacto              0.000000  ...                32.372711
# NOMBRE_COMPLETO                         0.000000  ...                32.334080
# CIUDAD                                  0.000000  ...                 1.058487
# POSICION                                0.000000  ...                 3.693116
# PS                                      0.000000  ...                 0.023179
# RG                                      0.077262  ...                 0.177702
# FECHA_NACIMIENTO                        0.000000  ...                28.926833
# fdp_FechaCreacion                       0.000000  ...                99.953643
# SEXO                                    0.000000  ...                 0.015452
# ID_x                                   99.845476  ...                 0.069536
# AREA                                   99.845476  ...                 0.069536
# AREAORGANIZATIVA_UNIDADNEGOCIO        100.000000  ...                 0.000000
# CARGO                                  99.845476  ...                 0.054083
# DESCRIPCION                            99.845476  ...                 0.054083
# DIRECCION_CONTRATO                     99.860929  ...                 0.061809
# DIRECCION_OFICINA                      99.845476  ...                 0.069536
# DN                                     99.845476  ...                 0.069536
# EMPRESA                                99.845476  ...                 0.069536
# FAX                                   100.000000  ...                 0.000000
# FECHA_EXPIRACION                       99.845476  ...                 0.061809
# HOME                                  100.000000  ...                 0.000000
# LOGIN                                  99.845476  ...                 0.069536
# MANAGER                                99.845476  ...                 0.054083
# NOMBRE_A_MOSTRAR                       99.845476  ...                 0.069536
# NOTAS                                 100.000000  ...                 0.000000
# PAGER                                 100.000000  ...                 0.000000
# WEB                                   100.000000  ...                 0.000000
# ID_y                                   46.225759  ...                19.802210
# APERS_x                                46.225759  ...                 0.054083
# AREA_DE_PERSONAL_x                     46.225759  ...                 0.054083
# CENTRO_COSTE                           46.225759  ...                 4.728425
# FECHA_LABORAL                          46.225759  ...                 7.919339
# GRPER_x                                46.225759  ...                 0.023179
# GRUPO_PERSONAL                         46.225759  ...                 0.023179
# UNIDAD_ORGANIZATIVA_x                  46.225759  ...                 3.461330
# ID_x                                   98.315692  ...                 0.479023
# CODIGO_FISCAL_PROVINCIA                98.315692  ...                 0.131345
# HISTORIA_CLINICA                       98.315692  ...                 0.224059
# NO_PERS                                98.315692  ...                 0.479023
# NUMPER_HIS_FAM                         98.385228  ...                 0.440392
# SUBTIPO                                98.315692  ...                 0.030905
# ID_y                                   60.210152  ...                10.167658
# ID_PENSIONADO                          99.520977  ...                 0.007726
# APERS_y                                99.544155  ...                 0.030905
# AREA_DE_PERSONAL_y                     60.210152  ...                 0.054083
# CLASE DE FECHA                         99.520977  ...                 0.007726
# DTYPE                                  99.520977  ...                 0.007726
# FECHA_PENSIONADO                       60.210152  ...                 6.760411
# GRPER_y                                60.210152  ...                 0.007726
# GRUPO DE PERSONAL                      60.210152  ...                 0.007726
# UNIDAD_ORGANIZATIVA_y                  60.797342  ...                 0.007726
#
# [54 rows x 5 columns]

# %%
df_tablas = mytable(df_entrada)
df =df_entrada
variables_eliminar = eliminacion_columnas(df_tablas)
try:
  variables_eliminar.remove('ID')
except Exception as e: 
  print(e)
mapa_columnas = [i not in variables_eliminar for i in df.columns]  
nuevas_columnas = df.columns[mapa_columnas]
df_entrada=df[nuevas_columnas]
# Out:
# numero de variables a eliminar : 12
# list.remove(x): x not in list

# %%
mytable(df_entrada)
# Out:
#                              % de datos nulos  ...  % de valores diferentes
# fgs_SiglasDocumentoContacto          0.000000  ...                 0.023179
# fgs_NumeroDocumContacto              0.000000  ...                32.334080
# N_DOCUMENTO                          0.000000  ...                32.334080
# fgs_NombreCompletoContacto           0.000000  ...                32.372711
# NOMBRE_COMPLETO                      0.000000  ...                32.334080
# CIUDAD                               0.000000  ...                 1.058487
# POSICION                             0.000000  ...                 3.693116
# PS                                   0.000000  ...                 0.023179
# RG                                   0.077262  ...                 0.177702
# FECHA_NACIMIENTO                     0.000000  ...                28.926833
# fdp_FechaCreacion                    0.000000  ...                99.953643
# SEXO                                 0.000000  ...                 0.015452
# ID_x                                99.845476  ...                 0.069536
# ID_x                                98.315692  ...                 0.479023
# AREA                                99.845476  ...                 0.069536
# CARGO                               99.845476  ...                 0.054083
# DESCRIPCION                         99.845476  ...                 0.054083
# DIRECCION_CONTRATO                  99.860929  ...                 0.061809
# DIRECCION_OFICINA                   99.845476  ...                 0.069536
# DN                                  99.845476  ...                 0.069536
# EMPRESA                             99.845476  ...                 0.069536
# FECHA_EXPIRACION                    99.845476  ...                 0.061809
# LOGIN                               99.845476  ...                 0.069536
# MANAGER                             99.845476  ...                 0.054083
# NOMBRE_A_MOSTRAR                    99.845476  ...                 0.069536
# ID_y                                46.225759  ...                19.802210
# ID_y                                60.210152  ...                10.167658
# APERS_x                             46.225759  ...                 0.054083
# AREA_DE_PERSONAL_x                  46.225759  ...                 0.054083
# CENTRO_COSTE                        46.225759  ...                 4.728425
# FECHA_LABORAL                       46.225759  ...                 7.919339
# GRPER_x                             46.225759  ...                 0.023179
# GRUPO_PERSONAL                      46.225759  ...                 0.023179
# UNIDAD_ORGANIZATIVA_x               46.225759  ...                 3.461330
# ID_x                                99.845476  ...                 0.069536
# ID_x                                98.315692  ...                 0.479023
# CODIGO_FISCAL_PROVINCIA             98.315692  ...                 0.131345
# HISTORIA_CLINICA                    98.315692  ...                 0.224059
# NO_PERS                             98.315692  ...                 0.479023
# NUMPER_HIS_FAM                      98.385228  ...                 0.440392
# SUBTIPO                             98.315692  ...                 0.030905
# ID_y                                46.225759  ...                19.802210
# ID_y                                60.210152  ...                10.167658
# APERS_y                             99.544155  ...                 0.030905
# AREA_DE_PERSONAL_y                  60.210152  ...                 0.054083
# FECHA_PENSIONADO                    60.210152  ...                 6.760411
#
# [46 rows x 5 columns]
